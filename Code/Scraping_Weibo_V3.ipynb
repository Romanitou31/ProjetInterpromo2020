# %% [markdown]
# ### Importations

# %%
import urllib.request
import urllib.parse
import urllib.error
from bs4 import BeautifulSoup
import ssl
import json
import ast
import json
import os
from urllib.request import Request, urlopen
from bs4 import BeautifulSoup as bs
import requests
import re
import pandas as pd
import numpy as np
import datetime as dt
from textblob import TextBlob

# %%
compagniesAeriennes=["American Airlines","Air Canada","Air France","Air Algerie","Air India","Aerolineas Argentinas","Royal Air Maroc","Finnair" ,"Alitalia "," Nouvelair","Air China","Cathay Pacific","Delta Airlines","Aer Lingus","Emirates","Ethiopian Airlines","Icelandair","Hawaiian Airlines","Iberia","Meridiana","Japan Airlines","KLM","Air Malta","Lan Airlines","Luxair","LIAT","LOT Polish Airlines","Air Madagascar","Air Mauritius","Austrian Airlines","Qatar Airways","South African Airways","SAS Scandinavian Airlines","Brussels Airlines","Singapore Airlines","Corsair","Aeroflot","Thai Airways","Turkish Airlines","TAP Portugal","Air Transat","Tunisair","Air Caraibes","United Airlines","Air Austral","Air Europa","Easyjet","Vietnam Airlines","Virgin Atlantic","Air Corsica","Condor","Flybe","Aegean Airlines","Air Tahiti Nui","Aigle Azur","HOP!","Jet Airways","Etihad Airways","Etihad Airways","Oman Air","XL Airways","Ryanair LTD","Vueling ","Norwegian","Transavia France","Germanwings","TUI Fly Belgium","Air Arabia","WOW air","Wizz Air","Air Asia","Volotea","southwest airlines"]
modelesBoeing=["Boeing 717","Boeing 727","Boeing 737-200","Boeing 737-300","Boeing 737-400","Boeing 737-500","Boeing 737-600","Boeing 737-700","Boeing 737-700ER","Boeing 737-800","Boeing 737-900","Boeing 737-900ER","Boeing 737 MAX 7","Boeing 737 MAX 8","Boeing 737 MAX 9","Boeing 737 MAX 10","Boeing 747-200","Boeing 747-400","Boeing 757-200","Boeing 757-300","Boeing 767-200","Boeing 767-300","Boeing 767-300ER","Boeing 767-400ER","Boeing 777 Triple Seven","Boeing 787 DreamLiner"]
modelesAirbus=["A300","A300-600ST","A318","A319","A320-100","A320-200","A320neo","A321-100","A321-200","A330-200","A330-300","A330-200F","A330-500","A340-200","A340-300","A340-500","A340-600","A350-900","A350-1000","A380-800","A220-300"]
motsCles=["trip","fly","plane","airplane","flight"]

equations=[]
for comp in compagniesAeriennes:
    for mod in modelesAirbus:
        equations.append('https://s.weibo.com/weibo/'+comp+'%2520'+mod)
    for mod in modelesBoeing:
        equations.append('https://s.weibo.com/weibo/'+comp+'%2520'+mod)
        
        
# Equation de recherche
liste1 = ['airbus', 'boeing', '']
liste2 = ['A320', 'A360', '']

a = []
for i in liste1:
    for j in liste2:
        a.append('https://s.weibo.com/weibo/'+i+'%2520'+j)
# a=['https://s.weibo.com/weibo/'+i+'%2520'+j for j in listes1 for i in liste2]

# %%
def textToDate(text):
    
    if "今天" in text:
        return dt.date.today()
    chiffres = re.search("([0-9]*\w)*",text).group(0)
    chiffres=re.findall(r"([0-9]+)",chiffres)
    if len(chiffres)==3:
        year=chiffres[0]
        month=chiffres[1]
        day=chiffres[2]
        
    elif len(chiffres)==2:
        now=dt.date.today()
        year=now.year
        month=chiffres[0]
        day=chiffres[1]
    else:
        return dt.date.today()
    return dt.date(int(year), int(month), int(day))

# %%
def recupTexteEntreBalise(texte, separateur):
    
    texte2 = []
    lisI = []
    lisS = []
    
    for i in range(0,len(texte)):
        if str(texte[i]) == "<":
            lisI.append(i)
        if texte[i] == '>':
            lisS.append(i)   

    taille = len(lisI)
    for h in range(0,taille):
        if h < (taille-1):
            texte2.append(texte[lisS[h]:lisI[h+1]])
    
    if separateur != 'non':
        description = str(texte2).replace('>','').replace(',','').replace('\'','').replace('，','')
        description = description.split(separateur)
    else:
        description = texte2
    
    return description

# %%
def supprimeBlanc(Author):
    Author2 = []
    for elem in Author:
        if len(elem) != 0:
            Author2.append(elem)
    return Author2

# %%
def recupWeibo(soup,date_comment,description,Author2, Partage,Comm,Like):
    
    nom_col = ['Data_Source','Airline_Name','Airline_Type','Region_Operation','Aircraft_Type','Cabin_Class','Type_Of_Lounge',
               'Type_Of_Traveller','Date_Visit','Date_Flown','Airport','Route','Category','Category_Detail',
               'Cabin_Staff_Service','Lounge_Staff_Service','Bar_And_Beverages','Food_And_Beverages','Ground_Service',
               'Catering','Cleanliness','Lounge_Comfort','Aisle_Space','Wifi_And_Connectivity','Inflight_Entertainment',
               'Viewing_Tv_Screen','Power_Supply','Date_publication'
              'Seat','Seat_type','Seat_Comfort','Seat_Legroom','Seat_Storage','Seat_Width','Seat_Recline','Washrooms',
               'Value_For_Money','Overall_Customer_Rating','Overall_Service_Rating','Overall_Airline_Rating',
              'Recommended','Departure_city','Arrival_city','Nb_bus_taken','Nb_train_taken',
               'Nb_car_taken','Nb_plane_taken','Duration','Price_min','Price_max','Nb_sharing','Awards',
               'Registration','Language']
    df = pd.DataFrame(columns = nom_col)
    
    detailVideos = {}

    detailVideos['Description'] = description
    detailVideos['Author'] = Author2
    detailVideos['Nb_sharing'] = Partage
    detailVideos['Likes'] = Like
#     detailVideos['Date3']= Date3
    detailVideos['Date_publication']= str(date_comment)

    with open('weibo.json', 'a', encoding='utf8') as outfile:
        json.dump(detailVideos, outfile, ensure_ascii=False, indent=4)

# %%
nb_day = 365
listURL = a

with open('weibo.json', 'w', encoding='utf8') as outfile :
    json
    
# for url in listURL :

url = listURL[0] 
#20 post
req = Request(url, headers={'User-Agent': 'Mozilla/5.0'})
web_page = urlopen(req).read()
soup = BeautifulSoup(web_page, 'html.parser')
compteur = 0

#     description

texte = str(soup.findAll('p',attrs={'node-type':'feed_list_content'}))
description = recupTexteEntreBalise(texte, '\\n')
del description[0]


#     autheur

auteur = soup.findAll('a',attrs={'class':'name'})
auteur = str(auteur)
Author = recupTexteEntreBalise(auteur, ' ')
Author2 = supprimeBlanc(Author)

# Partage / Commentaire, Avis / Like
aime = soup.findAll('div',attrs={'class':"card-act"})
aime = str(aime)
aime2 = recupTexteEntreBalise(aime, 'non')

Partage = []
Comm = []
Like = []

for i in range(0,len(aime2)):
    if aime2[i].startswith('> 转发'):
        Partage.append(str(re.findall(r'[0-9]+',str(aime2[i]))).replace('[','').replace(']','').replace('\'',''))
    if aime2[i].startswith('>评论'):
        Comm.append(str(re.findall(r'[0-9]+',str(aime2[i]))).replace('[','').replace(']','').replace('\'',''))
    test = re.findall(r'>[0-9]+',aime2[i])
    if (str(test))!='[]':
        test = re.findall(r'[0-9]+',str(test))
        Like.append(str(test).replace('[','').replace(']','').replace('\'','').replace('>',''))
    else:
        if aime2[i-7].startswith('>评论'):
            Like.append(str(aime2[i]).replace('[','').replace(']','').replace('\'','').replace('>',''))


for span1 in page1.findAll('p', attrs={'class' : 'from'}):
    for span in span1.findAll('a', attrs={'target' : '_blank'}):
        if textToDate(span.text.strip()) >= (dt.date.today() - dt.timedelta(days=(nb_day))):
            if compteur < len(Partage)-1:
                (recupWeibo(page1,textToDate(span.text.strip()),description[compteur],Author2[compteur], Partage[compteur],Comm[compteur],Like[compteur]))

    compteur += 1

print('fini')
# Out:
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# end
# 21

# %%
print(len(Like))
# Out:
# 20

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible">
# <meta content="webkit" name="renderer"/>
# <meta content="initial-scale=1,minimum-scale=1" name="viewport"/>
# <title>微博搜索</title>
# <link href="//img.t.sinajs.cn/t4/appstyle/searchpc/css/pc/css/video.css?version=20200106153100" rel="stylesheet"/>
# <link href="//img.t.sinajs.cn/t4/appstyle/searchpc/css/pc/css/global.css?version=20200106153100" rel="stylesheet"/>
# <link href="//img.t.sinajs.cn/t4/appstyle/searchpc/css/pc/css/module.css?version=20200106153100" rel="stylesheet"/>
# <link href="//img.t.sinajs.cn/t4/appstyle/searchpc/css/pc/css/page.css?version=20200106153100" rel="stylesheet"/>
# <link href="//img.t.sinajs.cn/t4/appstyle/searchpc/css/pc/css/card.css?version=20200106153100" rel="stylesheet"/>
# <link href="//img.t.sinajs.cn/t4/appstyle/searchpc/css/pc/css/css_v6/layer/layer_show_pic.css?version=20200106153100" rel="stylesheet"/>
# <script type="text/javascript">
#         var $PHOTO_TAGS=[]
#         var $CONFIG = {};
#         $CONFIG['islogin'] = '0';
#         $CONFIG['uid'] = '0';
#         $CONFIG['entry'] = 'weisousuo';
#         $CONFIG['setCover'] = 1; //ie6hack
#         $CONFIG['version'] = '20200106153100';
#         $CONFIG['bigpipe'] = 'false';
#         $CONFIG['timeDiff'] = (new Date() - 1578929400000);
#         $CONFIG['product'] = 'search';
#         $CONFIG['pageid'] = 'weibo';
#         $CONFIG['skin'] = '';
#         $CONFIG['lang'] = 'zh-cn';
#         $CONFIG['jsPath'] = '//jstest.t.sinajs.cn/t4/';
#         $CONFIG['cssPath'] = '//img.t.sinajs.cn/t4/';
#         $CONFIG['imgPath'] = '//img.t.sinajs.cn/t4/';
#         $CONFIG['servertime'] = 1578929400;
#         $CONFIG['ad_url_jump'] = '';
#         $CONFIG['$webim'] = 0; //1;
#         $CONFIG['mJsPath'] = ['https://js{n}.t.sinajs.cn/t4/', 1, 2];
#         $CONFIG['mCssPath'] = ['https://img{n}.t.sinajs.cn/t4/', 1, 2];
#         $CONFIG['s_domain'] = '//s.weibo.com';
#         $CONFIG['s_search'] = 'airbus%20A320';
#         $CONFIG['isAuto'] = 0;//0自动播放
#     </script>
# <script src="//js.t.sinajs.cn/t5/pack/js/bootstrap.js"></script>
# </meta></head>
# <body class="wbs-feed">
# <style>
#     .wrap-continuous{
#         margin-bottom: 0px;
#         border: 0px;
#     }
# </style>
# <div class="m-main">
# <!--搜索-->
# <div class="m-search" id="pl_feedtop_top">
# <div class="logo"><a class="logo_img" href="/"></a></div>
# <div class="searchbox" node-type="searchBar">
# <div class="search-input">
# <input autocomplete="off" maxlength="40" node-type="text" type="text" value="airbus A320"/>
# <div class="m-sug-list" node-type="suggestbox">
# </div>
# </div>
# <button class="s-btn-b" node-type="submit">搜索</button>
# </div>
# </div>
# <!--/搜索-->
# <!--主导航-->
# <div class="m-main-nav s-mt28">
# <ul>
# <li><a class="cur" href="/weibo?q=airbus%20A320&amp;Refer=weibo_weibo" title="综合">综合</a></li>
# <li><a href="/user?q=airbus%20A320&amp;Refer=weibo_user" title="找人">找人</a></li>
# <li><a href="/article?q=airbus%20A320&amp;Refer=weibo_article" title="文章">文章</a></li>
# <li><a href="/video?q=airbus%20A320&amp;xsort=hot&amp;hasvideo=1&amp;tw=video&amp;Refer=weibo_video" title="视频">视频</a></li>
# <li><a href="/pic?q=airbus%20A320&amp;Refer=weibo_pic" title="图片">图片</a></li>
# <li><a href="/topic?q=airbus%20A320&amp;pagetype=topic&amp;topic=1&amp;Refer=weibo_topic" title="话题">话题</a></li>
# </ul>
# </div>
# <!--/主导航-->
# <div id="pl_feed_main">
# <!--提示-->
# <div class="m-note" style="display:none"><a href="javascript:void(0);" node-type="feed_list_newBar" suda-data="key=tblog_search_weibo&amp;value=weibo_new">有8条新微博，点击查看</a></div>
# <!--/提示-->
# <!--内容-->
# <div class="m-wrap">
# <div class="m-con-l" id="pl_feedlist_index">
# <!--cate流-->
# <div>
# <!--微博card-->
# <!--card-wrap-->
# <div action-type="feed_list_item" class="card-wrap" mid="4389009834461570">
# <div class="card-top">
# <h4 class="title"><i class="icon-title icon-star"></i><a href="/weibo?q=airbus%20A320&amp;xsort=hot&amp;Refer=hotmore" suda-data="key=tblog_search_weibo&amp;value=seqid:157892939947302792048|type:1|t:0|pos:1-0|q:airbus%20A320|ext:cate:26,click:more" target="_blank">热门</a></h4>
# </div>
# <div class="card">
# <div class="card-feed">
# <div class="avator">
# <a href="//weibo.com/2204020345?refer_flag=1001030103_" suda-data="key=tblog_search_weibo&amp;value=seqid:157892939947302792048|type:1|t:0|pos:1-0|q:airbus%20A320|ext:cate:26,mpos:1,click:user_pic" target="_blank"><img src="https://tvax1.sinaimg.cn/crop.0.0.1006.1006.50/835eae79ly8g3vdau22gvj20ry0rytay.jpg?KID=imgbed,tva&amp;Expires=1578940199&amp;ssig=MqFpCuaSf4"/></a>
# </div>
# <!--微博内容-->
# <div class="content" node-type="like">
# <div class="info">
# <div class="menu s-fr">
# <a action-type="fl_menu" href="javascript:void(0);"><i class="wbicon">c</i></a>
# <ul node-type="fl_menu_right" style="display:none;">
# <li><a href="javascript:void(0);" onclick="javascript:window.open('//service.account.weibo.com/reportspam?rid=4389009834461570&amp;type=1&amp;from=10501&amp;url=&amp;bottomnav=1&amp;wvr=6', 'newwindow', 'height=700, width=550, toolbar =yes, menubar=no, scrollbars=yes, resizable=yes, location=no, status=no');">投诉</a></li>
# </ul>
# </div>
# <div>
# <a class="name" href="//weibo.com/2204020345?refer_flag=1001030103_" nick-name="三七V博" suda-data="key=tblog_search_weibo&amp;value=seqid:157892939947302792048|type:1|t:0|pos:1-0|q:airbus%20A320|ext:cate:26,mpos:1,click:user_name" target="_blank">三七V博</a>
# <a href="//verified.weibo.com/verify" target="_blank" title="微博个人认证"><i class="icon-vip icon-vip-y"></i></a>
# <!--广告微博加关注按钮 -->
# </div>
# </div>
# <p class="txt" nick-name="三七V博" node-type="feed_list_content">
# <div class="media media-video-a" node-type="feed_list_media_prev">
# <!--linkcard 不能播放视频-->
# <div class="media media-video-a" node-type="feed_list_media_disp" style="display:none;"></div>
# <!--视频card-->
# <div class="thumbnail" style="height:auto;min-height:281px;">
# <a action-data="type=feedvideo&amp;objectid=1034:4389009707981260&amp;keys=4389009806598106&amp;cover_img=%2F%2Fwx4.sinaimg.cn%2Forj480%2F835eae79ly1g4jjwwbzsij20u00gvguv.jpg&amp;card_height=0&amp;card_width=0&amp;play_count=10412&amp;short_url=http%3A%2F%2Ft.cn%2FAi0JsJGK&amp;encode_mode=&amp;bitrate=2132&amp;biz_id=230444¤t_mid=4389009834461570&amp;key=tblog_card&amp;title=%E4%B8%89%E4%B8%83V%E5%8D%9A%E7%9A%84%E7%A7%92%E6%8B%8D%E8%A7%86%E9%A2%91&amp;full_url=https%3A%2F%2Fvideo.weibo.com%2Fshow%3Ffid%3D1034%3A4389009707981260&amp;object_id=1034:4389009707981260&amp;video_src=%2F%2Ff.us.sinaimg.cn%2F001WzAoylx07v3XS8p3a01041200gIVY0E010.mp4%3Flabel%3Dmp4_ld%26template%3D632x360.22.0%26Expires%3D1578932999%26ssig%3DNoR6vIIOhV%26KID%3Dunistore%2Cvideo" action-type="feed_list_third_rend" class="WB_video_h5" href="javascript:void(0);" mediasize="852:480" node-type="fl_h5_video">
# <div node-type="fl_h5_video_pre">
# <img alt="" src="//wx4.sinaimg.cn/orj480/835eae79ly1g4jjwwbzsij20u00gvguv.jpg" style="display:block;height: 281px;"/>
# <i class="icon-media icon-play-b"></i>
# </div>
# <div node-type="fl_h5_video_disp" style="display:none;">
# </div>
# </a>
# </div>
# <!--/视频card-->
# </div>
# <!--/card解析-->
# <p class="from">
# <a href="//weibo.com/2204020345/HBlyfiIEO?refer_flag=1001030103_" suda-data="key=tblog_search_weibo&amp;value=seqid:157892939947302792048|type:1|t:0|pos:1-0|q:airbus%20A320|ext:cate:26,mpos:1,click:wb_time" target="_blank">
#                         2019年06月30日 22:29
#                         </a>
#                                           来自 <a href="https://weibo.com/" rel="nofollow">单机游戏 · 视频社区</a> </p>
# </div>
# <!--/微博内容-->
# </div>
# <div class="card-act">
# <ul>
# <li><a action-type="login" href="javascript:void(0);" suda-data="key=tblog_search_weibo&amp;value=seqid:157892939947302792048|type:1|t:0|pos:1-0|q:airbus%20A320|ext:cate:26,mpos:1,click:fav">收藏</a></li>
# <li><a action-data="allowForward=1&amp;mid=4389009834461570&amp;name=三七V博&amp;uid=2204020345&amp;suda-data=key%3Dtblog_search_weibo%26value%3Dseqid%3A157892939947302792048%7Ctype%3A1%7Ct%3A0%7Cpos%3A1-0%7Cq%3Aairbus%2520A320%7Cext%3Acate%3A26%2Cclick:do_repost,mid:4389009834461570" action-type="login" href="javascript:void(0);" suda-data="key=tblog_search_weibo&amp;value=seqid:157892939947302792048|type:1|t:0|pos:1-0|q:airbus%20A320|ext:cate:26,mpos:1,click:repost,mid:4389009834461570"> 转发 5</a></li>
# <li><a action-data="pageid=weibo&amp;suda-data=key%3Dtblog_search_weibo%26value%3Dweibo_h_1_p_p" action-type="login" href="javascript:void(0);" suda-data="key=tblog_search_weibo&amp;value=seqid:157892939947302792048|type:1|t:0|pos:1-0|q:airbus%20A320|ext:cate:26,mpos:1,click:comment">评论 12</a></li>
# <li><a action-data="mid=4389009834461570" action-type="login" href="javascript:void(0);" suda-data="key=tblog_search_weibo&amp;value=seqid:157892939947302792048|type:1|t:0|pos:1-0|q:airbus%20A320|ext:cate:26,mpos:1,click:like,mid:4389009834461570,act:add" title="赞"><i class="icon-act icon-act-praise"></i> <em>14</em></a></li>
# </ul>
# </div>
# <div node-type="feed_list_repeat"></div>
# </div>
# </div>
# <!--/card-wrap-->
# <!--card-wrap-->
# <div action-type="feed_list_item" class="card-wrap" mid="4243010344949473">
# <div class="card-top">
# <h4 class="title"><i class="icon-title icon-star"></i><a href="/weibo?q=airbus%20A320&amp;xsort=hot&amp;Refer=hotmore" suda-data="key=tblog_search_weibo&amp;value=seqid:157892939947302792048|type:1|t:0|pos:1-0|q:airbus%20A320|ext:cate:26,click:more" target="_blank">热门</a></h4>
# </div>
# <div class="card">
# <div class="card-feed">
# <div class="avator">
# <a href="//weibo.com/1368589977?refer_flag=1001030103_" suda-data="key=tblog_search_weibo&amp;value=seqid:157892939947302792048|type:1|t:0|pos:1-0|q:airbus%20A320|ext:cate:26,mpos:2,click:user_pic" target="_blank"><img src="https://tvax1.sinaimg.cn/crop.0.0.759.759.50/51930699ly8ft640j5puqj20l30l3jrx.jpg?KID=imgbed,tva&amp;Expires=1578940199&amp;ssig=4KVomjVtm9"/></a>
# </div>
# <!--微博内容-->
# <div class="content" node-type="like">
# <div class="info">
# <div class="menu s-fr">
# <a action-type="fl_menu" href="javascript:void(0);"><i class="wbicon">c</i></a>
# <ul node-type="fl_menu_right" style="display:none;">
# <li><a href="javascript:void(0);" onclick="javascript:window.open('//service.account.weibo.com/reportspam?rid=4243010344949473&amp;type=1&amp;from=10501&amp;url=&amp;bottomnav=1&amp;wvr=6', 'newwindow', 'height=700, width=550, toolbar =yes, menubar=no, scrollbars=yes, resizable=yes, location=no, status=no');">投诉</a></li>
# </ul>
# </div>
# <div>
# <a class="name" href="//weibo.com/1368589977?refer_flag=1001030103_" nick-name="FATIII" suda-data="key=tblog_search_weibo&amp;value=seqid:157892939947302792048|type:1|t:0|pos:1-0|q:airbus%20A320|ext:cate:26,mpos:2,click:user_name" target="_blank">FATIII</a>
# <a href="//verified.weibo.com/verify" target="_blank" title="微博个人认证"><i class="icon-vip icon-vip-g"></i></a>
# <!--广告微博加关注按钮 -->
# </div>
# </div>
# <p class="txt" nick-name="FATIII" node-type="feed_list_content">
# <a href="https://s.weibo.com/weibo?q=%23FATIII%E6%B8%B8%E8%AE%B0%23" target="_blank">#F<em class="s-color-red">A</em>TIII游记#</a> 再遇B<em class="s-color-red">a</em>by <em class="s-color-red">Airbus</em>，由于每座位使用成本远高于上座更高的<em class="s-color-red">A</em>319，也不敌E190/195等机型，导致<em class="s-color-red">A</em><em class="s-color-red">320</em>家族里最小的成员，俗称B<em class="s-color-red">a</em>by <em class="s-color-red">Airbus</em>的<em class="s-color-red">A</em>318销量未如理想，很多公司都把原本<em class="s-color-red">A</em>318的订单转到<em class="s-color-red">A</em>319（包括国航西南前身的中国西南航空，当年曾经是<em class="s-color-red">A</em>318亚洲启动用户，最后把所有<em class="s-color-red">A</em>318订单转成<em class="s-color-red">A</em>319）而 ​  <a action-type="fl_unfold" href="//weibo.com/1368589977/Gi2TwkLAd?refer_flag=1001030103_" target="_blank">展开全文<i class="wbicon">c</i></a> </p>
# <p class="txt" nick-name="FATIII" node-type="feed_list_content_full" style="display: none">
# <a href="https://s.weibo.com/weibo?q=%23FATIII%E6%B8%B8%E8%AE%B0%23" target="_blank">#F<em class="s-color-red">A</em>TIII游记#</a> 再遇Baby Airbus，由于每座位使用成本远高于上座更高的A319，也不敌E190/195等机型，导致A320家族里最小的成员，俗称Baby Airbus的A318销量未如理想，很多公司都把原本A318的订单转到A319（包括国航西南前身的中国西南航空，当年曾经是A318亚洲启动用户，最后把所有A318订单转成A319）而像边疆航空，墨西哥航空等虽然接收了A318，但短短数年就已经封存甚至拆解。近年为数不多的使用A318的航空公司包括法航，罗马尼亚航，英航（仅有两架用于LCY-JFK全商务舱服务）以及购入二手的哥伦比亚航空。上两天从卡塔赫纳前往波哥大，就有缘碰上了A318。一眼就望到头的客舱短小可爱。哥伦比亚航空是星空联盟成员，但常年被评为三星公司，可是他们很多软硬件都远超我们的四星甚至五星航空。首先所有窄体客机都有Wi-Fi串流提供娱乐服务或是全舱ptv。另外休息室布局非常的好，诸如CTG这等小机场的国内休息室都吊打三大航大多数的自营休息室。 <a action-type="fl_fold" href="javascript:void(0);">收起全文<i class="wbicon">d</i></a>
# </p>
# <!--card解析-->
# <div node-type="feed_list_media_prev">
action-type="login" href="javascript:void(0);" suda-data="key=tblog_search_weibo&amp;value=seqid:157892939947302792048|type:1|t:0|pos:1-0|q:airbus%20A320|ext:cate:26,mpos:2,click:like,mid:4243010344949473,act:add" title="赞"><i class="icon-act icon-act-praise"></i> <em>102</em></a></li>
# </ul>
# </div>
# <div node-type="feed_list_repeat"></div>
# </div>
# </div>
# <!--/card-wrap-->
# <!--card-wrap-->
# <div action-type="feed_list_item" class="card-wrap" mid="4204573465691134">
# <div class="card-top">
# <a class="more s-fr" href="/weibo?q=airbus%20A320&amp;xsort=hot&amp;Refer=hotmore" suda-data="key=tblog_search_weibo&amp;value=seqid:157892939947302792048|type:1|t:0|pos:1-0|q:airbus%20A320|ext:cate:26,click:more" target="_blank">更多 <i class="wbicon">a</i></a>
# <h4 class="title"><i class="icon-title icon-star"></i><a href="/weibo?q=airbus%20A320&amp;xsort=hot&amp;Refer=hotmore" suda-data="key=tblog_search_weibo&amp;value=seqid:157892939947302792048|type:1|t:0|pos:1-0|q:airbus%20A320|ext:cate:26,click:more" target="_blank">热门</a></h4>
# </div>
# <div class="card">
# <div class="card-feed">
# <div class="avator">
# <a href="//weibo.com/1393477857?refer_flag=1001030103_" suda-data="key=tblog_search_weibo&amp;value=seqid:157892939947302792048|type:1|t:0|pos:1-0|q:airbus%20A320|ext:cate:26,mpos:3,click:user_pic" target="_blank"><img src="https://tva3.sinaimg.cn/crop.0.0.180.180.50/530ec8e1jw1e8qgp5bmzyj2050050aa8.jpg?KID=imgbed,tva&amp;Expires=1578940199&amp;ssig=Rhi4aNXPCE"/></a>
# </div>
# <!--微博内容-->
# <div class="content" node-type="like">
# <div class="info">
# <div class="menu s-fr">
# <a action-type="fl_menu" href="javascript:void(0);"><i class="wbicon">c</i></a>
# <ul node-type="fl_menu_right" style="display:none;">
# <li><a href="javascript:void(0);" onclick="javascript:window.open('//service.account.weibo.com/reportspam?rid=4204573465691134&amp;type=1&amp;from=10501&amp;url=&amp;bottomnav=1&amp;wvr=6', 'newwindow', 'height=700, width=550, toolbar =yes, menubar=no, scrollbars=yes, resizable=yes, location=no, status=no');">投诉</a></li>
# </ul>
# </div>
# <div>
# <a class="name" href="//weibo.com/1393477857?refer_flag=1001030103_" nick-name="中性灰" suda-data="key=tblog_search_weibo&amp;value=seqid:157892939947302792048|type:1|t:0|pos:1-0|q:airbus%20A320|ext:cate:26,mpos:3,click:user_name" target="_blank">中性灰</a>
# <a href="//verified.weibo.com/verify" target="_blank" title="微博个人认证"><i class="icon-vip icon-vip-y"></i></a>
# <!--广告微博加关注按钮 -->
# </div>
# </div>
# <p class="txt" nick-name="中性灰" node-type="feed_list_content">
#                     终于，感觉完美<img alt="[喵喵]" class="face" src="//img.t.sinajs.cn/t4/appstyle/expression/ext/normal/7b/2018new_miaomiao_org.png" title="[喵喵]"><a href="//weibo.com/n/%E8%88%AA%E7%A9%BA%E7%89%A9%E8%AF%AD" target="_blank">@航空物语</a><br/>第一架，南航CZ359，<em class="s-color-red">A</em><em class="s-color-red">320</em>；<br/>第二架，国航C<em class="s-color-red">A</em>1725，<em class="s-color-red">A</em>321；<br/>第三架，南航CZ3616，<em class="s-color-red">A</em>330。<br/>由于全部是<em class="s-color-red">AirBus</em>的飞机，还要<a href="//weibo.com/n/%E7%A9%BA%E4%B8%AD%E5%AE%A2%E8%BD%A6" target="_blank">@空中客车</a> <img alt="[嘻嘻]" class="face" src="//img.t.sinajs.cn/t4/appstyle/expression/ext/normal/33/2018new_xixi_org.png" title="[嘻嘻]"><br/>C<em class="s-color-red">a</em>non EF500mm f/4L + EF2xII + TECH<em class="s-color-red">A</em>RT TCS-04 + <em class="s-color-red">a</em>9 ​                </img></img></p>
# <!--card解析-->
# <div node-type="feed_list_media_prev">
# <div action-data="uid=1393477857&amp;mid=4204573465691134&amp;pic_ids=530ec8e1gy1fo75iu1l7hj20zk0p03zu,530ec8e1gy1fo75iv6f5ij20zk0p0jss,530ec8e1gy1fo75ix70f1j20zk0p00u4,530ec8e1gy1fo75j1k0daj20zk0p0gmt,530ec8e1gy1fo75j3dy3lj20zk0p075l,530ec8e1gy1fo75j5489aj20zk0p0dh3,530ec8e1gy1fo75j7ho47j20zk0p0dhe,530ec8e1gy1fo75j936cmj20zk0p0myk,530ec8e1gy1fo75jb5tp6j20zk0p0t9v" class="media media-piclist" node-type="fl_pic_list">
refer_flag=1001030103_" suda-data="key=tblog_search_weibo&amp;value=seqid:157892939947302792048|type:1|t:0|pos:1-0|q:airbus%20A320|ext:cate:31,mpos:1,click:user_pic" target="_blank"><img src="https://tva1.sinaimg.cn/crop.0.0.180.180.50/537d2370jw1e8qgp5bmzyj2050050aa8.jpg?KID=imgbed,tva&amp;Expires=1578940199&amp;ssig=yoOLy3iRjF"/></a>
# </div>
# <!--微博内容-->
# <div class="content" node-type="like">
# <div class="info">
# <div class="menu s-fr">
# <a action-type="fl_menu" href="javascript:void(0);"><i class="wbicon">c</i></a>
# <ul node-type="fl_menu_right" style="display:none;">
# <li><a href="javascript:void(0);" onclick="javascript:window.open('//service.account.weibo.com/reportspam?rid=4454473915486816&amp;type=1&amp;from=10501&amp;url=&amp;bottomnav=1&amp;wvr=6', 'newwindow', 'height=700, width=550, toolbar =yes, menubar=no, scrollbars=yes, resizable=yes, location=no, status=no');">投诉</a></li>
# </ul>
# </div>
# <div>
# <a class="name" href="//weibo.com/1400710000?refer_flag=1001030103_" nick-name="Wingsworld_飞机模型" suda-data="key=tblog_search_weibo&amp;value=seqid:157892939947302792048|type:1|t:0|pos:1-0|q:airbus%20A320|ext:cate:31,mpos:1,click:user_name" target="_blank">Wingsworld_飞机模型</a>
# <a href="//vip.weibo.com" target="_blank" title="微博会员"><i class="icon-vip icon-member"></i></a>
# <!--广告微博加关注按钮 -->
# </div>
# </div>
# <p class="txt" nick-name="Wingsworld_飞机模型" node-type="feed_list_content">
#                     [广告]Phoenix 1:400 PH10923 M<em class="s-color-red">a</em>ldivi<em class="s-color-red">a</em>n 马尔代夫航空 <em class="s-color-red">Airbus</em> <em class="s-color-red">A</em><em class="s-color-red">320</em> 8Q-I<em class="s-color-red">A</em>N 购买地址: <a href="http://t.cn/AiFVttbN" target="_blank"><i class="wbicon">O</i>网页链接</a> ​                </p>
# <!--card解析-->
# <div node-type="feed_list_media_prev">
# <div action-data="uid=1400710000&amp;mid=4454473915486816&amp;pic_ids=537d2370gy1gaca68iy6sj212w0cvn8t,537d2370gy1gaca6950nhj212w0h149f,537d2370gy1gaca691z54j212w0ih49g,537d2370gy1gaca69ejspj212w0d67ed" class="media media-piclist" node-type="fl_pic_list">
# <ul class="m4">
# <li><img action-data="uid=1400710000&amp;pic_id=537d2370gy1gaca68iy6sj212w0cvn8t" action-type="fl_pics" src="//ww3.sinaimg.cn/thumb150/537d2370gy1gaca68iy6sj212w0cvn8t.jpg" suda-data="key=tblog_search_weibo&amp;value=weibo_ss_1_pic"/></li>
# <li><img action-data="uid=1400710000&amp;pic_id=537d2370gy1gaca6950nhj212w0h149f" action-type="fl_pics" src="//ww3.sinaimg.cn/orj360/537d2370gy1gaca6950nhj212w0h149f.jpg" style="position: relative;width: 251px;height: 110px;top: -0px;left: -52px;" suda-data="key=tblog_search_weibo&amp;value=weibo_ss_1_pic"/></li>
# <li><img action-data="uid=1400710000&amp;pic_id=537d2370gy1gaca691z54j212w0ih49g" action-type="fl_pics" src="//ww1.sinaimg.cn/orj360/537d2370gy1gaca691z54j212w0ih49g.jpg" style="position: relative;width: 231px;height: 110px;top: -0px;left: -24.5px;" suda-data="key=tblog_search_weibo&amp;value=weibo_ss_1_pic"/></li>
# <li><img action-data="uid=1400710000&amp;pic_id=537d2370gy1gaca69ejspj212w0d67ed" action-type="fl_pics" src="//ww1.sinaimg.cn/orj360/537d2370gy1gaca69ejspj212w0d67ed.jpg" style="position: relative;width: 324px;height: 110px;top: -0px;left: -44px;" suda-data="key=tblog_search_weibo&amp;value=weibo_ss_1_pic"/></li>
# </ul>
# </div>
# </div>
# <div node-type="feed_list_media_disp">
# </div>
# <!--/card解析-->
# <p class="from">
# <a href="//weibo.com/1400710000/ImR79n1n2?refer_flag=1001030103_" suda-data="key=tblog_search_weibo&amp;value=seqid:157892939947302792048|type:1|t:0|pos:1-0|q:airbus%20A320|ext:cate:31,mpos:1,click:wb_time" target="_blank">
#                         2019年12月28日 14:00
#                         </a>
#                                           来自 <a href="//app.weibo.com/t/feed/6vtZb0" rel="nofollow">微博 weibo.com</a> </p>
# </div>
# <!--/微博内容-->
# </div>
# <div class="card-act">
# <ul>
# <li><a action-type="login" href="javascript:void(0);" suda-data="key=tblog_search_weibo&amp;value=seqid:157892939947302792048|type:1|t:0|pos:1-0|q:airbus%20A320|ext:cate:31,mpos:1,click:fav">收藏</a></li>
# <li><a action-data="allowForward=1&amp;mid=4454473915486816&amp;name=Wingsworld_飞机模型&amp;uid=1400710000&amp;suda-data=key%3Dtblog_search_weibo%26value%3Dseqid%3A157892939947302792048%7Ctype%3A1%7Ct%3A0%7Cpos%3A1-0%7Cq%3Aairbus%2520A320%7Cext%3Acate%3A31%2Cclick:do_repost,mid:4454473915486816" action-type="login" href="javascript:void(0);" suda-data="key=tblog_search_weibo&amp;value=seqid:157892939947302792048|type:1|t:0|pos:1-0|q:airbus%20A320|ext:cate:31,mpos:1,click:repost,mid:4454473915486816"> 转发 </a></li>
# <li><a action-data="pageid=weibo&amp;suda-data=key%3Dtblog_search_weibo%26value%3Dweibo_h_1_p_p" action-type="login" href="javascript:void(0);" suda-data="key=tblog_search_weibo&amp;value=seqid:157892939947302792048|type:1|t:0|pos:1-0|q:airbus%20A320|ext:cate:31,mpos:1,click:comment">评论 </a></li>
# <li><a action-data="mid=4454473915486816" action-type="login" href="javascript:void(0);" suda-data="key=tblog_search_weibo&amp;value=seqid:157892939947302792048|type:1|t:0|pos:1-0|q:airbus%20A320|ext:cate:31,mpos:1,click:like,mid:4454473915486816,act:add" title="赞"><i class="icon-act icon-act-praise"></i> <em>1</em></a></li>
# </ul>
# </div>
# <div node-type="feed_list_repeat"></div>
# </div>
# </div>
# <!--/card-wrap-->
# <!--card-wrap-->
# <div action-type="feed_list_item" class="card-wrap" mid="4440280050508467">
# <div class="card">
# <div class="card-feed">
# <div class="avator">
# <a href="//weibo.com/1657547683?refer_flag=1001030103_" suda-data="key=tblog_search_weibo&amp;value=seqid:157892939947302792048|type:1|t:0|pos:1-0|q:airbus%20A320|ext:cate:31,mpos:2,click:user_pic" target="_blank"><img src="https://tvax2.sinaimg.cn/crop.0.0.996.996.50/62cc2ba3ly8g77iglou6hj20ro0roq5w.jpg?KID=imgbed,tva&amp;Expires=1578940199&amp;ssig=y3%2Bpy2dfYo"/></a>
# </div>
# <!--微博内容-->
# <div class="content" node-type="like">
# <div class="info">
# <div class="menu s-fr">
# <a action-type="fl_menu" href="javascript:void(0);"><i class="wbicon">c</i></a>
# <ul node-type="fl_menu_right" style="display:none;">
# <li><a href="javascript:void(0);" onclick="javascript:window.open('//service.account.weibo.com/reportspam?rid=4440280050508467&amp;type=1&amp;from=10501&amp;url=&amp;bottomnav=1&amp;wvr=6', 'newwindow', 'height=700, width=550, toolbar =yes, menubar=no, scrollbars=yes, resizable=yes, location=no, status=no');">投诉</a></li>
# </ul>
# </div>
# <div>
# <a class="name" href="//weibo.com/1657547683?refer_flag=1001030103_" nick-name="开飞机的LuSam-WUH" suda-data="key=tblog_search_weibo&amp;value=seqid:157892939947302792048|type:1|t:0|pos:1-0|q:airbus%20A320|ext:cate:31,mpos:2,click:user_name" target="_blank">开飞机的LuSam-WUH</a>
# <a href="//verified.weibo.com/verify" target="_blank" title="微博个人认证"><i class="icon-vip icon-vip-y"></i></a>
# <!--广告微博加关注按钮 -->
# </div>
# </div>
# <p class="txt" nick-name="开飞机的LuSam-WUH" node-type="feed_list_content">
#                     SDHRTHPY 发给我CGO廊桥机位的川航<em class="s-color-red">AIRBUS</em> <em class="s-color-red">A</em><em class="s-color-red">320</em>，滑行的天津航空<em class="s-color-red">AIRBUS</em> <em class="s-color-red">A</em><em class="s-color-red">320</em>-232 ✈️<img alt="[耶]" class="face" src="//img.t.sinajs.cn/t4/appstyle/expression/ext/normal/29/2018new_ye_org.png" title="[耶]"><img alt="[太开心]" class="face" src="//img.t.sinajs.cn/t4/appstyle/expression/ext/normal/1e/2018new_taikaixin_org.png" title="[太开心]"><img alt="[鼓掌]" class="face" src="//img.t.sinajs.cn/t4/appstyle/expression/ext/normal/6e/2018new_guzhang_org.png" title="[鼓掌]"><img alt="[嘻嘻]" class="face" src="//img.t.sinajs.cn/t4/appstyle/expression/ext/normal/33/2018new_xixi_org.png" title="[嘻嘻]"> <a href="https://s.weibo.com/weibo?q=%23%E8%88%AA%E7%A9%BA%E6%91%84%E5%BD%B1%23" target="_blank">#航空摄影#</a> ​  ​ <a href="http://t.cn/Aid2h0l3" target="_blank"><i class="wbicon">L</i>开飞机的LuS<em class="s-color-red">a</em>m-WUH的微博视频</a> ​                </img></img></img></img></p>
# <!--card解析-->
# <!--linkcard 不能播放视频-->
# <div class="media media-video-a" node-type="feed_list_media_prev">
# <!--linkcard 不能播放视频-->
# <div class="media media-video-a" node-type="feed_list_media_disp" style="display:none;"></div>
# <!--视频card-->
# <div class="thumbnail" style="height:auto;min-height:281px;">
# <a action-data="type=feedvideo&amp;objectid=1034:4440280007702330&amp;keys=4440280022385212&amp;cover_img=%2F%2Fwx4.sinaimg.cn%2Forj480%2F62cc2ba3gy1g93486uc6vj20f00qojt8.jpg&amp;card_height=960&amp;card_width=540&amp;play_count=722&amp;short_url=http%3A%2F%2Ft.cn%2FAid2h0l3&amp;encode_mode=&amp;bitrate=277&amp;biz_id=230444¤t_mid=4440280050508467&amp;key=tblog_card&amp;title=%E5%BC%80%E9%A3%9E%E6%9C%BA%E7%9A%84LuSam-WUH%E7%9A%84%E5%BE%AE%E5%8D%9A%E8%A7%86%E9%A2%91&amp;full_url=https%3A%2F%2Fvideo.weibo.com%2Fshow%3Ffid%3D1034%3A4440280007702330&amp;object_id=1034:4440280007702330&amp;video_src=%2F%2Ff.video.weibocdn.com%2F00326dVRlx07yHCO7RfG010412001taT0E010.mp4%3Flabel%3Dmp4_ld%26template%3D360x640.24.0%26trans_finger%3D81b11b8c5ffb62d33ceb3244bdd17e7b%26Expires%3D1578932999%26ssig%3DVvS%252FMbSh3%252B%26KID%3Dunistore%2Cvideo" action-type="feed_list_third_rend" class="WB_video_h5" href="javascript:void(0);" mediasize="852:480" node-type="fl_h5_video">
# <div node-type="fl_h5_video_pre">
# <img alt="" src="//wx4.sinaimg.cn/orj480/62cc2ba3gy1g93486uc6vj20f00qojt8.jpg" style="display:block;height: 281px;"/>
# <i class="icon-media icon-play-b"></i>
# </div>
# <div node-type="fl_h5_video_disp" style="display:none;">
# </div>
# </a>
# </div>
# <!--/视频card-->
# </div>
# <!--/card解析-->
# <p class="from">
# <a href="//weibo.com/1657547683/IgTRP28h5?refer_flag=1001030103_" suda-data="key=tblog_search_weibo&amp;value=seqid:157892939947302792048|type:1|t:0|pos:1-0|q:airbus%20A320|ext:cate:31,mpos:2,click:wb_time" target="_blank">
#                         2019年11月19日 09:58
#                         </a>
#                                           来自 <a href="//app.weibo.com/t/feed/1TqjXH" rel="nofollow">HUAWEI P30 Pro</a> </p>
# </div>
# <!--/微博内容-->
# </div>
# <div class="card-act">
# <ul>
# <li><a action-type="login" href="javascript:void(0);" suda-data="key=tblog_search_weibo&amp;value=seqid:157892939947302792048|type:1|t:0|pos:1-0|q:airbus%20A320|ext:cate:31,mpos:2,click:fav">收藏</a></li>
# <li><a action-data="allowForward=1&amp;mid=4440280050508467&amp;name=开飞机的LuSam-WUH&amp;uid=1657547683&amp;suda-data=key%3Dtblog_search_weibo%26value%3Dseqid%3A157892939947302792048%7Ctype%3A1%7Ct%3A0%7Cpos%3A1-0%7Cq%3Aairbus%2520A320%7Cext%3Acate%3A31%2Cclick:do_repost,mid:4440280050508467" action-type="login" href="javascript:void(0);" suda-data="key=tblog_search_weibo&amp;value=seqid:157892939947302792048|type:1|t:0|pos:1-0|q:airbus%20A320|ext:cate:31,mpos:2,click:repost,mid:4440280050508467"> 转发 </a></li>
# <li><a action-data="pageid=weibo&amp;suda-data=key%3Dtblog_search_weibo%26value%3Dweibo_h_1_p_p" action-type="login" href="javascript:void(0);" suda-data="key=tblog_search_weibo&amp;value=seqid:157892939947302792048|type:1|t:0|pos:1-0|q:airbus%20A320|ext:cate:31,mpos:2,click:comment">评论 </a></li>
# <li><a action-data="mid=4440280050508467" action-type="login" href="javascript:void(0);" suda-data="key=tblog_search_weibo&amp;value=seqid:157892939947302792048|type:1|t:0|pos:1-0|q:airbus%20A320|ext:cate:31,mpos:2,click:like,mid:4440280050508467,act:add" title="赞"><i class="icon-act icon-act-praise"></i> <em>2</em></a></li>
# </ul>
# </div>
# <div node-type="feed_list_repeat"></div>
# </div>
# </div>
# <!--/card-wrap-->
# <!--card-wrap-->
# <div action-type="feed_list_item" class="card-wrap" mid="4427781120838027">
# <div class="card">
# <div class="card-feed">
# <div class="avator">
# <a href="//weibo.com/1206518415?refer_flag=1001030103_" suda-data="key=tblog_search_weibo&amp;value=seqid:157892939947302792048|type:1|t:0|pos:1-0|q:airbus%20A320|ext:cate:31,mpos:3,click:user_pic" target="_blank"><img src="https://tvax4.sinaimg.cn/crop.0.0.1080.1080.50/47ea028fly8g14u0x652ij20u00u076g.jpg?KID=imgbed,tva&amp;Expires=1578940199&amp;ssig=1Stz352vWd"/></a>
# </div>
# <!--微博内容-->
# <div class="content" node-type="like">
# <div class="info">
# <div class="menu s-fr">
# <a action-type="fl_menu" href="javascript:void(0);"><i class="wbicon">c</i></a>
# <ul node-type="fl_menu_right" style="display:none;">
# <li><a href="javascript:void(0);" onclick="javascript:window.open('//service.account.weibo.com/reportspam?rid=4427781120838027&amp;type=1&amp;from=10501&amp;url=&amp;bottomnav=1&amp;wvr=6', 'newwindow', 'height=700, width=550, toolbar =yes, menubar=no, scrollbars=yes, resizable=yes, location=no, status=no');">投诉</a></li>
# </ul>
# </div>
# <div>
# <a class="name" href="//weibo.com/1206518415?refer_flag=1001030103_" nick-name="Haiwe" suda-data="key=tblog_search_weibo&amp;value=seqid:157892939947302792048|type:1|t:0|pos:1-0|q:airbus%20A320|ext:cate:31,mpos:3,click:user_name" target="_blank">Haiwe</a>
# <a href="//club.weibo.com/intro" target="_blank" title="微博达人"><i class="icon-vip icon-daren"></i></a>
# <!--广告微博加关注按钮 -->
# </div>
# </div>
# <p class="txt" nick-name="Haiwe" node-type="feed_list_content">
#                     第一个<em class="s-color-red">Airbus</em> <em class="s-color-red">A</em><em class="s-color-red">320</em>模型<img alt="[二哈]" class="face" src="//img.t.sinajs.cn/t4/appstyle/expression/ext/normal/22/2018new_erha_org.png" title="[二哈]"> <a href="http://t.cn/ELT0hke" target="_blank"><i class="wbicon">2</i>北京</a> ​                </img></p>
# <!--card解析-->
# <div node-type="feed_list_media_prev">
# <div action-data="uid=1206518415&amp;mid=4427781120838027&amp;pic_ids=47ea028fly1g7z8p1g4jij23402c0qv5" class="media media-piclist" node-type="fl_pic_list">
# <ul class="m1">
# <li><img action-data="uid=1206518415&amp;pic_id=47ea028fly1g7z8p1g4jij23402c0qv5" action-type="fl_pics" src="//ww4.sinaimg.cn/orj360/47ea028fly1g7z8p1g4jij23402c0qv5.jpg" style="width: 167px;height: 167px;" suda-data="key=tblog_search_weibo&amp;value=weibo_ss_1_pic"/></li>
# </ul>
# </div>
# </div>
# <div node-type="feed_list_media_disp">
# </div>
# <!--/card解析-->
# <p class="from">
# <a href="//weibo.com/1206518415/IbEIg3w0z?refer_flag=1001030103_" suda-data="key=tblog_search_weibo&amp;value=seqid:157892939947302792048|type:1|t:0|pos:1-0|q:airbus%20A320|ext:cate:31,mpos:3,click:wb_time" target="_blank">
#                         2019年10月15日 22:12
#                         </a>
#                                           来自 <a href="//weibo.com/" rel="nofollow">iPhone客户端</a> </p>
# </div>
# <!--/微博内容-->
# </div>
# <div class="card-act">
# <ul>
# <li><a action-type="login" href="javascript:void(0);" suda-data="key=tblog_search_weibo&amp;value=seqid:157892939947302792048|type:1|t:0|pos:1-0|q:airbus%20A320|ext:cate:31,mpos:3,click:fav">收藏</a></li>
# <li><a action-data="allowForward=1&amp;mid=4427781120838027&amp;name=Haiwe&amp;uid=1206518415&amp;suda-data=key%3Dtblog_search_weibo%26value%3Dseqid%3A157892939947302792048%7Ctype%3A1%7Ct%3A0%7Cpos%3A1-0%7Cq%3Aairbus%2520A320%7Cext%3Acate%3A31%2Cclick:do_repost,mid:4427781120838027" action-type="login" href="javascript:void(0);" suda-data="key=tblog_search_weibo&amp;value=seqid:157892939947302792048|type:1|t:0|pos:1-0|q:airbus%20A320|ext:cate:31,mpos:3,click:repost,mid:4427781120838027"> 转发 </a></li>
# <li><a action-data="pageid=weibo&amp;suda-data=key%3Dtblog_search_weibo%26value%3Dweibo_h_1_p_p" action-type="login" href="javascript:void(0);" suda-data="key=tblog_search_weibo&amp;value=seqid:157892939947302792048|type:1|t:0|pos:1-0|q:airbus%20A320|ext:cate:31,mpos:3,click:comment">评论 1</a></li>
# <li><a action-data="mid=4427781120838027" action-type="login" href="javascript:void(0);" suda-data="key=tblog_search_weibo&amp;value=seqid:157892939947302792048|type:1|t:0|pos:1-0|q:airbus%20A320|ext:cate:31,mpos:3,click:like,mid:4427781120838027,act:add" title="赞"><i class="icon-act icon-act-praise"></i> <em></em></a></li>
# </ul>
# </div>
# <div node-type="feed_list_repeat"></div>
# </div>
# </div>
# <!--/card-wrap-->
# <!--card-wrap-->
# <div action-type="feed_list_item" class="card-wrap" mid="4427009297746822">
# <div class="card">
# <div class="card-feed">
# <div class="avator">
# <a href="//weibo.com/1835092135?refer_flag=1001030103_" suda-data="key=tblog_search_weibo&amp;value=seqid:157892939947302792048|type:1|t:0|pos:1-0|q:airbus%20A320|ext:cate:31,mpos
href="javascript:void(0);" suda-data="key=tblog_search_weibo&amp;value=seqid:157892939947302792048|type:1|t:0|pos:1-0|q:airbus%20A320|ext:cate:31,mpos:17,click:like,mid:4377355763967241,act:add" title="赞"><i class="icon-act icon-act-praise"></i> <em>39</em></a></li>
# </ul>
# </div>
# <div node-type="feed_list_repeat"></div>
# </div>
# </div>
# <!--/card-wrap-->
# <!--/微博card-->
# </div>
# <!--/cate流-->
# <!--未登录提示-->
# <div class="m-hint"><i class="icon-warn icon-hint-s"></i><a action-type="login" href="javascript:void(0);">立即登录</a>查看更多结果。还没有账号？赶紧<a href="//weibo.com/signup/signup.php?lang=zh-cn&amp;entry=weisousuo" target="_blank">注册微博</a></div>
# <!--未登录提示-->
# </div>
# <div class="m-con-r">
# <!--话题右侧流加载-->
# <!--相关兴趣主页-->
# <div class="card-wrap">
# <div class="card card-interest">
# <div class="card-head">
# <a class="more s-fr" href="/related?q=airbus%20A320" target="_blank">更多 <i class="wbicon">a</i></a>
# <h4 class="title">相关兴趣主页</h4>
# </div>
# <div class="card-content s-pg16">
# <!--应用-->
# <div class="item item-app">
# <div class="pic"><a href="http://weibo.com/p/1004041672408" target="_blank"><img alt="Airbus A320 Checklist 1.0" src="//timg.sjs.sinajs.cn/miniblog2style/images/developer/default_50.gif" title="Airbus A320 Checklist 1.0"/></a></div>
# <div class="info">
# <h2><i class="icon-interest icon-app"></i><a href="http://weibo.com/p/1004041672408" target="_blank" title="Airbus A320 Checklist 1.0">Airbus A320 Checklist 1.0</a></h2>
# <p>Checklist application for JAR Design's Airbus A320 for X-Plane (http://airbus320neo.com)This app helps you to follow the standard checklist procedures in A320 cockpit.*** DO NOT USE THIS APP FOR REAL-WORLD FLYING! ***How to use:Tap on each item to mark as completed. You can change between checklists with swiping or the "Previous" and "Next" buttons.All feedback are welcome :)</p>
# <span>0人赞</span>
# </div>
# </div>
# <!--/应用-->
# </div>
# </div>
# </div>
# <!--相关兴趣主页
# <!--热搜榜-->
# <div class="card-wrap" id="pl_band_index">
# <div class="card card-hotrank">
# <div class="card-head">
# <a class="more s-fr" href="/top/summary?cate=realtimehot" target="_blank">更多 <i class="wbicon">a</i></a>
# <h4 class="title">热搜榜</h4>
# </div>
# <div class="card-content s-pg16">
# <ul>
# <li>
# <i class="num icon-top"></i>
# <p>
# <a href="/weibo?q=%2387%E5%B2%81%E8%80%81%E9%99%A2%E9%95%BF%E7%AC%91%E7%9D%80%E7%BB%93%E6%9D%9F%E6%9C%80%E5%90%8E%E4%B8%80%E6%AC%A1%E9%97%A8%E8%AF%8A%23&amp;Refer=new_time&amp;Refer=newtime">87岁老院长笑着结束最后一次门诊</a>
# <i class="icon-txt icon-txt-hot">热</i>
# </p>
# </li>
# <li>
# <span class="num top">1</span>
# <p>
# <span class="val">384万</span>
# <a href="/weibo?q=%23%E9%82%B1%E6%B3%BD%E5%BC%A0%E9%92%A7%E7%94%AF%E5%90%8C%E6%A1%86%23&amp;Refer=top">邱泽张钧甯同框</a>
# <i class="icon-txt icon-txt-new">新</i>
# </p>
# </li>
# <li>
# <span class="num top">2</span>
# <p>
# <span class="val">300万</span>
# <a href="/weibo?q=%23%E8%80%83%E6%8B%89%E6%88%96%E5%B0%86%E8%A2%AB%E5%88%97%E4%B8%BA%E6%BF%92%E5%8D%B1%E7%89%A9%E7%A7%8D%23&amp;Refer=top">考拉或将被列为濒危物种</a>

# </li>
# </ul>
# </div>
# </div>
# </div>
# <!--热搜榜-->
# <!--广告-->
# <div class="card-wrap">
# <div class="card card-film">
# <div class="card-head">
# <h4 class="title">广告</h4>
# </div>
# <div class="card-content">
# <iframe border="0" frameborder="0" marginheight="0" marginwidth="0" scrolling="no" src="//j.s.weibo.com/widget.html?t=157892940013392564" style="width:300px; height:250px;"></iframe>
# </div>
# </div>
# </div>
# <!--/广告-->
# <!--搜索历史-->
# <div class="card-wrap">
# <div class="card card-history" id="pl_history_index">
# </div>
# </div>
# <!--/搜索历史-->
# </div>
# </div>
# <!--/内容-->
# </div>
# <script>
#         //连续的微博单独处理个微博之间的间隙问题
#         var sCates = document.querySelectorAll('.wrap-continuous');
#         if(sCates.length){
#             sCates[sCates.length-1].style.marginBottom = '10px';
#             sCates[0].style.borderBottom = '1px solid #eee';
#         }
#     </script>
# <script charset="UTF-8" src="//js.t.sinajs.cn/t4/apps/searchpc/js/pc/js/conf/base.js?version=20200106153100" type="text/javascript"></script>
# <script charset="UTF-8" src="//js.t.sinajs.cn/t4/apps/searchpc/js/pc/js/conf/common.js?version=20200106153100" type="text/javascript"></script>
# <script charset="UTF-8" src="//js.t.sinajs.cn/t4/apps/searchpc/js/pc/js/conf/feed.js?version=20200106153100" type="text/javascript"></script>
# <script charset="UTF-8" src="//js.t.sinajs.cn/t4/apps/searchpc/js/pc/js/conf/weiboFeedList.js?version=20200106153100" type="text/javascript"></script>
# </div>
# <!--脚部-->
# <div class="m-footer">
# <div class="bottom">
# <div class="m-outlink">
# <div class="link">
# <a class="icon-wb" href="http://ir.weibo.com/phoenix.zhtml?c=253076&amp;p=irol-irhome" target="_blank" title="关于微博">关于微博</a>
# <a href="http://help.weibo.com/?refer=didao&amp;bottomnav=1&amp;wvr=5" target="_blank" title="微博帮助">微博帮助</a>
# <a href="http://help.weibo.com/newtopic/suggest?bottomnav=1&amp;wvr=5" target="_blank" title="意见反馈">意见反馈</a>
# <a href="http://open.weibo.com/?bottomnav=1&amp;wvr=5" target="_blank" title="开放平台">开放平台</a>
# <a href="http://hr.weibo.com/?bottomnav=1&amp;wvr=5" target="_blank" title="微博招聘">微博招聘</a>
# <a href="http://news.sina.com.cn/guide/?bottomnav=1&amp;wvr=5" target="_blank" title="新浪网导航">新浪网导航</a>
# <a href="http://service.account.weibo.com/?bottomnav=1&amp;wvr=5&amp;is_redirected=1" target="_blank" title="社区管理中心">社区管理中心</a>
# <a href="http://service.account.weibo.com/roles/gongyue?bottomnav=1&amp;wvr=5&amp;is_redirected=1" target="_blank" title="微博社区公约">微博社区公约</a>
# </div>
# <p class="copyright">
#                 Copyright © 2009-2020 WEIBO 北京微梦创科网络技术有限公司
#                 <a href="https://weibo.com/aj/static/jww.html" target="_blank">京网文[2011]0398-130号</a>
# <a href="http://www.miibeian.gov.cn" target="_blank">京ICP备12002058号</a>
# <!-- <select id="pl_language_language">
#                     <option value="zh-cn" selected="selected">中文(简体)</option>
#                     <option value="zh-tw">中文(繁体)</option>
#                 </select> -->
# </p></div></div></div></body></html>
#
#
#
# <!-- <script src="https://js.t.sinajs.cn/t5/pack/static/musicplayer/musicplayer_stk_v6.1.5.js"></script> -->
# <script>
#     // //设置用户uid 用于同步赞状态
#     // WEIBO_MUSIC_PLAYER.load({page_id:''});
#     // //监听赞事件
#     // //监听分享事件
#     // WEIBO_MUSIC_PLAYER.on('share', function (evt, song) {
#     //     alert(song.copy);
#     //     song //歌曲的所有信息
#     // });
#     </script>
#
# <!--脚部-->
# <!--回到顶部-->
# <div id="pl_common_scrollToTop">
# <div class="m-gotop" node-type="scrollToTop" style="display: none;">
# <a class="wbicon" href="javascript:void(0);">Ú</a>
# </div>
# </div>
# <!--/回到顶部-->
# <script src="//js.t.sinajs.cn/t6/home/js/pl/top/topInit.js"></script>
# <script type="text/javascript">
#     (function() {
#         WBtopGlobal && WBtopGlobal.init({
#             'islogin':0,
#             "backurl":"//s.weibo.com"
#         });
#     })();
# </script>
# <script async="" charset="utf-8" src="//js.t.sinajs.cn/open/analytics/js/suda.js?version=2018080418263900" type="text/javascript"></script>
# <!-- SUDA_CODE_START -->
# <noscript><img alt="" border="0" height="0" src="//beacon.sina.com.cn/a.gif?noScript" width="0"/></noscript>
# <!-- SUDA_CODE_END -->
#
# <!-- video -->
# <!-- <script src="//js.t.sinajs.cn/t6/page/js/pl/third/search/index.js?version=2018073117" type="text/javascript"></script> -->

# %%
compteur = 0 
for span in soup.findAll('p',attrs={'node-type':'feed_list_content'}):
    a = (span.text.strip())
    compteur  +=1
print(compteur)
print(a)
# Out:
# 21
# #不止飞行##航空那些事儿#中国航空摄影 Airbus 50th🎂@空中客车 生日快乐！1～9 A300 A310 A319 A320 A321 A330 A340 A350 A380@微博航空 @FATIII @谈粽色变 @前站起飞 @阿神Ming @一直在追飞机的8252 @黑堡种玉米 @DS_T黑黑T @最炫飞天侠 @飞天小妞marica ​

# %% [markdown]
# # Traduction

# %%
import gettext
gettext.bindtextdomain('myapplication', 'C:/Users/user/Desktop/Git/Groupe1_CollecteDeDonnées/ProjetInterpromo2020')
# Out:
# 'C:/Users/user/Desktop/Git/Groupe1_CollecteDeDonnées/ProjetInterpromo2020'

# %%
from langdetect import detect

source_language = detect('bonjour, je suis Vincent')
source_language
# Out:
# 'fr'

# %%
translator = TextBlob("今天")
translation = translator.translate(to="fr")
translation
# Out:
# TextBlob("Aujourd'hui")

# %%
translator = TextBlob("01月10日 12:21")
translation = translator.translate(to="fr")
translation
# Out:
# TextBlob("10 janv.12: 21")

# %% [markdown]
# p class=from a href target=blank

# %%
textToDate("今天20:15")
# Out:
# datetime.date(2020, 1, 13)

# %%
from selenium.webdriver.chrome.options import Options
from selenium import webdriver

# %%
url= "https://s.weibo.com/weibo?q=airbus"

# options = Options()
# options.add_argument("--start-maximized")
# driver =  webdriver.PhantomJS('/home/sid2019-13/Téléchargements/phantomjs-2.1.1-linux-x86_64/bin/phantomjs')
# driver.get(url)
# page1 =BeautifulSoup(driver.page_source, 'html.parser')


req = Request(url, headers={'User-Agent': 'Mozilla/5.0'})
web_page = urlopen(req).read()
page1 = BeautifulSoup(web_page, 'html.parser')

# %%
re.search("[0-9][0-9]*/s*[0-9]*/s*[0-9]*",'2019年12月25日 20:26')

# %%
chiffres = re.search("([0-9]*\w)*", '2019年12月25日 20:26').group(0                                                            )

chiffres=re.findall(r"([0-9]+)",chiffres)
