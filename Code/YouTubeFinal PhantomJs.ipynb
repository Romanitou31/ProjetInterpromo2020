# %%
# Created on 09/01/2020
# Group1
# @authors: benjamin anton

import json
import re
from datetime import datetime, timedelta,date
import time
import requests
from urllib.request import Request, urlopen
from textblob import TextBlob
from langdetect import detect
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

# %%
#path
path = '/home/sid2019-13/Téléchargements/chromedriver'

# %%
def translate (texte) : 
    try :
        new = str(TextBlob(texte).translate(to='en'))
        return new
    except :
        return texte
    
def replace_all(text, dic):
    for i, j in dic.items():
        text = text.replace(i, j)
    return text

# %%
def getVideos(soup, limitDate=None):
    """Documentation    
       Parameters:
            soup : soup for the request 
            limitDate : date on which we will filter video
       out : 
            list_Videos : search equation videos list        
    """
    videos = soup.findAll('a', attrs={'class': 'yt-uix-tile-link'})
    dates = soup.findAll('ul', attrs={'class': 'yt-lockup-meta-info'})
    
    list_Videos = []
    for i in range(len(videos)):
        date = DateCalculation(str(dates[i]).split(
            "</li><li>")[0].split("<li>")[-1])
        if limitDate is None:
            list_Videos.append('https://www.youtube.com'+videos[i]['href'])
        elif date > limitDate:
            list_Videos.append('https://www.youtube.com'+videos[i]['href'])
            
    return list_Videos

# %% [markdown]
# # Create equation research

# %%
Airline_Companies = [
    "American Airlines",
    "Air Canada",
    "Air France",
    "Air Algerie",
    "Air India",
    "Aerolineas Argentinas",
    "Royal Air Maroc",
    "Finnair",
    "Alitalia ",
    " Nouvelair",
    "Air China",
    "Cathay Pacific",
    "Delta Airlines",
    "Aer Lingus",
    "Emirates",
    "Ethiopian Airlines",
    "Icelandair",
    "Hawaiian Airlines",
    "Iberia",
    "Meridiana",
    "Japan Airlines",
    "KLM",
    "Air Malta",
    "Lan Airlines",
    "Luxair",
    "LIAT",
    "LOT Polish Airlines",
    "Air Madagascar",
    "Air Mauritius",
    "Austrian Airlines",
    "Qatar Airways",
    "South African Airways",
    "SAS Scandinavian Airlines",
    "Brussels Airlines",
    "Singapore Airlines",
    "Corsair",
    "Aeroflot",
    "Thai Airways",
    "Turkish Airlines",
    "TAP Portugal",
    "Air Transat",
    "Tunisair",
    "Air Caraibes",
    "United Airlines",
    "Air Austral",
    "Air Europa",
    "Easyjet",
    "Vietnam Airlines",
    "Virgin Atlantic",
    "Air Corsica",
    "Condor",
    "Flybe",
    "Aegean Airlines",
    "Air Tahiti Nui",
    "Aigle Azur",
    "HOP!",
    "Jet Airways",
    "Etihad Airways",
    "Etihad Airways",
    "Oman Air",
    "XL Airways",
    "Ryanair LTD",
    "Vueling ",
    "Norwegian",
    "Transavia France",
    "Germanwings",
    "TUI Fly Belgium",
    "Air Arabia",
    "WOW air",
    "Wizz Air",
    "Air Asia",
    "Volotea",
    "southwest airlines"
]
Airline_Companies = [compagnies.replace(
    ' ', '+') for compagnies in Airline_Companies]


Boeing_Models = [
    "Boeing 717",
    "Boeing 727",
    "Boeing 737-200",
    "Boeing 737-300",
    "Boeing 737-400",
    "Boeing 737-500",
    "Boeing 737-600",
    "Boeing 737-700",
    "Boeing 737-700ER",
    "Boeing 737-800",
    "Boeing 737-900",
    "Boeing 737-900ER",
    "Boeing 737 MAX 7",
    "Boeing 737 MAX 8",
    "Boeing 737 MAX 9",
    "Boeing 737 MAX 10",
    "Boeing 747-200",
    "Boeing 747-400",
    "Boeing 757-200",
    "Boeing 757-300",
    "Boeing 767-200",
    "Boeing 767-300",
    "Boeing 767-300ER",
    "Boeing 767-400ER",
    "Boeing 777 Triple Seven",
    "Boeing 787 DreamLiner"
]
Boeing_Models = [models.replace(' ', '+') for models in Boeing_Models]


Airbus_Models = [
    "A300",
    "A300-600ST",
    "A318",
    "A319",
    "A320-100",
    "A320-200",
    "A320neo",
    "A321-100",
    "A321-200",
    "A330-200",
    "A330-300",
    "A330-200F",
    "A330-500",
    "A340-200",
    "A340-300",
    "A340-500",
    "A340-600",
    "A350-900",
    "A350-1000",
    "A380-800",
    "A220-300"
]

key_words = [
    "trip",
    "fly",
    "plane",
    "airplane",
    "flight"
]


equations = []
for comp in Airline_Companies:
    for mod in Airbus_Models:
        equations.append(comp+"+"+mod)
    for mod in Boeing_Models:
        equations.append(comp+"+"+mod)

# quibbling function

# %%
def ChangeDate(chain):
    """Documentation    
       Parameters:
            chain : character string in format "ex :il ya 300 ans"    
       out : 
            expression.group(0) : character string in format  "ex 300 ans"          
    """
    expression = re.search("[0-9]*\s[a-zA-Z]*$", chain)
    return(expression.group(0))


def Simplification(chain):
    # transform M into 1000000,  and K into 1000
    """Documentation    
       Parameters:
            chain : character string in format "ex : 300K"    
       out : 
            int(float(expression) * coef) : integer  "ex 300 000"          
    """
    chain = chain.replace(',', '.')
    if '.' in chain:
        expression = (re.search("\d+\.\d+", chain)).group(0)
    else:
        expression = (re.search("\d+", chain)).group(0)
    coef = 1
    if 'k' in chain:
        coef = 1000
    if 'M' in chain:
        coef = 1000000
    return(int(float(expression) * coef))


def DateCalculation(chain):
    # calculate the exact date of publication of the video
    """Documentation    
       Parameters :
            chain : character string in format "ex : il ya 300 ans"    
       out : 
            chain : date           
    """

    chain = (chain).replace('il y a ', '')
    day_nb=0
    if 'hier' in chain:
        day_nb = 1
    else:
        day_nb = int((re.search("\d+", chain)).group(0))
    if 'mois' in chain:
        day_nb = day_nb * 30
    if 'an' in chain:
        day_nb = day_nb * 365
    if 'semaine' in chain:
        day_nb = day_nb * 7

    now = date.today()
    return str(now - timedelta(days=(day_nb)))

# %% [markdown]
# # Creation of the url list

# %%
def URLlist(Research_Equations,limitDate):
    # returns the list of videos of the search equation passed in parameter
    """Documentation    
       Parameters:
            Research_Equations : search equation we want to launch    
       out : 
            list_Videos : search equation videos list        
    """
    root_URL = "https://www.youtube.com/results?search_query="
    #ResearchEquations = "airbus+A380"

    r = requests.get(root_URL + Research_Equations)
    page = r.text
    soup = BeautifulSoup(page, 'html.parser')
    
    list_Videos = getVideos(soup,limitDate)
    return list_Videos

# %% [markdown]
# # Function that creates our filled Json file

# %%
def GetCodeHTML(URL_list, fig):
    """Documentation    

       Parameters:
            URL_list : list of url   
            fig : url index processed
       out :  
            BeautifulSoup(web_page, 'html.parser') : return html code of the url page      
    """
    url = URL_list[fig]
    req = Request(url, headers={'User-Agent': 'Mozilla/5.0'})
    web_page = urlopen(req).read()
    return BeautifulSoup(web_page, 'html.parser')


def CreateJs(comment, nb_com, soup, comment_date):
    # create the json file with all the information on the page
    """Documentation    

       Parameters:
            comment : character string of the comment
            nb_com : number of comment
            comment_date : comment date

    """
    name_col = ['Airline_Name',
                'Airline_Type',
                'Region_Operation',
                'Aircraft_Type',
                'Cabin_Class',
                'Type_Of_Lounge',
                'Type_Of_Traveller',
                'Date_Visit',
                'Date_Flown',
                'Airport',
                'Route',
                'Category',
                'Category_Detail',
                'Cabin_Staff_Service',
                'Lounge_Staff_Service',
                'Bar_And_Beverages',
                'Food_And_Beverages',
                'Ground_Service',
                'Catering', 'Cleanliness',
                'Lounge_Comfort',
                'Aisle_Space',
                'Wifi_And_Connectivity',
                'Inflight_Entertainment',
                'Viewing_Tv_Screen',
                'Power_Supply',
                'Seat',
                'Seat_type',
                'Seat_Comfort',
                'Seat_Legroom',
                'Seat_Storage',
                'Seat_Width',
                'Seat_Recline',
                'Washrooms',
                'Value_For_Money',
                'Overall_Customer_Rating',
                'Overall_Service_Rating',
                'Overall_Airline_Rating',
                'Recommended',
                'Departure_city',
                'Arrival_city',
                'Nb_bus_taken',
                'Nb_train_taken',
                'Nb_car_taken',
                'Nb_plane_taken',
                'Duration',
                'Price_min',
                'Price_max',
                'Nb_sharing',
                'Awards',
                'Registration',
                'Language']

    soup = soup
    video_details = {}

# Fill data

    video_details['Data_Source'] = 'Youtube'

    for i in range(39):
        video_details[name_col[i]] = ' '

    video_details['Date_Review'] = DateCalculation(comment_date)
    video_details['Review'] = translate(comment)

    for i in range(39, 48):
        video_details[name_col[i]] = ' '

# get the title of the video
    video_details['Title'] = soup.find(
        'span', attrs={'class': 'watch-title'}).text.strip()

# get the name of the chain
    for script in soup.findAll('script', attrs={'type': 'application/ld+json'}):
        channelDescription = json.loads(script.text.strip())
        video_details['Author'] = channelDescription['itemListElement'][0]['item']['name']

# get description
    video_details['Description'] = soup.find(
        'p', attrs={'id': "eow-description"}).text.strip()

# get the date of publication
    dic = {'.':'','avr':'apr','janv':'jan','mars':'mar','mai':'may','juin':'jun','févr':'feb','juil':'jul','déc':'dec','août':'aug','sept':'sep','aoÃ»t':'aug'}
    var_date_of_public = soup.find('strong',attrs={'class': "watch-time-text"}).text.strip().replace('.','')
    var_date_of_public = replace_all(var_date_of_public,dic)
    video_details['Date_publication'] = str(datetime.strptime(re.search("[0-9][0-9]* [a-zA-Z]* [0-9]*", var_date_of_public).group(0), '%d %b %Y')). replace('00:00:00', '')

# get the number of views
    video_details['View_Count'] = (soup.find(
        'div', attrs={'class': 'watch-view-count'}).text.strip()).replace('vues', '')

# get a likes button
    for span in soup.findAll('', attrs={'class': "yt-uix-button yt-uix-button-size-default yt-uix-button-opacity yt-uix-button-has-icon no-icon-markup like-button-renderer-like-button like-button-renderer-like-button-unclicked yt-uix-clickcard-target yt-uix-tooltip"}):
        video_details['Likes'] = span.find(
            'span', attrs={'class': 'yt-uix-button-content'}).text.strip()

# get a dislikes button
    for button in soup.findAll('button', attrs={'class': "yt-uix-button yt-uix-button-size-default yt-uix-button-opacity yt-uix-button-has-icon no-icon-markup like-button-renderer-dislike-button like-button-renderer-dislike-button-unclicked yt-uix-clickcard-target yt-uix-tooltip"}):
        video_details['Dislikes'] = button.find(
            'span', attrs={'class': 'yt-uix-button-content'}).text.strip()

# get subscriber number
    if (soup.find('span', attrs={'class': 'yt-subscription-button-subscriber-count-branded-horizontal yt-subscriber-count'}) == None):
        video_details["Nb_subscribers"] = 0
    else:
        video_details["Nb_subscribers"] = Simplification(soup.find('span', attrs={
                                                         'class': 'yt-subscription-button-subscriber-count-branded-horizontal yt-subscriber-count'}).text.strip())

    video_details['Nb_comments'] = (nb_com).replace('commentaires', '')

    video_details[name_col[48]] = ' '
# get hashtags
    hashtags = []

    for span in soup.findAll('span', attrs={'class': 'standalone-collection-badge-renderer-text'}):
        for a in span.findAll('a', attrs={'class': 'yt-uix-sessionlink'}):
            hashtags.append(a.text.strip())
    video_details['hashtags'] = hashtags

    for i in range(49, 51):
        video_details[name_col[i]] = ' '

    video_details['Language'] = 'unknown'
    if re.search("([a-z]).*", str(comment).lower()):
        video_details['Language'] = detect(str(comment))

    with open('data.json', 'a', encoding='utf8') as outfile:
        json.dump(video_details, outfile, ensure_ascii=False, indent=4)


def scroll(url, nb_scroll):
    #scroll down in the page
    """Documentation    
       Parameters:
            url : page url 
            nb_scroll : number of times you scroll  
       out : 
            BeautifulSoup(driver.page_source, 'html.parser') : the new page after scroll
            

    """
    options = Options()
    options.add_argument("--start-maximized")
    driver =  webdriver.PhantomJS('/home/sid2019-13/Téléchargements/phantomjs-2.1.1-linux-x86_64/bin/phantomjs')
    driver.get(url)
    Y = 0
    for _ in range(nb_scroll):
        time.sleep(4)
        driver.execute_script("window.scrollTo("+str(Y)+","+str(Y+800)+")")
        Y += 1200
    
#     lastHeight = driver.execute_script("return document.body.scrollHeight")
    
#     while True :
#         driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
#         time.sleep(2)

#         newHeight = driver.execute_script("return document.body.scrollHeight")
#         print (newHeight)

#         if newHeight == lastHeight:
#             break
#         lastHeight = newHeight
#         i += 1
#         driver.get_screenshot_as_file("test03_1_"+str(i)+".jpg")




    return BeautifulSoup(driver.page_source, 'html.parser')

# %%
driver = webdriver.PhantomJS('/home/sid2019-13/Téléchargements/phantomjs-2.1.1-linux-x86_64/bin/phantomjs')
driver.set_window_size(1120, 550)
driver.get("https://www.google.fr/")

driver.quit()

# %%
soup = scroll('https://www.youtube.com/watch?v=8A0zP9E6tjM',4)

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="content-snap-width-1" data-cast-api-enabled="true" lang="fr-FR"><head><style name="www-roboto">@font-face{font-family:'Roboto';font-style:italic;font-weight:500;src:local('Roboto Medium Italic'),local('Roboto-MediumItalic'),url(//fonts.gstatic.com/s/roboto/v18/KFOjCnqEu92Fr1Mu51S7ACc6CsE.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:italic;font-weight:400;src:local('Roboto Italic'),local('Roboto-Italic'),url(//fonts.gstatic.com/s/roboto/v18/KFOkCnqEu92Fr1Mu51xIIzc.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:500;src:local('Roboto Medium'),local('Roboto-Medium'),url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmEU9fBBc9.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:400;src:local('Roboto Regular'),local('Roboto-Regular'),url(//fonts.gstatic.com/s/roboto/v18/KFOmCnqEu92Fr1Mu4mxP.ttf)format('truetype');}</style><script src="https://pagead2.googlesyndication.com/pagead/show_companion_ad.js"></script><script name="www-roboto">if (document.fonts && document.fonts.load) {document.fonts.load("400 10pt Roboto", "F");document.fonts.load("500 10pt Roboto", "F");}</script><script>var ytcsi = {gt: function(n) {n = (n || '') + 'data_';return ytcsi[n] || (ytcsi[n] = {tick: {},info: {}});},now: (window.performance && window.performance.timing &&window.performance.now && window.performance.timing.navigationStart) ?function() {return window.performance.timing.navigationStart +window.performance.now();} :function() {return (new Date()).getTime();},tick: function(l, t, n) {ticks = ytcsi.gt(n).tick;var v = t || ytcsi.now();if (ticks[l]) {ticks['_' + l] = (ticks['_' + l] || [ticks[l]]);ticks['_' + l].push(v);}ticks[l] = v;},info: function(k, v, n) {ytcsi.gt(n).info[k] = v;},setStart: function(s, t, n) {ytcsi.info('yt_sts', s, n);ytcsi.tick('_start', t, n);}};(function(w, d) {ytcsi.setStart('dhs', w.performance ? w.performance.timing.responseStart : null);var isPrerender = (d.visibilityState || d.webkitVisibilityState) == 'prerender';var vName = (!d.visibilityState && d.webkitVisibilityState)? 'webkitvisibilitychange' : 'visibilitychange';if (isPrerender) {ytcsi.info('prerender', 1);var startTick = function() {ytcsi.setStart('dhs');d.removeEventListener(vName, startTick);};d.addEventListener(vName, startTick, false);}if (d.addEventListener) {d.addEventListener(vName, function() {ytcsi.tick('vc');}, false);}function isGecko() {if (!w.navigator || !w.navigator.userAgent) {return false;}var ua = w.navigator.userAgent;return ua.indexOf('Gecko') > 0 &&ua.toLowerCase().indexOf('webkit') < 0 &&ua.indexOf('Edge') < 0 &&ua.indexOf('Trident') < 0 &&ua.indexOf('MSIE') < 0;}if (isGecko()) {var isHidden = (d.visibilityState || d.webkitVisibilityState) == 'hidden';if (isHidden) {ytcsi.tick('vc');}}var slt = function(el, t) {setTimeout(function() {var n = ytcsi.now();el.loadTime = n;if (el.slt) {el.slt();}}, t);};w.__ytRIL = function(el) {if (!el.getAttribute('data-thumb')) {if (w.requestAnimationFrame) {w.requestAnimationFrame(function() {slt(el, 0);});} else {slt(el, 16);}}};})(window, document);</script><script>var ytcfg = {d: function() {return (window.yt && yt.config_) || ytcfg.data_ || (ytcfg.data_ = {});},get: function(k, o) {return (k in ytcfg.d()) ? ytcfg.d()[k] : o;},set: function() {var a = arguments;if (a.length > 1) {ytcfg.d()[a[0]] = a[1];} else {for (var k in a[0]) {ytcfg.d()[k] = a[0][k];}}}};</script> <script>ytcfg.set("ROOT_VE_TYPE", 3832);ytcfg.set("EVENT_ID", "AC8cXsDKLtfIVK6AqdgO");</script>
# <script>ytcfg.set("LACT", null);</script>
# <script>window.yterr = window.yterr || true;</script>
# <script>
#         (function(){/*
#
#  Copyright The Closure Library Authors.
#  SPDX-License-Identifier: Apache-2.0
# */
# var a={a:"content-snap-width-1",b:"content-snap-width-2",f:"content-snap-width-3"};function f(){var c=[],b;for(b in a)c.push(a[b]);return c}
# function h(c){var b=f().concat(["guide-pinned","show-guide"]),d=b.length,g=[];c.replace(/\S+/g,function(e){for(var k=0;k<d;k++)if(e==b[k])return;g.push(e)});
# return g}
# ;function l(c,b,d){var g=document.getElementsByTagName("html")[0],e=h(g.className);c&&1251<=(window.innerWidth||document.documentElement.clientWidth)&&(e.push("guide-pinned"),b&&e.push("show-guide"));d&&(d=(window.innerWidth||document.documentElement.clientWidth)-21-50,1251<=(window.innerWidth||document.documentElement.clientWidth)&&c&&b&&(d-=230),e.push(1262<=d?"content-snap-width-3":1056<=d?"content-snap-width-2":"content-snap-width-1"));g.className=e.join(" ")}
# var m=["yt","www","masthead","sizing","runBeforeBodyIsReady"],n=this||self;m[0]in n||"undefined"==typeof n.execScript||n.execScript("var "+m[0]);for(var p;m.length&&(p=m.shift());)m.length||void 0===l?n[p]&&n[p]!==Object.prototype[p]?n=n[p]:n=n[p]={}:n[p]=l;}).call(this);
#
#       try {window.ytbuffer = {};ytbuffer.handleClick = function(e) {var element = e.target || e.srcElement;while (element.parentElement) {if (/(^| )yt-can-buffer( |$)/.test(element.className)) {window.ytbuffer = {bufferedClick: e};element.className += ' yt-is-buffered';break;}element = element.parentElement;}};if (document.addEventListener) {document.addEventListener('click', ytbuffer.handleClick);} else {document.attachEvent('onclick', ytbuffer.handleClick);}} catch(e) {}
#
#     yt.www.masthead.sizing.runBeforeBodyIsReady(false,false,true);
#   </script>
# <script class="js-httpswwwyoutubecomytsjsbinschedulervflcHH6r0schedulerjs" name="scheduler/scheduler" src="/yts/jsbin/scheduler-vflcHH6r0/scheduler.js" type="text/javascript"></script>
# <script>var ytimg = {};ytimg.count = 1;ytimg.preload = function(src) {var img = new Image();var count = ++ytimg.count;ytimg[count] = img;img.onload = img.onerror = function() {delete ytimg[count];};img.src = src;};</script>
# <script async="" class="js-httpswwwyoutubecomytsjsbinwwwpageadidvfl89tyv3wwwpageadidjs" name="www-pagead-id/www-pagead-id" src="/yts/jsbin/www-pagead-id-vfl89tyv3/www-pagead-id.js" type="text/javascript"></script>
# <script class="js-httpswwwyoutubecomytsjsbinplayer_iasvflJiqSE7fr_FRbasejs" name="player_ias/base" src="/yts/jsbin/player_ias-vflJiqSE7/fr_FR/base.js"></script>
# <link class="css-httpswwwyoutubecomytscssbinwwwcorevflRlRixQcss" href="/yts/cssbin/www-core-vflRlRixQ.css" name="www-core" rel="stylesheet"/>
# <link class="css-httpswwwyoutubecomytscssbinplayervfl0tglhlwwwplayercss" href="/yts/cssbin/player-vfl0tglhl/www-player.css" name="player/www-player" rel="stylesheet"/>
# <link class="css-httpswwwyoutubecomytscssbinwwwpageframevfldKQBmrcss" href="/yts/cssbin/www-pageframe-vfldKQBmr.css" name="www-pageframe" rel="stylesheet"/>
# <script>ytimg.preload("https:\/\/r3---sn-gx1v2vax-atne.googlevideo.com\/generate_204?conn2");ytimg.preload("https:\/\/r3---sn-gx1v2vax-atne.googlevideo.com\/generate_204");</script>
# <title>Vous n'avez pas vu ça... - YouTube</title><link href="https://www.youtube.com/watch?v=Qt7ds3MpPEo" rel="canonical"/><link href="https://m.youtube.com/watch?v=Qt7ds3MpPEo" media="handheld" rel="alternate"/><link href="https://m.youtube.com/watch?v=Qt7ds3MpPEo" media="only screen and (max-width: 640px)" rel="alternate"/> <meta content="Vous n'avez pas vu ça..." name="title"/>
# <meta content="Je reviens sur mon année 2019 et surtout je vous parle des projets à venir ! Et on termine avec le bêtisier 👌" name="description"/>
# <meta content="cyprien, bêtisier, bilan 2019, film, jeu mobile" name="keywords"/>
# <link href="/manifest.json" rel="manifest"/><link href="https://youtu.be/Qt7ds3MpPEo" rel="shortlink"/><link href="https://www.youtube.com/opensearch?locale=fr_FR" rel="search" title="Recherche de vidéos YouTube" type="application/opensearchdescription+xml"/><link href="https://s.ytimg.com/yts/img/favicon-vfl8qSV2F.ico" rel="shortcut icon" type="image/x-icon"/> <link href="/yts/img/favicon_32-vflOogEID.png" rel="icon" sizes="32x32"/><link href="/yts/img/favicon_48-vflVjB_Qk.png" rel="icon" sizes="48x48"/><link href="/yts/img/favicon_96-vflW9Ec0w.png" rel="icon" sizes="96x96"/><link href="/yts/img/favicon_144-vfliLAfaB.png" rel="icon" sizes="144x144"/><meta content="#ff0000" name="theme-color"/> <link href="android-app://com.google.android.youtube/http/www.youtube.com/watch?v=Qt7ds3MpPEo" rel="alternate"/>
# <link href="ios-app://544007664/vnd.youtube/www.youtube.com/watch?v=Qt7ds3MpPEo" rel="alternate"/>
# <link href="http://www.youtube.com/oembed?format=json&amp;url=https%3A%2F%2Fwww.youtube.com%2Fwatch%3Fv%3DQt7ds3MpPEo" rel="alternate" title="Vous n'avez pas vu ça..." type="application/json+oembed"/>
# <link href="http://www.youtube.com/oembed?format=xml&amp;url=https%3A%2F%2Fwww.youtube.com%2Fwatch%3Fv%3DQt7ds3MpPEo" rel="alternate" title="Vous n'avez pas vu ça..." type="text/xml+oembed"/>
# <meta content="YouTube" property="og:site_name"/>
# <meta content="https://www.youtube.com/watch?v=Qt7ds3MpPEo" property="og:url"/>
# <meta content="Vous n'avez pas vu ça..." property="og:title"/>
# <meta content="https://i.ytimg.com/vi/Qt7ds3MpPEo/maxresdefault.jpg" property="og:image"/>
# <meta content="1280" property="og:image:width"/>
# <meta content="720" property="og:image:height"/>
# <meta content="Je reviens sur mon année 2019 et surtout je vous parle des projets à venir ! Et on termine avec le bêtisier 👌" property="og:description"/>
# <meta content="544007664" property="al:ios:app_store_id"/>
# <meta content="YouTube" property="al:ios:app_name"/>
# <meta content="vnd.youtube://www.youtube.com/watch?v=Qt7ds3MpPEo&amp;feature=applinks" property="al:ios:url"/>
# <meta content="vnd.youtube://www.youtube.com/watch?v=Qt7ds3MpPEo&amp;feature=applinks" property="al:android:url"/>
# <meta content="YouTube" property="al:android:app_name"/>
# <meta content="com.google.android.youtube" property="al:android:package"/>
# <meta content="https://www.youtube.com/watch?v=Qt7ds3MpPEo&amp;feature=applinks" property="al:web:url"/>
# <meta content="video.other" property="og:type"/>
# <meta content="https://www.youtube.com/embed/Qt7ds3MpPEo" property="og:video:url"/>
# <meta content="https://www.youtube.com/embed/Qt7ds3MpPEo" property="og:video:secure_url"/>
# <meta content="text/html" property="og:video:type"/>
# <meta content="1280" property="og:video:width"/>
# <meta content="720" property="og:video:height"/>
# <meta content="cyprien" property="og:video:tag"/>
# <meta content="bêtisier" property="og:video:tag"/>
# <meta content="bilan 2019" property="og:video:tag"/>
# <meta content="film" property="og:video:tag"/>
# <meta content="jeu mobile" property="og:video:tag"/>
# <meta content="87741124305" property="fb:app_id"/>
# <meta content="player" name="twitter:card"/>
# <meta content="@youtube" name="twitter:site"/>
# <meta content="https://www.youtube.com/watch?v=Qt7ds3MpPEo" name="twitter:url"/>
# <meta content="Vous n'avez pas vu ça..." name="twitter:title"/>
# <meta content="Je reviens sur mon année 2019 et surtout je vous parle des projets à venir ! Et on termine avec le bêtisier 👌" name="twitter:description"/>
# <meta content="https://i.ytimg.com/vi/Qt7ds3MpPEo/maxresdefault.jpg" name="twitter:image"/>
# <meta content="YouTube" name="twitter:app:name:iphone"/>
# <meta content="544007664" name="twitter:app:id:iphone"/>
# <meta content="YouTube" name="twitter:app:name:ipad"/>
# <meta content="544007664" name="twitter:app:id:ipad"/>
# <meta content="vnd.youtube://www.youtube.com/watch?v=Qt7ds3MpPEo&amp;feature=applinks" name="twitter:app:url:iphone"/>
# <meta content="vnd.youtube://www.youtube.com/watch?v=Qt7ds3MpPEo&amp;feature=applinks" name="twitter:app:url:ipad"/>
# <meta content="YouTube" name="twitter:app:name:googleplay"/>
# <meta content="com.google.android.youtube" name="twitter:app:id:googleplay"/>
# <meta content="https://www.youtube.com/watch?v=Qt7ds3MpPEo" name="twitter:app:url:googleplay"/>
# <meta content="https://www.youtube.com/embed/Qt7ds3MpPEo" name="twitter:player"/>
# <meta content="1280" name="twitter:player:width"/>
# <meta content="720" name="twitter:player:height"/>
# <link class="css-httpswwwyoutubecomytscssbinwwwwatchtranscriptvflp9_n_icss" href="/yts/cssbin/www-watch-transcript-vflp9_n_i.css" name="www-watch-transcript" rel="stylesheet"/>
# <style>.exp-invert-logo .hats-logo {background: no-repeat url(/yts/img/ringo/hitchhiker/logo_mini_gray-vflfanGkh.png);width: 65px;height: 15px;}.exp-invert-logo #header:before,.exp-invert-logo .ypc-join-family-header .logo,.exp-invert-logo #footer-logo .footer-logo-icon,.exp-invert-logo #yt-masthead #logo-container .logo,.exp-invert-logo #masthead #logo-container,.exp-invert-logo .admin-masthead-logo a,.exp-invert-logo #yt-sidebar-styleguide-logo #logo {background: no-repeat url(/yts/img/ringo/hitchhiker/logo_small-vflHpzGZm.png);width: 100px;height: 30px;}.exp-invert-logo.inverted-hdpi #header:before,.exp-invert-logo.inverted-hdpi .ypc-join-family-header .logo,.exp-invert-logo.inverted-hdpi #footer-logo .footer-logo-icon,.exp-invert-logo.inverted-hdpi #yt-masthead #logo-container .logo,.exp-invert-logo.inverted-hdpi #masthead #logo-container,.exp-invert-logo.inverted-hdpi .admin-masthead-logo a,.exp-invert-logo.inverted-hdpi #yt-sidebar-styleguide-logo #logo {background: no-repeat url(/yts/img/ringo/hitchhiker/logo_small_2x-vfl4_cFqn.png);background-size: 100px 30px;width: 100px;height: 30px;}.exp-invert-logo.exp-fusion-nav-redesign .masthead-logo-renderer-logo {background: no-repeat url(/yts/img/ringo/hitchhiker/yt_play_logo-vflLfk4yD.png);width: 40px;height: 28px;}.exp-invert-logo.inverted-hdpi.exp-fusion-nav-redesign .masthead-logo-renderer-logo {background: no-repeat url(/yts/img/ringo/hitchhiker/yt_play_logo_2x-vflXx5Pg3.png);width: 40px;height: 28px;}@media screen and (max-width: 656px) {.exp-invert-logo #yt-masthead #logo-container .logo {background: no-repeat url(/yts/img/ringo/hitchhiker/yt_play_logo-vflLfk4yD.png);width: 40px;height: 28px;}.exp-invert-logo.inverted-hdpi #yt-masthead #logo-container .logo {background: no-repeat url(/yts/img/ringo/hitchhiker/yt_play_logo_2x-vflXx5Pg3.png);background-size: 40px 28px;width: 40px;height: 28px;}}@media only screen and (min-width: 0px) and (max-width: 498px),only screen and (min-width: 499px) and (max-width: 704px) {.exp-invert-logo.exp-responsive #yt-masthead #logo-container {background: no-repeat url(/yts/img/ringo/hitchhiker/yt_play_logo-vflLfk4yD.png);width: 40px;height: 28px;}.exp-invert-logo.inverted-hdpi.exp-responsive #yt-masthead #logo-container {background: no-repeat url(/yts/img/ringo/hitchhiker/yt_play_logo_2x-vflXx5Pg3.png);background-size: 40px 28px;width: 40px;height: 28px;}}.exp-invert-logo #yt-masthead #logo-container .logo-red {background: no-repeat url(/yts/img/ringo/hitchhiker/logo_youtube_red-vflZxcSR1.png);width: 132px;height: 30px;}.exp-invert-logo.inverted-hdpi #yt-masthead #logo-container .logo-red {background: no-repeat url(/yts/img/ringo/hitchhiker/logo_youtube_red_2x-vflOSHA_n.png);background-size: 132px 30px;width: 132px;height: 30px;}.exp-invert-logo #yt-masthead #logo-container .logo-premium {background: no-repeat url(/yts/img/ringo/hitchhiker/logo_youtube_premium-vfltrvziB.png);width: 108px;height: 30px;}.exp-invert-logo.inverted-hdpi #yt-masthead #logo-container .logo-premium {background: no-repeat url(/yts/img/ringo/hitchhiker/logo_youtube_premium_2x-vflxcbz_g.png);background-size: 108px 30px;width: 108px;height: 30px;}.exp-invert-logo .guide-item .guide-video-youtube-red-icon {background: no-repeat url(/yts/img/ringo/hitchhiker/video_youtube_red-vflovGTdz.png);width: 20px;height: 20px;}.exp-invert-logo.inverted-hdpi .guide-item .guide-video-youtube-red-icon {background: no-repeat url(/yts/img/ringo/hitchhiker/video_youtube_red_2x-vflqMdgEM.png);background-size: 20px 20px;width: 20px;height: 20px;}.exp-invert-logo .guide-item:hover .guide-video-youtube-red-icon,.exp-invert-logo .guide-item.guide-item-selected .guide-video-youtube-red-icon {background: no-repeat url(/yts/img/ringo/hitchhiker/video_youtube_red_hover-vflgV4Gv0.png);width: 20px;height: 20px;}.exp-invert-logo.inverted-hdpi .guide-item:hover .guide-video-youtube-red-icon,.exp-invert-logo.inverted-hdpi .guide-item.guide-item-selected .guide-video-youtube-red-icon {background: no- ...
# <div id="early-body"></div><div id="body-container"><div id="a11y-announcements-container" role="alert"><div id="a11y-announcements-message"></div></div><form action="/logout" method="POST" name="logoutForm"><input name="action_logout" type="hidden" value="1"/><input name="session_token" type="hidden" value=""/></form><div id="masthead-positioner"> <div id="ticker-content">
# </div>
# <div class="clearfix yt-base-gutter" id="yt-masthead-container"> <button class="skip-nav" data-target-id="content" id="a11y-skip-nav" tabindex="3">
# Ignorer les liens de navigation
#   </button>
# <div id="yt-masthead"><div class="yt-masthead-logo-container"> <button aria-controls="appbar-guide-menu" aria-label="Guide" class="yt-uix-button yt-uix-button-size-default yt-uix-button-text yt-uix-button-empty yt-uix-button-has-icon appbar-guide-toggle appbar-guide-clickable-ancestor" id="appbar-guide-button" onclick=";return false;" type="button"><span class="yt-uix-button-icon-wrapper"><span class="yt-uix-button-icon yt-uix-button-icon-appbar-guide yt-sprite"></span></span></button>
# <div id="appbar-main-guide-notification-container"></div>
# <a class="spf-link masthead-logo-renderer yt-uix-sessionlink" data-sessionlink="" href="/" id="logo-container" title="Accueil YouTube"><span class="logo masthead-logo-renderer-logo yt-sprite" title="Accueil YouTube"></span><span class="content-region">FR</span></a>
# </div><div id="yt-masthead-signin"> <a class="yt-uix-button yt-uix-sessionlink yt-uix-button-opacity yt-uix-button-size-default yt-uix-button-has-icon yt-uix-tooltip yt-uix-button-empty" data-sessionlink="ei=AC8cXsDKLtfIVK6AqdgO&amp;feature=mhsb" href="//www.youtube.com/upload" id="upload-btn" title="Mettre en ligne"><span class="yt-uix-button-icon-wrapper"><span class="yt-uix-button-icon yt-uix-button-icon-material-upload yt-sprite"></span></span></a>
# <div class="signin-container"><button class="yt-uix-button yt-uix-button-size-default yt-uix-button-primary" href="https://accounts.google.com/ServiceLogin?continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Fapp%3Ddesktop%26action_handle_signin%3Dtrue%26hl%3Dfr%26next%3D%252Fwatch%253Fv%253DQt7ds3MpPEo%26feature%3Dsign_in_button&amp;passive=true&amp;service=youtube&amp;hl=fr&amp;uilel=3" onclick=";window.location.href=this.getAttribute('href');return false;" role="link" type="button"><span class="yt-uix-button-content">Connexion</span></button> <iframe id="signin-passive" src="https://accounts.google.com/ServiceLogin?continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Fapp%3Ddesktop%26action_handle_signin%3Dtrue%26hl%3Dfr%26next%3D%252Fsignin_passive%26feature%3Dpassive&amp;passive=true&amp;service=youtube&amp;hl=fr&amp;uilel=3"></iframe>
# </div></div><div id="yt-masthead-content"><form action="/results" class="search-form consolidated-form" data-clicktracking="CAIQ7VAiEwjAytXhmIDnAhVXJBUKHS5ACuso-B0" data-visibility-tracking="CAIQ7VAiEwjAytXhmIDnAhVXJBUKHS5ACuso-B0" id="masthead-search" onsubmit="if (document.getElementById('masthead-search-term').value == '') return false;"><button class="yt-uix-button yt-uix-button-size-default yt-uix-button-default search-btn-component search-button" dir="ltr" id="search-btn" onclick="if (document.getElementById('masthead-search-term').value == '') return false; document.getElementById('masthead-search').submit(); return false;;return true;" tabindex="2" type="submit"><span class="yt-uix-button-content">Rechercher</span></button><div class="masthead-search-terms-border" dir="ltr" id="masthead-search-terms"><input aria-label="Rechercher" autocomplete="off" class="search-term masthead-search-renderer-input yt-uix-form-input-bidi" id="masthead-search-term" name="search_query" onkeydown="if (!this.value &amp;&amp; (event.keyCode == 40 || event.keyCode == 32 || event.keyCode == 34)) {this.onkeydown = null; this.blur();}" placeholder="Rechercher" tabindex="1" title="Rechercher" type="text" value=""/></div></form></div></div></div>
# <div class="clearfix" id="masthead-appbar-container"><div id="masthead-appbar"><div class="" id="appbar-content"></div></div></div>
# </div><div id="masthead-positioner-height-offset"></div><div id="page-container"><div class="watch video-Qt7ds3MpPEo clearfix watch-non-stage-mode" id="page"><div class="yt-scrollbar" id="guide"><div class="appbar-menu appbar-guide-menu-layout appbar-guide-clickable-ancestor yt-uix-scroller yt-uix-tdl" id="appbar-guide-menu" role="navigation">
# <div id="guide-container">
# <div class="guide-module-content yt-scrollbar">
# <ul class="guide-toplevel">
# <li class="guide-section vve-check" data-visibility-tracking="CAwQ5isYACITCOLN9OOYgOcCFYqD1QodULUBxg==">
# <div class="guide-item-container personal-item">
# <ul class="guide-user-links yt-uix-tdl yt-box" role="menu">
# <li class="vve-check guide-channel guide-notification-item overflowable-list-item" data-visibility-tracking="CBAQtSwYACITCOLN9OOYgOcCFYqD1QodULUBxg==" id="what_to_watch-guide-item" role="menuitem">
# <a class="guide-item yt-uix-sessionlink yt-valign spf-link" data-external-id="what_to_watch" data-serialized-endpoint="0qDduQEREg9GRXdoYXRfdG9fd2F0Y2g%3D" data-sessionlink="ei=BS8cXo65G6OgxwKZpIqABA&amp;feature=g-system&amp;ved=CAIQtSwYACITCM7P8-OYgOcCFSPQUQodGZICQA" data-visibility-tracking="CBAQtSwYACITCOLN9OOYgOcCFYqD1QodULUBxg==" href="/" title="Accueil">
# <span class="yt-valign-container">
# <span class="thumb guide-what-to-watch-icon yt-sprite"></span>
# <span class="display-name no-count">
# <span>
#             Accueil
#           </span>
# </span>
# </span>
# </a>
# </li>
# <li class="vve-check guide-channel guide-notification-item overflowable-list-item" data-visibility-tracking="CA8QtSwYASITCOLN9OOYgOcCFYqD1QodULUBxg==" id="trending-guide-item" role="menuitem">
# <a class="guide-item yt-uix-sessionlink yt-valign spf-link" data-external-id="trending" data-serialized-endpoint="0qDduQEMEgpGRXRyZW5kaW5n" data-sessionlink="ei=BS8cXo65G6OgxwKZpIqABA&amp;feature=g-trending&amp;ved=CAMQtSwYASITCM7P8-OYgOcCFSPQUQodGZICQA" data-visibility-tracking="CA8QtSwYASITCOLN9OOYgOcCFYqD1QodULUBxg==" href="/feed/trending" title="Tendances">
# <span class="yt-valign-container">
# <span class="thumb guide-trending-icon yt-sprite"></span>
# <span class="display-name no-count">
# <span>
#             Tendances
#           </span>
# </span>
# </span>
# </a>
# </li>
# <li class="vve-check guide-channel guide-notification-item overflowable-list-item" data-visibility-tracking="CA4QtSwYAiITCOLN9OOYgOcCFYqD1QodULUBxg==" id="history-guide-item" role="menuitem">
# <a class="guide-item yt-uix-sessionlink yt-valign spf-link" data-external-id="history" data-serialized-endpoint="0qDduQELEglGRWhpc3Rvcnk%3D" data-sessionlink="ei=BS8cXo65G6OgxwKZpIqABA&amp;feature=g-personal&amp;ved=CAQQtSwYAiITCM7P8-OYgOcCFSPQUQodGZICQA" data-visibility-tracking="CA4QtSwYAiITCOLN9OOYgOcCFYqD1QodULUBxg==" href="/feed/history" title="Historique">
# <span class="yt-valign-container">
# <span class="thumb guide-history-icon yt-sprite"></span>
# <span class="display-name no-count">
# <span>
#             Historique
#           </span>
# </span>
# </span>
# </a>
# </li>
# <li class="vve-check guide-channel guide-notification-item overflowable-list-item" data-visibility-tracking="CA0QmbcBGAMiEwjizfTjmIDnAhWKg9UKHVC1AcY=" id="unlimited-guide-item" role="menuitem">
# <a class="guide-item yt-uix-sessionlink yt-valign spf-link" data-external-id="unlimited" data-serialized-endpoint="0qDduQENEgtTUHVubGltaXRlZA%3D%3D" data-sessionlink="ei=BS8cXo65G6OgxwKZpIqABA&amp;ved=CAUQtSwYAyITCM7P8-OYgOcCFSPQUQodGZICQA" data-visibility-tracking="CA0QmbcBGAMiEwjizfTjmIDnAhWKg9UKHVC1AcY=" href="/premium" title="Obtenir YouTube Premium">
# <span class="yt-valign-container">
# <span class="thumb guide-video-youtube-red-icon yt-sprite"></span>
# <span class="display-name no-count">
# <span>
#             Obtenir YouTube Premium
#           </span>
# </span>
# </span>
# </a>
# </li>
# </ul>
# </div>
# <hr class="guide-section-separator"/>
# </li>
# <li class="guide-section vve-check" data-visibility-tracking="CAMQ5isYASITCOLN9OOYgOcCFYqD1QodULUBxg==">
# <div class="guide-item-container personal-item">
# <h3>
#       Le meilleur de YouTube
#     </h3>
# <ul class="guide-user-links yt-uix-tdl yt-box" role="menu">
# <li class="vve-check guide-channel guide-notification-item overflowable-list-item" data-visibility-tracking="CAsQtSwYACITCOLN9OOYgOcCFYqD1QodULUBxg==" id="UC-9-kyTW8ZkZNDHQJ6FgpwQ-guide-item" role="menuitem">
# <a class="guide-item yt-uix-sessionlink yt-valign spf-link" data-external-id="UC-9-kyTW8ZkZNDHQJ6FgpwQ" data-serialized-endpoint="0qDduQEaEhhVQy05LWt5VFc4WmtaTkRIUUo2Rmdwd1E%3D" data-sessionlink="ei=BS8cXo65G6OgxwKZpIqABA&amp;feature=g-channel&amp;ved=CAcQtSwYACITCM7P8-OYgOcCFSPQUQodGZICQA" data-visibility-tracking="CAsQtSwYACITCOLN9OOYgOcCFYqD1QodULUBxg==" href="/channel/UC-9-kyTW8ZkZNDHQJ6FgpwQ" title="Musique">
# <span class="yt-valign-container">
# <span class="thumb"> <span class="video-thumb yt-thumb yt-thumb-20">
# <span class="yt-thumb-square">
# <span class="yt-thumb-clip">
# <img alt="" aria-hidden="true" data-thumb="//yt3.ggpht.com/xM1_RRR6ILpU-5apPJmdJio03Ia4H-Bv6pzA-siXKjpYptwdRZVE6yIpc0ZGeSt8KRPAkwkLWg=s20-c-k-c0xffffffff-no-nd-rj" data-ytimg="1" height="20" onload=";window.__ytRIL &amp;&amp; __ytRIL(this)" src="/yts/img/pixel-vfl3z5WfW.gif" width="20"/>
# <span class="vertical-align"></span>
# </span>
# </span>
# </span>
# </span>
# <span class="display-name no-count">
# <span>
#             Musique
#           </span>
# </span>
# </span>
# </a>
# </li>
# <li class="vve-check guide-channel guide-notification-item overflowable-list-item" data-visibility-tracking="CAoQtSwYASITCOLN9OOYgOcCFYqD1QodULUBxg==" id="UCEgdi0XIXXZ-qJOFPf4JSKw-guide-item" role="menuitem">
# <a class="guide-item yt-uix-sessionlink yt-valign spf-link" data-external-id="UCEgdi0XIXXZ-qJOFPf4JSKw" data-serialized-endpoint="0qDduQEaEhhVQ0VnZGkwWElYWFotcUpPRlBmNEpTS3c%3D" data-sessionlink="ei=BS8cXo65G6OgxwKZpIqABA&amp;feature=g-channel&amp;ved=CAgQtSwYASITCM7P8-OYgOcCFSPQUQodGZICQA" data-visibility-tracking="CAoQtSwYASITCOLN9OOYgOcCFYqD1QodULUBxg==" href="/channel/UCEgdi0XIXXZ-qJOFPf4JSKw" title="Sport">
# <span class="yt-valign-container">
# <span class="thumb"> <span class="video-thumb yt-thumb yt-thumb-20">
# <span class="yt-thumb-square">
# <span class="yt-thumb-clip">
# <img alt="" aria-hidden="true" data-thumb="//yt3.ggpht.com/UiKw8wbChl12bk4FBp5LcdeqFb6JItDCYT7W0RhzVrQSOElzFL4R1sc7uTX8WsiChORwmzG7ZQ=s20-c-k-c0xffffffff-no-nd-rj" data-ytimg="1" height="20" onload=";window.__ytRIL &amp;&amp; __ytRIL(this)" src="/yts/img/pixel-vfl3z5WfW.gif" width="20"/>
# <span class="vertical-align"></span>
# </span>
# </span>
# </span>
# </span>
# <span class="display-name no-count">
# <span>
#             Sport
#           </span>
# </span>
# </span>
# </a>
# </li>
# <li class="vve-check guide-channel guide-notification-item overflowable-list-item" data-visibility-tracking="CAkQtSwYAiITCOLN9OOYgOcCFYqD1QodULUBxg==" id="UCOpNcN46UbXVtpKMrmU4Abg-guide-item" role="menuitem">
# <a class="guide-item yt-uix-sessionlink yt-valign spf-link" data-external-id="UCOpNcN46UbXVtpKMrmU4Abg" data-serialized-endpoint="0qDduQEaEhhVQ09wTmNONDZVYlhWdHBLTXJtVTRBYmc%3D" data-sessionlink="ei=BS8cXo65G6OgxwKZpIqABA&amp;feature=g-channel&amp;ved=CAkQtSwYAiITCM7P8-OYgOcCFSPQUQodGZICQA" data-visibility-tracking="CAkQtSwYAiITCOLN9OOYgOcCFYqD1QodULUBxg==" href="/gaming" title="Jeux vidéo">
# <span class="yt-valign-container">
# <span class="thumb"> <span class="video-thumb yt-thumb yt-thumb-20">
# <span class="yt-thumb-square">
# <span class="yt-thumb-clip">
# <img alt="" aria-hidden="true" data-thumb="//yt3.ggpht.com/cRDFsKz6UZUYtKqXM5Kf6Uvjil29ajv43iCaz788nhDfsL0DbQO1dpoGlCR5S-oD2LQEBD2OVw=s20-c-k-c0xffffffff-no-nd-rj" data-ytimg="1" height="20" onload=";window.__ytRIL &amp;&amp; __ytRIL(this)" src="/yts/img/pixel-vfl3z5WfW.gif" width="20"/>
# <span class="vertical-align"></span>
# </span>
# </span>
# </span>
# </span>
# <span class="display-name no-count">
# <span>
#             Jeux vidéo
#           </span>
# </span>
# </span>
# </a>
# </li>
# <li class="vve-check guide-channel guide-notification-item overflowable-list-item" data-visibility-tracking="CAgQtSwYAyITCOLN9OOYgOcCFYqD1QodULUBxg==" id="UClgRkhTL3_hImCAmdLfDE4g-guide-item" role="menuitem">
# <a class="guide-item yt-uix-sessionlink yt-valign spf-link" data-external-id="UClgRkhTL3_hImCAmdLfDE4g" data-serialized-endpoint="0qDduQEaEhhVQ2xnUmtoVEwzX2hJbUNBbWRMZkRFNGc%3D" data-sessionlink="ei=BS8cXo65G6OgxwKZpIqABA&amp;feature=g-channel&amp;ved=CAoQtSwYAyITCM7P8-OYgOcCFSPQUQodGZICQA" data-visibility-tracking="CAgQtSwYAyITCOLN9OOYgOcCFYqD1QodULUBxg==" href="/channel/UClgRkhTL3_hImCAmdLfDE4g" title="Films">
# <span class="yt-valign-container">
# <span class="thumb"> <span class="video-thumb yt-thumb yt-thumb-20">
# <span class="yt-thumb-square">
# <span class="yt-thumb-clip">
# <img alt="" aria-hidden="true" data-thumb="//yt3.ggpht.com/NAxG9tyiFeMjAkktAPSAFFXwxctJe62ycjSCsAw_AW4Bk1CDblULKQqSYGmN7bw1MzTKJOOr=s20-c-k-c0xffffffff-no-nd-rj" data-ytimg="1" height="20" onload=";window.__ytRIL &amp;&amp; __ytRIL(this)" src="/yts/img/pixel-vfl3z5WfW.gif" width="20"/>
# <span class="vertical-align"></span>
# </span>
# </span>
# </span>
# </span>
# <span class="display-name no-count">
# <span>
#             Films
#           </span>
# </span>
# </span>
# </a>
# </li>
# <li class="vve-check guide-channel guide-notification-item overflowable-list-item" data-visibility-tracking="CAcQtSwYBCITCOLN9OOYgOcCFYqD1QodULUBxg==" id="UCl8dMTqDrJQ0c8y23UBu4kQ-guide-item" role="menuitem">
# <a class="guide-item yt-uix-sessionlink yt-valign spf-link" data-external-id="UCl8dMTqDrJQ0c8y23UBu4kQ" data-serialized-endpoint="0qDduQEaEhhVQ2w4ZE1UcURySlEwYzh5MjNVQnU0a1E%3D" data-sessionlink="ei=BS8cXo65G6OgxwKZpIqABA&amp;feature=g-channel&amp;ved=CAsQtSwYBCITCM7P8-OYgOcCFSPQUQodGZICQA" data-visibility-tracking="CAcQtSwYBCITCOLN9OOYgOcCFYqD1QodULUBxg==" href="/channel/UCl8dMTqDrJQ0c8y23UBu4kQ" title="Émissions">
# <span class="yt-valign-container">
# <span class="thumb"> <span class="video-thumb yt-thumb yt-thumb-20">
# <span class="yt-thumb-square">
# <span class="yt-thumb-clip">
# <img alt="" aria-hidden="true" data-thumb="https://yt3.ggpht.com/a/AGF-l7-_-b5OC14l78t-7-qdeVnkwlgz8wPO8IYcFA=s20-c-k-c0xffffffff-no-rj-mo" data-ytimg="1" height="20" onload=";window.__ytRIL &amp;&amp; __ytRIL(this)" src="/yts/img/pixel-vfl3z5WfW.gif" width="20"/>
# <span class="vertical-align"></span>
# </span>
# </span>
# </span>
# </span>
# <span class="display-name no-count">
# <span>
#             Émissions
#           </span>
# </span>
# </span>
# </a>
# </li>
# <li class="vve-check guide-channel guide-notification-item overflowable-list-item" data-visibility-tracking="CAYQtSwYBSITCOLN9OOYgOcCFYqD1QodULUBxg==" id="UCYfdidRxbB8Qhf0Nx7ioOYw-guide-item" role="menuitem">
# <a class="guide-item yt-uix-sessionlink yt-valign spf-link" data-external-id="UCYfdidRxbB8Qhf0Nx7ioOYw" data-serialized-endpoint="0qDduQEaEhhVQ1lmZGlkUnhiQjhRaGYwTng3aW9PWXc%3D" data-sessionlink="ei=BS8cXo65G6OgxwKZpIqABA&amp;feature=g-channel&amp;ved=CAwQtSwYBSITCM7P8-OYgOcCFSPQUQodGZICQA" data-visibility-tracking="CAYQtSwYBSITCOLN9OOYgOcCFYqD1QodULUBxg==" href="/channel/UCYfdidRxbB8Qhf0Nx7ioOYw" title="Actualités">
# <span class="yt-valign-container">
# <span class="thumb"> <span class="video-thumb yt-thumb yt-thumb-20">
# <span class="yt-thumb-square">
# <span class="yt-thumb-clip">
# <img alt="" aria-hidden="true" data-thumb="//yt3.ggpht.com/e65lESfYTZ75XZHf_C5boorDDPi2t6534wyKoTvfeY8ef-YIWVBY-LUcg1V2yzdKn-1Lyyy5=s20-c-k-c0xffffffff-no-nd-rj" data-ytimg="1" height="20" onload=";window.__ytRIL &amp;&amp; __ytRIL(this)" src="/yts/img/pixel-vfl3z5WfW.gif" width="20"/>
# <span class="vertical-align"></span>
# </span>
# </span>
# </span>
# </span>
# <span class="display-name no-count">
# <span>
#             Actualités
#           </span>
# </span>
# </span>
# </a>
# </li>
# <li class="vve-check guide-channel guide-notification-item overflowable-list-item" data-visibility-tracking="CAUQtSwYBiITCOLN9OOYgOcCFYqD1QodULUBxg==" id="UC4R8DWoMoI7CAwX8_LjQHig-guide-item" role="menuitem">
# <a class="guide-item yt-uix-sessionlink yt-valign spf-link" data-external-id="UC4R8DWoMoI7CAwX8_LjQHig" data-serialized-endpoint="0qDduQEaEhhVQzRSOERXb01vSTdDQXdYOF9MalFIaWc%3D" data-sessionlink="ei=BS8cXo65G6OgxwKZpIqABA&amp;feature=g-channel&amp;ved=CA0QtSwYBiITCM7P8-OYgOcCFSPQUQodGZICQA" data-visibility-tracking="CAUQtSwYBiITCOLN9OOYgOcCFYqD1QodULUBxg==" href="/channel/UC4R8DWoMoI7CAwX8_LjQHig" title="En direct">
# <span class="yt-valign-container">
# <span class="thumb"> <span class="video-thumb yt-thumb yt-thumb-20">
# <span class="yt-thumb-square">
# <span class="yt-thumb-clip">
# <img alt="" aria-hidden="true" data-thumb="//yt3.ggpht.com/5HkUAx2SOolanKFGX7Au5O84m4XbzvjpxXowcw2EYjbZmUObb_MzjZiiSDfy3z9ImpC0PCuZIB_dlPnEqQ=s20-c-k-c0xffffffff-no-nd-rj" data-ytimg="1" height="20" onload=";window.__ytRIL &amp;&amp; __ytRIL(this)" src="/yts/img/pixel-vfl3z5WfW.gif" width="20"/>
# <span class="vertical-align"></span>
# </span>
# </span>
# </span>
# </span>
# <span class="display-name no-count">
# <span>
#             En direct
#           </span>
# </span>
# </span>
# </a>
# </li>
# <li class="vve-check guide-channel guide-notification-item overflowable-list-item" data-visibility-tracking="CAQQtSwYByITCOLN9OOYgOcCFYqD1QodULUBxg==" id="UCzuqhhs6NWbgTzMuM09WKDQ-guide-item" role="menuitem">
# <a class="guide-item yt-uix-sessionlink yt-valign spf-link" data-external-id="UCzuqhhs6NWbgTzMuM09WKDQ" data-serialized-endpoint="0qDduQEaEhhVQ3p1cWhoczZOV2JnVHpNdU0wOVdLRFE%3D" data-sessionlink="ei=BS8cXo65G6OgxwKZpIqABA&amp;feature=g-channel&amp;ved=CA4QtSwYByITCM7P8-OYgOcCFSPQUQodGZICQA" data-visibility-tracking="CAQQtSwYByITCOLN9OOYgOcCFYqD1QodULUBxg==" href="/channel/UCzuqhhs6NWbgTzMuM09WKDQ" title="Vidéo à 360°">
# <span class="yt-valign-container">
# <span class="thumb"> <span class="video-thumb yt-thumb yt-thumb-20">
# <span class="yt-thumb-square">
# <span class="yt-thumb-clip">
# <img alt="" aria-hidden="true" data-thumb="//yt3.ggpht.com/Zgo1BGZQlCRsrG6wL4HEvvKB3aE6IE854QPpCtojDOz1P8qjMLhr3NSkoKm3RihqJN5QuKSt=s20-c-k-c0xffffffff-no-nd-rj" data-ytimg="1" height="20" onload=";window.__ytRIL &amp;&amp; __ytRIL(this)" src="/yts/img/pixel-vfl3z5WfW.gif" width="20"/>
# <span class="vertical-align"></span>
# </span>
# </span>
# </span>
# </span>
# <span class="display-name no-count">
# <span>
#             Vidéo à 360°
#           </span>
# </span>
# </span>
# </a>
# </li>
# </ul>
# </div>
# <hr class="guide-section-separator"/>
# </li>
# <li class="guide-section vve-check" data-visibility-tracking="CAEQ5isYAiITCOLN9OOYgOcCFYqD1QodULUBxg==">
# <div class="guide-item-container personal-item">
# <ul class="guide-user-links yt-uix-tdl yt-box" role="menu">
# <li class="vve-check guide-channel guide-notification-item overflowable-list-item" data-visibility-tracking="CAIQtSwYACITCOLN9OOYgOcCFYqD1QodULUBxg==" id="guide_builder-guide-item" role="menuitem">
# <a class="guide-item yt-uix-sessionlink yt-valign spf-link" data-external-id="guide_builder" data-serialized-endpoint="0qDduQEREg9GRWd1aWRlX2J1aWxkZXI%3D" data-sessionlink="ei=BS8cXo65G6OgxwKZpIqABA&amp;feature=g-manage&amp;ved=CBAQtSwYACITCM7P8-OYgOcCFSPQUQodGZICQA" data-visibility-tracking="CAIQtSwYACITCOLN9OOYgOcCFYqD1QodULUBxg==" href="/feed/guide_builder" title="Parcourir les chaînes">
# <span class="yt-valign-container">
# <span class="thumb guide-builder-icon yt-sprite"></span>
# <span class="display-name no-count">
# <span>
#             Parcourir les chaînes
#           </span>
# </span>
# </span>
# </a>
# </li>
# </ul>
# </div>
# <hr class="guide-section-separator"/>
# </li>
# <li class="guide-section guide-header signup-promo">
# <p>
#       Connectez-vous à YouTube pour cliquer sur "J'aime", ajouter un commentaire et vous abonner.
#     </p>
# <div class="signed-out clearfix" id="guide-builder-promo-buttons">
# <a class="yt-uix-button yt-uix-sessionlink yt-uix-button-primary yt-uix-button-size-default" data-sessionlink="ei=BS8cXo65G6OgxwKZpIqABA" href="https://accounts.google.com/ServiceLogin?uilel=3&amp;continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Faction_handle_signin%3Dtrue%26next%3Dhttps%253A%252F%252Fwww.youtube.com%252Fwatch%253Fv%253DQt7ds3MpPEo%26app%3Ddesktop%26feature%3Dsign_in_promo%26hl%3Dfr&amp;passive=true&amp;service=youtube&amp;hl=fr"><span class="yt-uix-button-content">Se connecter</span></a>
# </div>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="hid" id="appbar-guide-notifications">
# <div id="appbar-guide-notification-watch-later-video-added">
# <!--
#     <div class="appbar-guide-notification " role="alert"><span class="appbar-guide-notification-content-wrapper yt-valign"><span class="appbar-guide-notification-icon yt-sprite"></span><span class="appbar-guide-notification-text-content" >Ajoutée à la liste &quot;À regarder plus tard&quot;</span></span></div>
#     -->
# </div>
# <div id="appbar-guide-notification-watch-later-video-removed">
# <!--
#     <div class="appbar-guide-notification " role="alert"><span class="appbar-guide-notification-content-wrapper yt-valign"><span class="appbar-guide-notification-icon yt-sprite"></span><span class="appbar-guide-notification-text-content" >Supprimée des vidéos &quot;À regarder plus tard&quot;.</span></span></div>
#     -->
# </div>
# <div id="appbar-guide-notification-subscription">
# <!--
#     <div class="appbar-guide-notification " role="alert"><span class="appbar-guide-notification-content-wrapper yt-valign"><span class="appbar-guide-notification-icon yt-sprite"></span><span class="appbar-guide-notification-text-content" >Abonnement ajouté.</span></span></div>
#     -->
# </div>
# <div id="appbar-guide-notification-unsubscription">
# <!--
#     <div class="appbar-guide-notification " role="alert"><span class="appbar-guide-notification-content-wrapper yt-valign"><span class="appbar-guide-notification-icon yt-sprite"></span><span class="appbar-guide-notification-text-content" >Abonnement supprimé.</span></span></div>
#     -->
# </div>
# <div id="appbar-guide-notification-playlist-like">
# <!--
#     <div class="appbar-guide-notification " role="alert"><span class="appbar-guide-notification-content-wrapper yt-valign"><span class="appbar-guide-notification-icon yt-sprite"></span><span class="appbar-guide-notification-text-content" >Enregistrée dans Playlists.</span></span></div>
#     -->
# </div>
# <div id="appbar-guide-notification-playlist-unlike">
# <!--
#     <div class="appbar-guide-notification " role="alert"><span class="appbar-guide-notification-content-wrapper yt-valign"><span class="appbar-guide-notification-icon yt-sprite"></span><span class="appbar-guide-notification-text-content" >Supprimée de Playlists.</span></span></div>
#     -->
# </div>
# <div id="appbar-guide-notification-playlist-video-added">
# <!--
#     <div class="appbar-guide-notification " role="alert"><span class="appbar-guide-notification-content-wrapper yt-valign"><span class="appbar-guide-notification-icon yt-sprite"></span><span class="appbar-guide-notification-text-content" >Ajoutée à la playlist</span></span></div>
#     -->
# </div>
# <div id="appbar-guide-notification-playlist-video-removed">
# <!--
#     <div class="appbar-guide-notification " role="alert"><span class="appbar-guide-notification-content-wrapper yt-valign"><span class="appbar-guide-notification-icon yt-sprite"></span><span class="appbar-guide-notification-text-content" >Supprimée de la playlist</span></span></div>
#     -->
# </div>
# <div id="appbar-guide-notification-video-like">
# <!--
#     <div class="appbar-guide-notification " role="alert"><span class="appbar-guide-notification-content-wrapper yt-valign"><span class="appbar-guide-notification-icon yt-sprite"></span><span class="appbar-guide-notification-text-content" >Ajoutée aux vidéos &quot;J&#39;aime&quot;</span></span></div>
#     -->
# </div>
# <div id="appbar-guide-notification-video-unlike">
# <!--
#     <div class="appbar-guide-notification " role="alert"><span class="appbar-guide-notification-content-wrapper yt-valign"><span class="appbar-guide-notification-icon yt-sprite"></span><span class="appbar-guide-notification-text-content" >Supprimée des vidéos &quot;J&#39;aime&quot;</span></span></div>
#     -->
# </div>
# <div id="appbar-guide-notification-event-reminder-set">
# <!--
#     <div class="appbar-guide-notification " role="alert"><span class="appbar-guide-notification-content-wrapper yt-valign"><span class="appbar-guide-notification-icon yt-sprite"></span><span class="appbar-guide-notification-text-content" >Vous recevrez un rappel de la diffusion de cet événement.</span></span></div>
#     -->
# </div>
# <div id="appbar-guide-notification-event-reminder-removed">
# <!--
#     <div class="appbar-guide-notification " role="alert"><span class="appbar-guide-notification-content-wrapper yt-valign"><span class="appbar-guide-notification-icon yt-sprite"></span><span class="appbar-guide-notification-text-content" >Rappel de l&#39;événement supprimé.</span></span></div>
#     -->
# </div>
# </div>
# <div class="hid" id="appbar-guide-item-templates">
# <div id="appbar-guide-item-template-playlist">
# <!--
#
#   <li class="vve-check guide-channel guide-notification-item overflowable-list-item show-insertion-notification " id="__ID__-guide-item"
#  data-visibility-tracking="" role="menuitem">
#
#   <a class="guide-item yt-uix-sessionlink yt-valign spf-nolink    "
#     href="__URL__"
#     title="__TITLE__"
#     data-sessionlink="ei=BS8cXo65G6OgxwKZpIqABA&amp;feature=g-playlists" data-serialized-endpoint="" data-external-id="__ID__" data-visibility-tracking=""
#   >
#     <span class="yt-valign-container">
#         <span class="thumb guide-playlists-icon yt-sprite"></span>
#         <span class="display-name  no-count">
#           <span>
#             __TITLE__
#           </span>
#         </span>
#     </span>
#   </a>
#
#       <div class="appbar-guide-notification guide-item-insertion-notification" role="alert"><span class="appbar-guide-notification-content-wrapper yt-valign"><span class="appbar-guide-notification-icon yt-sprite"></span><span class="appbar-guide-notification-text-content" aria-label="Enregistrée dans Playlists.">__NOTIFICATION_OVERLAY_MESSAGE__</span></span></div>
#   </li>
#
#       -->
# </div>
# <div id="appbar-guide-item-template-mix">
# <!--
#
#   <li class="vve-check guide-channel guide-notification-item overflowable-list-item show-insertion-notification " id="__ID__-guide-item"
#  data-visibility-tracking="" role="menuitem">
#
#   <a class="guide-item yt-uix-sessionlink yt-valign spf-nolink    "
#     href="__URL__"
#     title="__TITLE__"
#     data-sessionlink="ei=BS8cXo65G6OgxwKZpIqABA&amp;feature=g-playlists" data-serialized-endpoint="" data-external-id="__ID__" data-visibility-tracking=""
#   >
#     <span class="yt-valign-container">
#         <span class="thumb guide-mix-icon yt-sprite"></span>
#         <span class="display-name  no-count">
#           <span>
#             __TITLE__
#           </span>
#         </span>
#     </span>
#   </a>
#
#       <div class="appbar-guide-notification guide-item-insertion-notification" role="alert"><span class="appbar-guide-notification-content-wrapper yt-valign"><span class="appbar-guide-notification-icon yt-sprite"></span><span class="appbar-guide-notification-text-content" aria-label="Enregistrée dans Playlists.">__NOTIFICATION_OVERLAY_MESSAGE__</span></span></div>
#   </li>
#
#       -->
# </div>
# <div id="appbar-guide-item-template-channel">
# <!--
#
#   <li class="vve-check guide-channel guide-notification-item overflowable-list-item show-insertion-notification " id="__ID__-guide-item"
#  data-visibility-tracking="" role="menuitem">
#
#   <a class="guide-item yt-uix-sessionlink yt-valign spf-nolink    "
#     href="__URL__"
#     title="__TITLE__"
#     data-sessionlink="ei=BS8cXo65G6OgxwKZpIqABA&amp;feature=g-channel" data-serialized-endpoint="" data-external-id="__ID__" data-visibility-tracking=""
#   >
#     <span class="yt-valign-container">
#         <span class="thumb">  <span class="video-thumb  yt-thumb yt-thumb-20"
#     >
#     <span class="yt-thumb-square">
#       <span class="yt-thumb-clip">
#
#   <img alt="" onload=";window.__ytRIL &amp;&amp; __ytRIL(this)" height="20" data-ytimg="1" width="20" aria-hidden="true" src="__THUMBNAIL_URL__" >
#
#         <span class="vertical-align"></span>
#       </span>
#     </span>
#   </span>
# </span>
#         <span class="display-name  no-count">
#           <span>
#             __TITLE__
#           </span>
#         </span>
#     </span>
#   </a>
#
#       <div class="appbar-guide-notification guide-item-insertion-notification" role="alert"><span class="appbar-guide-notification-content-wrapper yt-valign"><span class="appbar-guide-notification-icon yt-sprite"></span><span class="appbar-guide-notification-text-content" aria-label="Abonnement ajouté.">__NOTIFICATION_OVERLAY_MESSAGE__</span></span></div>
#   </li>
#
#       -->
# </div>
# </div></div><div class="alerts-wrapper"><div class="content-alignment" id="alerts">
# <div id="editor-progress-alert-container"></div>
# <div class="yt-alert yt-alert-default yt-alert-warn hid" id="editor-progress-alert-template"> <div class="yt-alert-icon">
# <span class="icon master-sprite yt-sprite"></span>
# </div>
# <div class="yt-alert-content" role="alert"></div><div class="yt-alert-buttons"><button aria-label="Fermer" class="yt-uix-button yt-uix-button-size-default yt-uix-button-close close yt-uix-close" data-close-parent-class="yt-alert" onclick=";return false;" type="button"><span class="yt-uix-button-content">Fermer</span></button></div></div>
# </div></div><div id="header"></div><div class="content-alignment watch-small" id="player" role="complementary"><div class="player-height" id="theater-background"></div> <div id="player-mole-container">
# <div class="hid player-width player-height player-unavailable" id="player-unavailable">
# <img alt="" class="icon meh" data-icon="/yts/img/meh7-vflGevej7.png" src="/yts/img/pixel-vfl3z5WfW.gif"/>
# <div class="content">
# <h1 class="message" id="unavailable-message">
#               Cette vidéo n'est pas disponible.
#
#     </h1>
# <div class="submessage" id="unavailable-submessage">
# </div>
# </div>
# </div>
# ...
#           'BG_IU': "\/\/www.google.com\/js\/bg\/_mlCwTaS3ftYlLPjiYBUqmaWUIKOu9m_2E9Wu7234aE.js",
#
#         'METADATA_LANGUAGE': 'fr',
#
#
#         'COMMENTS_TOKEN': "EkQSC1F0N2RzM01wUEVvwAEAyAEA4AEBogINKP___________wFAAMICGxoXaHR0cHM6Ly93d3cueW91dHViZS5jb20iABgG",
#
#       'GET_PLAYER_EVENT_ID': "",
#       'HL_LOCALE': "fr_FR",
#       'TTS_URL': "https:\/\/www.youtube.com\/api\/timedtext?v=Qt7ds3MpPEo\u0026asr_langs=de,en,es,fr,it,ja,ko,nl,pt,ru\u0026caps=asr\u0026hl=fr\u0026ip=0.0.0.0\u0026ipbits=0\u0026expire=1578930544\u0026sparams=ip,ipbits,expire,v,asr_langs,caps\u0026signature=B7B221D5316550C7362ED033F5493FAC7234F622.C688B3E3F198DD48096B62D4ADE37F30E0713F11\u0026key=yt8",
#       'JS_DELAY_LOAD': 0,
#       'LIST_AUTO_PLAY_VALUE': 1,
#       'SHUFFLE_VALUE': 0,
#       'SKIP_RELATED_ADS': false,
#       'SKIP_TO_NEXT_VIDEO': false,
#       'CONVERSION_CONFIG_DICT': {},
#       'RESOLUTION_TRACKING_ENABLED': false,
#       'WATCH_LEGAL_TEXT_ENABLE_AUTOSCROLL': false,
#       'ADS_DATA': {"show_afc":false,"show_afv":true,"gut_vars":{"tag":"\\4061\\ytpwmpu"},"show_instream":true,"show_pyv":false,"afc_vars":{"core_dbp":"ChYyQzlZMmRjdUdKdUlqMFhrbkNKTkdnEAEgASgAOAI","pucrd":"APb3F2-OPBWz8PLh1op2R11YROraPD7F0hUF57niwZR0CEQEeOAIGvdvVBSsi5zspLYKKdmVRb3eegGws2b1","ad_block":"2","language":"fr","format":"300x250_as","targeting":"","video_doc_id":"yt_Qt7ds3MpPEo","ad_channel":"0854550287+Vertical_182+Vertical_211+Vertical_3+Vertical_36+Vertical_613+afc_on_page+afv_user_id_yWqModMQlbIo8274Wh_ZsQ+afv_user_monsieurdream+yt_bs3+yt_cid_14744272+yt_gp+yt_mabv+yt_mpvid_bbywIZ2EoESO9gky+yt_no_360+yt_no_ap+yt_no_wa+ytdevice_1+ytdevicever_1.20200108.07.03+ytel_detailpage+ytps_default","loeid":"23795268,23839597,23847204,23848795,23854020,23861503,23861737,23863451,23865511,23866231,23866339,23867270,16021084,9477942","tag_for_child_directed_treatment":"","ad_host":"ca-yt-host-pub-3575961816217993","ad_host_tier_id":"","lact":"-1","eids":[],"ad_client":"ca-pub-6219811747049371","ad_type":"image","alternate_ad_url":"https:\/\/www.youtube.com\/ad_frame?id=watch-channel-brand-div"},"afv_vars":{"google_scs":"","google_eids":[],"google_ad_client":"ca-pub-6219811747049371","google_ad_host":"ca-yt-host-pub-3575961816217993","google_tag_for_child_directed_treatment":"","google_cust_gender":"","google_ad_height":"250","google_video_doc_id":"yt_Qt7ds3MpPEo","google_yt_pt":"APb3F29z4zbWxhP87CQWdVF-6wAEep4gKRMGOJeanzOb6VkIWwLRLmBzvsH9nUBy-J4mzr3dNtICGi7jJMH0S0HTmBwUO_8O5Wax92_7JKKdYvaPaefc2UOtf691A5denYD7DQQQ513ZXwEXLjT2SUrWWXEOmCWhl_7lL0mWTb9nJFMpm9dSmcQRbetbcEaHuJUfZNgcY7i96v0L5-xz","google_alternate_ad_url":"https:\/\/www.youtube.com\/ad_frame?id=watch-channel-brand-div","google_ad_channel":"0854550288+Vertical_182+Vertical_211+Vertical_3+Vertical_36+Vertical_613+afv_user_id_yWqModMQlbIo8274Wh_ZsQ+afv_user_monsieurdream+yt_bs3+yt_cid_14744272+yt_gp+yt_mabv+yt_mpvid_bbywIZ2EoESO9gky+yt_no_360+yt_no_ap+yt_no_wa+ytdevice_1+ytdevicever_1.20200108.07.03+ytel_detailpage+ytps_default","google_lact":"-1","google_page_url":"http:\/\/www.youtube.com\/video\/Qt7ds3MpPEo","google_ad_format":"300x250_as","google_cust_age":"","google_language":"fr","google_ad_block":"2","google_loeid":"23795268,23839597,23847204,23848795,23854020,23861503,23861737,23863451,23865511,23866231,23866339,23867270,16021084,9477942","google_core_dbp":"ChYyQzlZMmRjdUdKdUlqMFhrbkNKTkdnEAEgASgAOAI","google_ad_host_tier_id":"","google_targeting":"","google_ad_type":"image","google_pucrd":"APb3F2-OPBWz8PLh1op2R11YROraPD7F0hUF57niwZR0CEQEeOAIGvdvVBSsi5zspLYKKdmVRb3eegGws2b1"},"use_gut":true,"check_status":false},
#       'PLAYBACK_ID': "AAWcAYw2CzneZ6cb",
#       'IS_DISTILLER': true,
#       'SHARE_CAPTION': null,
#       'SHARE_REFERER': "",
#       'PLAYLIST_INDEX': null
#     });
#
#
#     yt.setMsg({
#       'EDITOR_AJAX_REQUEST_FAILED': "Une erreur s\u0026#39;est produite lors de l\u0026#39;obtention des données à partir du serveur. Veuillez réessayer ou actualisez la page.",
#       'EDITOR_AJAX_REQUEST_503': "Cette fonctionnalité n\u0026#39;est pas disponible pour le moment. Veuillez réessayer ultérieurement.",
#         'HTML5_SUBS_ASR': "sous-titres automatiques",
#         'CC_ADD_TRANSCRIPT_TITLE': "Ajouter des sous-titres",
#       'LOADING': "Chargement en cours…"    });
#
#
#
#
#       yt.setConfig({
#     'GUIDED_HELP_LOCALE': "fr_FR",
#     'GUIDED_HELP_ENVIRONMENT': "prod"
#   });
#
#   </script>
# <script>yt.setConfig({INNERTUBE_CONTEXT_CLIENT_NAME: 1,GAPI_HINT_PARAMS: "m;\/_\/scs\/abc-static\/_\/js\/k=gapi.gapi.en.MEVzAPCznC8.O\/d=1\/ct=zgms\/rs=AHpOoo_iL6i3Fuh5d3bLKRBazYvzpKjkxg\/m=__features__",INNERTUBE_CONTEXT_CLIENT_VERSION: "1.20200108.07.03",INNERTUBE_API_KEY: "AIzaSyAO_FJ2SlqU8Q4STEHLGCilw_Y9_11qcW8",INNERTUBE_API_VERSION: "v1",'VISITOR_DATA': "CgtIcFJsMWZtdHNVNCiA3vDwBQ%3D%3D",'DELEGATED_SESSION_ID': null,'GAPI_HOST': "https:\/\/apis.google.com",'GAPI_LOCALE': "fr_FR",'INNERTUBE_CONTEXT_HL': "fr",'INNERTUBE_CONTEXT_GL': "FR",'XHR_APIARY_HOST': "youtubei.youtube.com"});yt.setConfig({'PAGE_NAME': "watch",'LOGGED_IN': false,'SESSION_INDEX': null,'VALID_SESSION_TEMPDATA_DOMAINS': ["www.youtube.com","gaming.youtube.com"],'PARENT_TRACKING_PARAMS': "",'FORMATS_FILE_SIZE_JS': ["%s octets","%s Ko","%s Mo","%s Go","%s To"],'ONE_PICK_URL': "",'GOOGLEPLUS_HOST': "https:\/\/plus.google.com",'PAGEFRAME_JS': "\/yts\/jsbin\/www-pageframe-vflPMvchQ\/www-pageframe.js",'GAPI_LOADER_URL': "\/yts\/jsbin\/www-gapi-loader-vflX6I5Bf\/www-gapi-loader.js",'JS_COMMON_MODULE': "\/yts\/jsbin\/www-en_US-vflf34fHi\/common.js",'PAGE_FRAME_DELAYLOADED_CSS': "\/yts\/cssbin\/www-pageframedelayloaded-vflZQkKIB.css",'EXPERIMENT_FLAGS': {"desktop_polymer_video_masthead_always_use_responsive_iframe":true,"log_window_onerror_fraction":0.1,"enable_ve_tracker_key":true,"disable_legacy_desktop_remote_queue_watch":true,"botguard_periodic_refresh":true,"gfeedback_for_signed_out_users_enabled":true,"desktop_videowall_companion_wta_support":true,"web_logging_max_batch":100,"desktop_notification_set_title_bar":true,"service_worker_push_logged_out_prompt_watches":-1,"web_gel_timeout_cap":true,"service_worker_push_force_notification_prompt_tag":"1","enable_watch_next_pause_autoplay_lact":true,"desktop_pyv_on_watch_missing_params":true,"ignore_empty_xhr":true,"autoplay_pause_by_lact_sec":0,"web_post_search":true,"should_clear_video_data_on_player_cued_unstarted":true,"log_web_meta_interval_ms":0,"desktop_action_companion_wta_support":true,"autoplay_pause_by_lact_sampling_fraction":0.0,"disable_legacy_desktop_remote_queue":true,"web_gel_debounce_ms":10000,"desktop_polymer_video_masthead_session_tempdata_ttl":30,"no_sub_count_on_sub_button":true,"mdx_enable_privacy_disclosure_ui":true,"desktop_pyv_on_watch_override_lact":true,"desktop_image_companion_wta_support":true,"cancel_pending_navs":true,"use_watch_fragments2":true,"live_chat_client_url":true,"service_worker_push_watch_page_prompt":true,"web_use_beacon_api_for_ad_click_server_pings":true,"autoescape_tempdata_url":true,"custom_csi_timeline_use_gel":true,"watch_next_pause_autoplay_lact_sec":4500,"prefetch_comments_ms_after_video":0,"service_worker_push_prompt_delay_microseconds":3888000000000,"app_settings_snapshot_min_time_between_snapshots_hours":24,"service_worker_enabled":true,"service_worker_scope":"\/","enable_ypc_spinners":true,"warm_load_nav_start_web":true,"live_chat_increased_min_height":true,"enable_premium_voluntary_pause":true,"web_always_load_chat_support":true,"live_chat_unicode_emoji_json_url":"https:\/\/www.gstatic.com\/youtube\/img\/emojis\/emojis-svg-1.json","service_worker_push_enabled":true,"kevlar_guide_refresh":true,"update_super_chat_moderation":true,"desktop_shopping_companion_wta_support":true,"retry_web_logging_batches":true,"service_worker_push_prompt_cap":-1,"desktop_notification_high_priority_ignore_push":true,"log_vis_on_tab_change":true,"pass_biscotti_id_in_header_ajax":true,"web_system_health_fraction":0.01,"consent_url_override":"","enable_read_more_format_decoration":true,"service_worker_push_home_page_prompt":true,"enable_docked_chat_messages":true},'GUIDE_DELAY_LOAD': true,'GUIDE_DELAYLOADED_CSS': "\/yts\/cssbin\/www-guide-vflybhooe.css",'GUIDED_HELP_PARAMS': {"logged_in":"0"},'HIGH_CONTRAST_MODE_CSS': "\/yts\/cssbin\/www-highcontrastmode-vfl2pKdoC.css",'PREFETCH_LINKS': false,'PREFETCH_LINKS_MAX': 1,'PREFETCH_AUTOPLAY': false,'PREFETCH_AUTOPLAY_TIME': 0,'PREFETCH_AUTONA ...
#     'GUIDED_HELP_LOCALE': "fr_FR",
#     'GUIDED_HELP_ENVIRONMENT': "prod"
#   });
# yt.setConfig('SPF_SEARCH_BOX', true);yt.setMsg({'ADDTO_CREATE_NEW_PLAYLIST': "Créer une playlist\n",'ADDTO_CREATE_PLAYLIST_DYNAMIC_TITLE': "  $dynamic_title_placeholder (créer)\n",'ADDTO_WATCH_LATER': "Watch later",'ADDTO_WATCH_LATER_ADDED': "Ajoutée",'ADDTO_WATCH_LATER_ERROR': "Erreur",'ADDTO_WATCH_QUEUE': "Watch Queue",'ADDTO_WATCH_QUEUE_ADDED': "Ajoutée",'ADDTO_WATCH_QUEUE_ERROR': "Erreur",'ADDTO_TV_QUEUE': "Queue",'MASTHEAD_NOTIFICATIONS_LABEL': {"other": "#\u00a0notifications non lues.", "case1": "1\u00a0notification non lue.", "case0": "Aucune notification non lue.", "one": "#\u00a0notification non lue."},'MASTHEAD_NOTIFICATIONS_COUNT_99PLUS': "\u0026gt; 99",'MDX_AUTOPLAY_OFF': 'Lecture automatique désactivée','MDX_AUTOPLAY_ON': 'Lecture automatique activée'});  yt.setConfig('FEED_PRIVACY_CSS_URL', "\/yts\/cssbin\/www-feedprivacydialog-vfltb5-JE.css");
#   yt.setConfig('FEED_PRIVACY_LIGHTBOX_ENABLED', true);
# yt.setConfig({'SBOX_JS_URL': "\/yts\/jsbin\/www-searchbox-vflyG4gaq\/www-searchbox.js",'SBOX_SETTINGS': {"PSUGGEST_TOKEN":null,"PQ":"","IS_FUSION":false,"REQUEST_DOMAIN":"fr","HAS_ON_SCREEN_KEYBOARD":false,"REQUEST_LANGUAGE":"fr","SESSION_INDEX":null,"SUGG_EXP_ID":""},'SBOX_LABELS': {"SUGGESTION_DISMISS_LABEL":"Supprimer","SUGGESTION_DISMISSED_LABEL":"Suggestion supprimée"}});  yt.setConfig({
#     'YPC_LOADER_JS': "\/yts\/jsbin\/www-ypc-vflYFn1AH\/www-ypc.js",
#     'YPC_LOADER_CSS': "\/yts\/cssbin\/www-ypc-vflx_KJhA.css",
#     'YPC_SIGNIN_URL': "https:\/\/accounts.google.com\/ServiceLogin?continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Fapp%3Ddesktop%26action_handle_signin%3Dtrue%26hl%3Dfr%26next%3D%252F\u0026passive=true\u0026service=youtube\u0026hl=fr\u0026uilel=3",
#     'DBLCLK_ADVERTISER_ID': "2542116",
#     'DBLCLK_YPC_ACTIVITY_GROUP': "youtu444",
#     'SUBSCRIPTION_URL': "\/subscription_ajax",
#     'YPC_SWITCH_URL': "\/signin?skip_identity_prompt=True\u0026action_handle_signin=true\u0026next=%2F\u0026feature=purchases",
#     'YPC_GB_LANGUAGE': "fr_FR",
#     'YPC_MB_URL': "https:\/\/payments.youtube.com\/payments\/v4\/js\/integrator.js?ss=md",
#     'YPC_TRANSACTION_URL': "\/transaction_handler",
#     'YPC_SUBSCRIPTION_URL': "\/ypc_subscription_ajax",
#     'YPC_POST_PURCHASE_URL': "\/ypc_post_purchase_ajax",
#     'YTR_FAMILY_CREATION_URL': "https:\/\/families.google.com\/webcreation?usegapi=1",
#     'YTO_GTM_DATA': {'event': 'purchased', 'purchaseStatus': 'success'},
#     'YTO_GTM_1_BUTTON_CLICK_DATA': {'event': 'landingButtonClick', 'buttonPosition': '1'},
#     'YTO_GTM_2_BUTTON_CLICK_DATA': {'event': 'landingButtonClick', 'buttonPosition': '2'}
#   });
#   yt.setMsg({
#     'YPC_OFFER_OVERLAY': "  \n",
#     'YPC_UNSUBSCRIBE_OVERLAY': "  \n"
#   });
#   yt.setConfig('GOOGLE_HELP_CONTEXT', "watch");
# ytcsi.info('st', 272);ytcfg.set({"TIMING_INFO":{"c":"WEB","GetPlayer_rid":"0x716dfee3d4ab6407","yt_pl":0,"yt_lt":"cold","yt_li":"0","yt_ad":"1","GetWatchNext_rid":"0x716dfee3d4ab6407","cver":"1.20200108.07.03"},"CSI_SERVICE_NAME":"youtube"});;ytcfg.set({"TIMING_ACTION":"watch","CSI_VIEWPORT":true});;  yt.setConfig({
#       'XSRF_TOKEN': "",
#       'XSRF_FIELD_NAME': "session_token",
#
#       'XSRF_REDIRECT_TOKEN': "notWx-_gxTltu8ocZceISxsJlW98MTU3ODk5MTc0NUAxNTc4OTA1MzQ1"  });
# yt.setConfig('ID_TOKEN', null);window.ytcfg.set('SERVICE_WORKER_KILLSWITCH', false);  yt.setConfig('THUMB_DELAY_LOAD_BUFFER', 0);
# if (window.ytcsi) {window.ytcsi.tick("jl", null, '');}</script>
# </body></html>

# %%
list_Videos[17]
# Out:
# 'https://www.youtube.com/watch?v=8A0zP9E6tjM'

# %%
SoupCréeJS
# Out:
# <!DOCTYPE html>
# <html data-cast-api-enabled="true" lang="fr-FR"><head><style name="www-roboto">@font-face{font-family:'Roboto';font-style:normal;font-weight:400;src:local('Roboto Regular'),local('Roboto-Regular'),url(//fonts.gstatic.com/s/roboto/v18/KFOmCnqEu92Fr1Mu4mxP.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:500;src:local('Roboto Medium'),local('Roboto-Medium'),url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmEU9fBBc9.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:italic;font-weight:400;src:local('Roboto Italic'),local('Roboto-Italic'),url(//fonts.gstatic.com/s/roboto/v18/KFOkCnqEu92Fr1Mu51xIIzc.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:italic;font-weight:500;src:local('Roboto Medium Italic'),local('Roboto-MediumItalic'),url(//fonts.gstatic.com/s/roboto/v18/KFOjCnqEu92Fr1Mu51S7ACc6CsE.ttf)format('truetype');}</style><script name="www-roboto">if (document.fonts && document.fonts.load) {document.fonts.load("400 10pt Roboto", "F");document.fonts.load("500 10pt Roboto", "F");}</script><script>var ytcsi = {gt: function(n) {n = (n || '') + 'data_';return ytcsi[n] || (ytcsi[n] = {tick: {},info: {}});},now: (window.performance && window.performance.timing &&window.performance.now && window.performance.timing.navigationStart) ?function() {return window.performance.timing.navigationStart +window.performance.now();} :function() {return (new Date()).getTime();},tick: function(l, t, n) {ticks = ytcsi.gt(n).tick;var v = t || ytcsi.now();if (ticks[l]) {ticks['_' + l] = (ticks['_' + l] || [ticks[l]]);ticks['_' + l].push(v);}ticks[l] = v;},info: function(k, v, n) {ytcsi.gt(n).info[k] = v;},setStart: function(s, t, n) {ytcsi.info('yt_sts', s, n);ytcsi.tick('_start', t, n);}};(function(w, d) {ytcsi.setStart('dhs', w.performance ? w.performance.timing.responseStart : null);var isPrerender = (d.visibilityState || d.webkitVisibilityState) == 'prerender';var vName = (!d.visibilityState && d.webkitVisibilityState)? 'webkitvisibilitychange' : 'visibilitychange';if (isPrerender) {ytcsi.info('prerender', 1);var startTick = function() {ytcsi.setStart('dhs');d.removeEventListener(vName, startTick);};d.addEventListener(vName, startTick, false);}if (d.addEventListener) {d.addEventListener(vName, function() {ytcsi.tick('vc');}, false);}function isGecko() {if (!w.navigator || !w.navigator.userAgent) {return false;}var ua = w.navigator.userAgent;return ua.indexOf('Gecko') > 0 &&ua.toLowerCase().indexOf('webkit') < 0 &&ua.indexOf('Edge') < 0 &&ua.indexOf('Trident') < 0 &&ua.indexOf('MSIE') < 0;}if (isGecko()) {var isHidden = (d.visibilityState || d.webkitVisibilityState) == 'hidden';if (isHidden) {ytcsi.tick('vc');}}var slt = function(el, t) {setTimeout(function() {var n = ytcsi.now();el.loadTime = n;if (el.slt) {el.slt();}}, t);};w.__ytRIL = function(el) {if (!el.getAttribute('data-thumb')) {if (w.requestAnimationFrame) {w.requestAnimationFrame(function() {slt(el, 0);});} else {slt(el, 16);}}};})(window, document);</script><script>var ytcfg = {d: function() {return (window.yt && yt.config_) || ytcfg.data_ || (ytcfg.data_ = {});},get: function(k, o) {return (k in ytcfg.d()) ? ytcfg.d()[k] : o;},set: function() {var a = arguments;if (a.length > 1) {ytcfg.d()[a[0]] = a[1];} else {for (var k in a[0]) {ytcfg.d()[k] = a[0][k];}}}};</script> <script>ytcfg.set("ROOT_VE_TYPE", 3832);ytcfg.set("EVENT_ID", "7jEcXorPKOrmhAeJ7JqAAw");</script>
# <script>ytcfg.set("LACT", null);</script>
# <script>window.yterr = window.yterr || true;</script>
# <script>
#         (function(){/*
#
#  Copyright The Closure Library Authors.
#  SPDX-License-Identifier: Apache-2.0
# */
# var a={a:"content-snap-width-1",b:"content-snap-width-2",f:"content-snap-width-3"};function f(){var c=[],b;for(b in a)c.push(a[b]);return c}
# function h(c){var b=f().concat(["guide-pinned","show-guide"]),d=b.length,g=[];c.replace(/\S+/g,function(e){for(var k=0;k<d;k++)if(e==b[k])return;g.push(e)});
# return g}
# ;function l(c,b,d){var g=document.getElementsByTagName("html")[0],e=h(g.className);c&&1251<=(window.innerWidth||document.documentElement.clientWidth)&&(e.push("guide-pinned"),b&&e.push("show-guide"));d&&(d=(window.innerWidth||document.documentElement.clientWidth)-21-50,1251<=(window.innerWidth||document.documentElement.clientWidth)&&c&&b&&(d-=230),e.push(1262<=d?"content-snap-width-3":1056<=d?"content-snap-width-2":"content-snap-width-1"));g.className=e.join(" ")}
# var m=["yt","www","masthead","sizing","runBeforeBodyIsReady"],n=this||self;m[0]in n||"undefined"==typeof n.execScript||n.execScript("var "+m[0]);for(var p;m.length&&(p=m.shift());)m.length||void 0===l?n[p]&&n[p]!==Object.prototype[p]?n=n[p]:n=n[p]={}:n[p]=l;}).call(this);
#
#       try {window.ytbuffer = {};ytbuffer.handleClick = function(e) {var element = e.target || e.srcElement;while (element.parentElement) {if (/(^| )yt-can-buffer( |$)/.test(element.className)) {window.ytbuffer = {bufferedClick: e};element.className += ' yt-is-buffered';break;}element = element.parentElement;}};if (document.addEventListener) {document.addEventListener('click', ytbuffer.handleClick);} else {document.attachEvent('onclick', ytbuffer.handleClick);}} catch(e) {}
#
#     yt.www.masthead.sizing.runBeforeBodyIsReady(false,false,true);
#   </script>
# <script name="scheduler/scheduler" src="/yts/jsbin/scheduler-vflcHH6r0/scheduler.js" type="text/javascript"></script>
# <script>var ytimg = {};ytimg.count = 1;ytimg.preload = function(src) {var img = new Image();var count = ++ytimg.count;ytimg[count] = img;img.onload = img.onerror = function() {delete ytimg[count];};img.src = src;};</script>
# <script async="" name="www-pagead-id/www-pagead-id" src="/yts/jsbin/www-pagead-id-vfl89tyv3/www-pagead-id.js" type="text/javascript"></script>
# <script name="player_ias/base" src="/yts/jsbin/player_ias-vflJiqSE7/fr_FR/base.js"></script>
# <link href="/yts/cssbin/www-core-vflRlRixQ.css" name="www-core" rel="stylesheet"/>
# <link href="/yts/cssbin/player-vfl0tglhl/www-player.css" name="player/www-player" rel="stylesheet"/>
# <link href="/yts/cssbin/www-pageframe-vfldKQBmr.css" name="www-pageframe" rel="stylesheet"/>
# <script>ytimg.preload("https:\/\/r2---sn-gx1v2vax-atne.googlevideo.com\/generate_204?conn2");ytimg.preload("https:\/\/r2---sn-gx1v2vax-atne.googlevideo.com\/generate_204");</script>
# <title>Mahan Air A340-600 Business Class - What's Iranian Airline Like? - YouTube</title><link href="https://www.youtube.com/watch?v=_ejGGpW1YxE" rel="canonical"/><link href="https://m.youtube.com/watch?v=_ejGGpW1YxE" media="handheld" rel="alternate"/><link href="https://m.youtube.com/watch?v=_ejGGpW1YxE" media="only screen and (max-width: 640px)" rel="alternate"/> <meta content="Mahan Air A340-600 Business Class - What's Iranian Airline Like?" name="title"/>
# <meta content="Follow me on Mahan Air A340-600 from Kuala Lumpur to Tehran Imam Khomeini Int'l Airport. Find out what's the Business Class is like on an Iranian Airline. A ..." name="description"/>
# <meta content="Mahan Air, Sam Chui, Mahan Air A340-600, Mahan Air Business Class, Mahan Air Economy Class, Sam Chui Trip Report, Imam Khomeini International Airport, CIP Te..." name="keywords"/>
# <link href="/manifest.json" rel="manifest"/><link href="https://youtu.be/_ejGGpW1YxE" rel="shortlink"/><link href="https://www.youtube.com/opensearch?locale=fr_FR" rel="search" title="Recherche de vidÃ©os YouTube" type="application/opensearchdescription+xml"/><link href="https://s.ytimg.com/yts/img/favicon-vfl8qSV2F.ico" rel="shortcut icon" type="image/x-icon"/> <link href="/yts/img/favicon_32-vflOogEID.png" rel="icon" sizes="32x32"/><link href="/yts/img/favicon_48-vflVjB_Qk.png" rel="icon" sizes="48x48"/><link href="/yts/img/favicon_96-vflW9Ec0w.png" rel="icon" sizes="96x96"/><link href="/yts/img/favicon_144-vfliLAfaB.png" rel="icon" sizes="144x144"/><meta content="#ff0000" name="theme-color"/> <link href="android-app://com.google.android.youtube/http/www.youtube.com/watch?v=_ejGGpW1YxE" rel="alternate"/>
# <link href="ios-app://544007664/vnd.youtube/www.youtube.com/watch?v=_ejGGpW1YxE" rel="alternate"/>
# <link href="http://www.youtube.com/oembed?format=json&amp;url=https%3A%2F%2Fwww.youtube.com%2Fwatch%3Fv%3D_ejGGpW1YxE" rel="alternate" title="Mahan Air A340-600 Business Class - What's Iranian Airline Like?" type="application/json+oembed"/>
# <link href="http://www.youtube.com/oembed?format=xml&amp;url=https%3A%2F%2Fwww.youtube.com%2Fwatch%3Fv%3D_ejGGpW1YxE" rel="alternate" title="Mahan Air A340-600 Business Class - What's Iranian Airline Like?" type="text/xml+oembed"/>
# <meta content="YouTube" property="og:site_name"/>
# <meta content="https://www.youtube.com/watch?v=_ejGGpW1YxE" property="og:url"/>
# <meta content="Mahan Air A340-600 Business Class - What's Iranian Airline Like?" property="og:title"/>
# <meta content="https://i.ytimg.com/vi/_ejGGpW1YxE/maxresdefault.jpg" property="og:image"/>
# <meta content="1280" property="og:image:width"/>
# <meta content="720" property="og:image:height"/>
# <meta content="Follow me on Mahan Air A340-600 from Kuala Lumpur to Tehran Imam Khomeini Int'l Airport. Find out what's the Business Class is like on an Iranian Airline. A ..." property="og:description"/>
# <meta content="544007664" property="al:ios:app_store_id"/>
# <meta content="YouTube" property="al:ios:app_name"/>
# <meta content="vnd.youtube://www.youtube.com/watch?v=_ejGGpW1YxE&amp;feature=applinks" property="al:ios:url"/>
# <meta content="vnd.youtube://www.youtube.com/watch?v=_ejGGpW1YxE&amp;feature=applinks" property="al:android:url"/>
# <meta content="YouTube" property="al:android:app_name"/>
# <meta content="com.google.android.youtube" property="al:android:package"/>
# <meta content="https://www.youtube.com/watch?v=_ejGGpW1YxE&amp;feature=applinks" property="al:web:url"/>
# <meta content="video.other" property="og:type"/>
# <meta content="https://www.youtube.com/embed/_ejGGpW1YxE" property="og:video:url"/>
# <meta content="https://www.youtube.com/embed/_ejGGpW1YxE" property="og:video:secure_url"/>
# <meta content="text/html" property="og:video:type"/>
# <meta content="1280" property="og:video:width"/>
# <meta content="720" property="og:video:height"/>
# <meta content="Mahan Air" property="og:video:tag"/>
# <meta content="Sam Chui" property="og:video:tag"/>
# <meta content="Mahan Air A340-600" property="og:video:tag"/>
# <meta content="Mahan Air Business Class" property="og:video:tag"/>
# <meta content="Mahan Air Economy Class" property="og:video:tag"/>
# <meta content="Sam Chui Trip Report" property="og:video:tag"/>
# <meta content="Imam Khomeini International Airport" property="og:video:tag"/>
# <meta content="CIP Terminal IKA" property="og:video:tag"/>
# <meta content="CIP Terminal Tehran Airport" property="og:video:tag"/>
# <meta content="Mahan Air A340-300" property="og:video:tag"/>
# <meta content="Airbus A340-600" property="og:video:tag"/>
# <meta content="Airbus 340" property="og:video:tag"/>
# <meta content="Air Asia Flight Review" property="og:video:tag"/>
# <meta content="Coral Lounge Don Muang Bangkok" property="og:video:tag"/>
# <meta content="87741124305" property="fb:app_id"/>
# <meta content="player" name="twitter:card"/>
# <meta content="@youtube" name="twitter:site"/>
# <meta content="https://www.youtube.com/watch?v=_ejGGpW1YxE" name="twitter:url"/>
# <meta content="Mahan Air A340-600 Business Class - What's Iranian Airline Like?" name="twitter:title"/>
# <meta content="Follow me on Mahan Air A340-600 from Kuala Lumpur to Tehran Imam Khomeini Int'l Airport. Find out what's the Business Class is like on an Iranian Airline. A ..." name="twitter:description"/>
# <meta content="https://i.ytimg.com/vi/_ejGGpW1YxE/maxresdefault.jpg" name="twitter:image"/>
# <meta content="YouTube" name="twitter:app:name:iphone"/>
# <meta content="544007664" name="twitter:app:id:iphone"/>
# <meta content="YouTube" name="twitter:app:name:ipad"/>
# <meta content="544007664" name="twitter:app:id:ipad"/>
# <meta content="vnd.youtube://www.youtube.com/watch?v=_ejGGpW1YxE&amp;feature=applinks" name="twitter:app:url:iphone"/>
# <meta content="vnd.youtube://www.youtube.com/watch?v=_ejGGpW1YxE&amp;feature=applinks" name="twitter:app:url:ipad"/>
# <meta content="YouTube" name="twitter:app:name:googleplay"/>
# <meta content="com.google.android.youtube" name="twitter:app:id:googleplay"/>
# <meta content="https://www.youtube.com/watch?v=_ejGGpW1YxE" name="twitter:app:url:googleplay"/>
# <meta content="https://www.youtube.com/embed/_ejGGpW1YxE" name="twitter:player"/>
# <meta content="1280" name="twitter:player:width"/>
# <meta content="720" name="twitter:player:height"/>
# <link href="/yts/cssbin/www-watch-transcript-vflp9_n_i.css" name="www-watch-transcript" rel="stylesheet"/>
# <style>.exp-invert-logo .hats-logo {background: no-repeat url(/yts/img/ringo/hitchhiker/logo_mini_gray-vflfanGkh.png);width: 65px;height: 15px;}.exp-invert-logo #header:before,.exp-invert-logo .ypc-join-family-header .logo,.exp-invert-logo #footer-logo .footer-logo-icon,.exp-invert-logo #yt-masthead #logo-container .logo,.exp-invert-logo #masthead #logo-container,.exp-invert-logo .admin-masthead-logo a,.exp-invert-logo #yt-sidebar-styleguide-logo #logo {background: no-repeat url(/yts/img/ringo/hitchhiker/logo_small-vflHpzGZm.png);width: 100px;height: 30px;}.exp-invert-logo.inverted-hdpi #header:before,.exp-invert-logo.inverted-hdpi .ypc-join-family-header .logo,.exp-invert-logo.inverted-hdpi #footer-logo .footer-logo-icon,.exp-invert-logo.inverted-hdpi #yt-masthead #logo-container .logo,.exp-invert-logo.inverted-hdpi #masthead #logo-container,.exp-invert-logo.inverted-hdpi .admin-masthead-logo a,.exp-invert-logo.inverted-hdpi #yt-sidebar-styleguide-logo #logo {background: no-repeat url(/yts/img/ringo/hitchhiker/logo_small_2x-vfl4_cFqn.png);background-size: 100px 30px;width: 100px;height: 30px;}.exp-invert-logo.exp-fusion-nav-redesign .masthead-logo-renderer-logo {background: no-repeat url(/yts/img/ringo/hitchhiker/yt_play_logo-vflLfk4yD.png);width: 40px;height: 28px;}.exp-invert-logo.inverted-hdpi.exp-fusion-nav-redesign .masthead-logo-renderer-logo {background: no-repeat url(/yts/img/ringo/hitchhiker/yt_play_logo_2x-vflXx5Pg3.png);width: 40px;height: 28px;}@media screen and (max-width: 656px) {.exp-invert-logo #yt-masthead #logo-container .logo {background: no-repeat url(/yts/img/ringo/hitchhiker/yt_play_logo-vflLfk4yD.png);width: 40px;height: 28px;}.exp-invert-logo.inverted-hdpi #yt-masthead #logo-container .logo {background: no-repeat url(/yts/img/ringo/hitchhiker/yt_play_logo_2x-vflXx5Pg3.png);background-size: 40px 28px;width: 40px;height: 28px;}}@media only screen and (min-width: 0px) and (max-width: 498px),only screen and (min-width: 499px) and (max-width: 704px) {.exp-invert-logo.exp-responsive #yt-masthead #logo-container {background: no-repeat url(/yts/img/ringo/hitchhiker/yt_play_logo-vflLfk4yD.png);width: 40px;height: 28px;}.exp-invert-logo.inverted-hdpi.exp-responsive #yt-masthead #logo-container {background: no-repeat url(/yts/img/ringo/hitchhiker/yt_play_logo_2x-vflXx5Pg3.png);background-size: 40px 28px;width: 40px;height: 28px;}}.exp-invert-logo #yt-masthead #logo-container .logo-red {background: no-repeat url(/yts/img/ringo/hitchhiker/logo_youtube_red-vflZxcSR1.png);width: 132px;height: 30px;}.exp-invert-logo.inverted-hdpi #yt-masthead #logo-container .logo-red {background: no-repeat url(/yts/img/ringo/hitchhiker/logo_youtube_red_2x-vflOSHA_n.png);background-size: 132px 30px;width: 132px;height: 30px;}.exp-invert-logo #yt-masthead #logo-container .logo-premium {background: no-repeat url(/yts/img/ringo/hitchhiker/logo_youtube_premium-vfltrvziB.png);width: 108px;height: 30px;}.exp-invert-logo.inverted-hdpi #yt-masthead #logo-container .logo-premium {background: no-repeat url(/yts/img/ringo/hitchhiker/logo_youtube_premium_2x-vflxcbz_g.png);background-size: 108px 30px;width: 108px;height: 30px;}.exp-invert-logo .guide-item .guide-video-youtube-red-icon {background: no-repeat url(/yts/img/ringo/hitchhiker/video_youtube_red-vflovGTdz.png);width: 20px;height: 20px;}.exp-invert-logo.inverted-hdpi .guide-item .guide-video-youtube-red-icon {background: no-repeat url(/yts/img/ringo/hitchhiker/video_youtube_red_2x-vflqMdgEM.png);background-size: 20px 20px;width: 20px;height: 20px;}.exp-invert-logo .guide-item:hover .guide-video-youtube-red-icon,.exp-invert-logo .guide-item.guide-item-selected .guide-video-youtube-red-icon {background: no-repeat url(/yts/img/ringo/hitchhiker/video_youtube_red_hover-vflgV4Gv0.png);width: 20px;height: 20px;}.exp-invert-logo.inverted-hdpi .guide-item:hover .guide-video-youtube-red-icon,.exp-invert-logo.inverted-hdpi .guide-item.guide-item-selected .guide-video-youtube-red-icon {background: no- ...
# <div id="early-body"></div><div id="body-container"><div id="a11y-announcements-container" role="alert"><div id="a11y-announcements-message"></div></div><form action="/logout" method="POST" name="logoutForm"><input name="action_logout" type="hidden" value="1"/></form><div id="masthead-positioner"> <div id="ticker-content">
# </div>
# <div class="clearfix yt-base-gutter" id="yt-masthead-container"> <button class="skip-nav" data-target-id="main" id="a11y-skip-nav" tabindex="3">
# Ignorer les liens de navigation
#   </button>
# <div id="yt-masthead"><div class="yt-masthead-logo-container"> <button aria-controls="appbar-guide-menu" aria-label="Guide" class="yt-uix-button yt-uix-button-size-default yt-uix-button-text yt-uix-button-empty yt-uix-button-has-icon appbar-guide-toggle appbar-guide-clickable-ancestor" id="appbar-guide-button" onclick=";return false;" type="button"><span class="yt-uix-button-icon-wrapper"><span class="yt-uix-button-icon yt-uix-button-icon-appbar-guide yt-sprite"></span></span></button>
# <div id="appbar-main-guide-notification-container"></div>
# <a class="spf-link masthead-logo-renderer yt-uix-sessionlink" data-sessionlink="" href="/" id="logo-container" title="Accueil YouTube"><span class="logo masthead-logo-renderer-logo yt-sprite" title="Accueil YouTube"></span><span class="content-region">FR</span></a>
# </div><div id="yt-masthead-signin"> <a class="yt-uix-button yt-uix-sessionlink yt-uix-button-opacity yt-uix-button-size-default yt-uix-button-has-icon yt-uix-tooltip yt-uix-button-empty" data-sessionlink="ei=7jEcXorPKOrmhAeJ7JqAAw&amp;feature=mhsb" href="//www.youtube.com/upload" id="upload-btn" title="Mettre en ligne"><span class="yt-uix-button-icon-wrapper"><span class="yt-uix-button-icon yt-uix-button-icon-material-upload yt-sprite"></span></span></a>
# <div class="signin-container"><button class="yt-uix-button yt-uix-button-size-default yt-uix-button-primary" href="https://accounts.google.com/ServiceLogin?continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Ffeature%3Dsign_in_button%26next%3D%252Fwatch%253Fv%253D_ejGGpW1YxE%26hl%3Dfr%26action_handle_signin%3Dtrue%26app%3Ddesktop&amp;uilel=3&amp;hl=fr&amp;passive=true&amp;service=youtube" onclick=";window.location.href=this.getAttribute('href');return false;" role="link" type="button"><span class="yt-uix-button-content">Connexion</span></button> <iframe id="signin-passive" src="https://accounts.google.com/ServiceLogin?continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Ffeature%3Dpassive%26next%3D%252Fsignin_passive%26hl%3Dfr%26action_handle_signin%3Dtrue%26app%3Ddesktop&amp;uilel=3&amp;hl=fr&amp;passive=true&amp;service=youtube"></iframe>
# </div></div><div id="yt-masthead-content"><form action="/results" class="search-form consolidated-form vve-check" data-clicktracking="CAEQ7VAiEwiK_p_Hm4DnAhVqM-EKHQm2BjAo-B0" data-visibility-tracking="CAEQ7VAiEwiK_p_Hm4DnAhVqM-EKHQm2BjAo-B0" id="masthead-search" onsubmit="if (document.getElementById('masthead-search-term').value == '') return false;"><button class="yt-uix-button yt-uix-button-size-default yt-uix-button-default search-btn-component search-button" dir="ltr" id="search-btn" onclick="if (document.getElementById('masthead-search-term').value == '') return false; document.getElementById('masthead-search').submit(); return false;;return true;" tabindex="2" type="submit"><span class="yt-uix-button-content">Rechercher</span></button><div class="masthead-search-terms-border" dir="ltr" id="masthead-search-terms"><input aria-label="Rechercher" autocomplete="off" class="search-term masthead-search-renderer-input yt-uix-form-input-bidi" id="masthead-search-term" name="search_query" onkeydown="if (!this.value &amp;&amp; (event.keyCode == 40 || event.keyCode == 32 || event.keyCode == 34)) {this.onkeydown = null; this.blur();}" placeholder="Rechercher" tabindex="1" title="Rechercher" type="text" value=""/></div></form></div></div></div>
# <div class="clearfix" id="masthead-appbar-container"><div id="masthead-appbar"><div class="" id="appbar-content"></div></div></div>
# </div><div id="masthead-positioner-height-offset"></div><div id="page-container"><div class="watch video-_ejGGpW1YxE clearfix" id="page"><div class="yt-scrollbar" id="guide"> <div class="appbar-menu appbar-guide-menu-layout appbar-guide-clickable-ancestor" id="appbar-guide-menu">
# <div id="guide-container">
# <div class="guide-module-content guide-module-loading">
# <p class="yt-spinner">
# <span class="yt-spinner-img yt-sprite" title="IcÃ´ne de chargement"></span>
# <span class="yt-spinner-message">
# Chargementâ€¦
#     </span>
# </p>
# </div>
# </div>
# </div>
# </div><div class="alerts-wrapper"><div class="content-alignment" id="alerts">
# <div id="editor-progress-alert-container"></div>
# <div class="yt-alert yt-alert-default yt-alert-warn hid" id="editor-progress-alert-template"> <div class="yt-alert-icon">
# <span class="icon master-sprite yt-sprite"></span>
# </div>
# <div class="yt-alert-content" role="alert"></div><div class="yt-alert-buttons"><button aria-label="Fermer" class="yt-uix-button yt-uix-button-size-default yt-uix-button-close close yt-uix-close" data-close-parent-class="yt-alert" onclick=";return false;" type="button"><span class="yt-uix-button-content">Fermer</span></button></div></div>
# </div></div><div id="header"></div><div class="content-alignment watch-small" id="player" role="complementary"><div class="player-height" id="theater-background"></div> <div id="player-mole-container">
# <div class="hid player-width player-height player-unavailable" id="player-unavailable">
# <img alt="" class="icon meh" data-icon="/yts/img/meh7-vflGevej7.png" src="/yts/img/pixel-vfl3z5WfW.gif"/>
# <div class="content">
# <h1 class="message" id="unavailable-message">
#               Cette vidÃ©o n'est pas disponible.
#
#     </h1>
# <div class="submessage" id="unavailable-submessage">
# </div>
# </div>
# </div>
# <div class="player-width player-height off-screen-target player-api" id="player-api" tabindex="-1"></div>
# <script>if (window.ytcsi) {window.ytcsi.tick("cfg", null, '');}</script>
# <script>var ytplayer = ytplayer || {};ytplayer.config = {"attrs":{"id":"movie_player"},"assets":{"js":"\/yts\/jsbin\/player_ias-vflJiqSE7\/fr_FR\/base.js","css":"\/yts\/cssbin\/player-vfl0tglhl\/www-player.css"},"args":{"enablejsapi":"1","timestamp":"1578906094","gapi_hint_params":"m;\/_\/scs\/abc-static\/_\/js\/k=gapi.gapi.en.MEVzAPCznC8.O\/d=1\/ct=zgms\/rs=AHpOoo_iL6i3Fuh5d3bLKRBazYvzpKjkxg\/m=__features__","hl":"fr_FR","innertube_api_version":"v1","loaderUrl":"https:\/\/www.youtube.com\/watch?v=_ejGGpW1YxE","player_response":"{\"playabilityStatus\":{\"status\":\"OK\",\"playableInEmbed\":true,\"contextParams\":\"Q0FFU0FnZ0M=\"},\"streamingData\":{\"expiresInSeconds\":\"21540\",\"formats\":[{\"itag\":18,\"url\":\"https:\/\/r2---sn-gx1v2vax-atne.googlevideo.com\/videoplayback?expire=1578927694\\u0026ei=7jEcXorPKOrmhAeJ7JqAAw\\u0026ip=195.220.58.236\\u0026id=o-ADOIwZ-1ObAvtZbQ2Ls8KsqDqYT_bn40b5G4UPe1Tfbt\\u0026itag=18\\u0026source=youtube\\u0026requiressl=yes\\u0026mm=31%2C29\\u0026mn=sn-gx1v2vax-atne%2Csn-hgn7rn7k\\u0026ms=au%2Crdu\\u0026mv=m\\u0026mvi=1\\u0026pl=20\\u0026initcwndbps=1590000\\u0026vprv=1\\u0026mime=video%2Fmp4\\u0026gir=yes\\u0026clen=49538765\\u0026ratebypass=yes\\u0026dur=719.609\\u0026lmt=1538760389633076\\u0026mt=1578906037\\u0026fvip=4\\u0026fexp=23842630\\u0026c=WEB\\u0026txp=5531432\\u0026sparams=expire%2Cei%2Cip%2Cid%2Citag%2Csource%2Crequiressl%2Cvprv%2Cmime%2Cgir%2Cclen%2Cratebypass%2Cdur%2Clmt\\u0026sig=ALgxI2wwRgIhANopPa9iaY5vwpjej0AUOhWe6aHH5Y2MNexitRvmiAyKAiEAvcV2Mrbu4o4-gBz7NxMsLX5vg1uPRoCpbKvVKCncY4Y%3D\\u0026lsparams=mm%2Cmn%2Cms%2Cmv%2Cmvi%2Cpl%2Cinitcwndbps\\u0026lsig=AHylml4wRAIgUxig361jw3iJtlCs3yGdjw5ZKUkPa6UtxdjzRITqYHcCIG8fryGNmWk1fmmE14L9x9dqa53Taq1FCtjoiTni6Ecu\",\"mimeType\":\"video\/mp4; codecs=\\\"avc1.42001E, mp4a.40.2\\\"\",\"bitrate\":550767,\"width\":640,\"height\":360,\"lastModified\":\"1538760389633076\",\"contentLength\":\"49538765\",\"quality\":\"medium\",\"qualityLabel\":\"360p\",\"projectionType\":\"RECTANGULAR\",\"averageBitrate\":550729,\"audioQuality\":\"AUDIO_QUALITY_LOW\",\"approxDurationMs\":\"719609\",\"audioSampleRate\":\"44100\",\"audioChannels\":2},{\"itag\":22,\"url\":\"https:\/\/r2---sn-gx1v2vax-atne.googlevideo.com\/videoplayback?expire=1578927694\\u0026ei=7jEcXorPKOrmhAeJ7JqAAw\\u0026ip=195.220.58.236\\u0026id=o-ADOIwZ-1ObAvtZbQ2Ls8KsqDqYT_bn40b5G4UPe1Tfbt\\u0026itag=22\\u0026source=youtube\\u0026requiressl=yes\\u0026mm=31%2C29\\u0026mn=sn-gx1v2vax-atne%2Csn-hgn7rn7k\\u0026ms=au%2Crdu\\u0026mv=m\\u0026mvi=1\\u0026pl=20\\u0026initcwndbps=1590000\\u0026vprv=1\\u0026mime=video%2Fmp4\\u0026ratebypass=yes\\u0026dur=719.609\\u0026lmt=1538767230199287\\u0026mt=1578906037\\u0026fvip=4\\u0026fexp=23842630\\u0026c=WEB\\u0026txp=5531432\\u0026sparams=expire%2Cei%2Cip%2Cid%2Citag%2Csource%2Crequiressl%2Cvprv%2Cmime%2Cratebypass%2Cdur%2Clmt\\u0026sig=ALgxI2wwRQIgJcoZmFcm-yaC886DwmYgwlgU7O72NeiZaLkZSKVOy3ECIQDgEoXwxArJArBaqVwk5RCUqgaOf-KkilUdamf7nE5g7Q%3D%3D\\u0026lsparams=mm%2Cmn%2Cms%2Cmv%2Cmvi%2Cpl%2Cinitcwndbps\\u0026lsig=AHylml4wRAIgUxig361jw3iJtlCs3yGdjw5ZKUkPa6UtxdjzRITqYHcCIG8fryGNmWk1fmmE14L9x9dqa53Taq1FCtjoiTni6Ecu\",\"mimeType\":\"video\/mp4; codecs=\\\"avc1.64001F, mp4a.40.2\\\"\",\"bitrate\":1163520,\"width\":1280,\"height\":720,\"lastModified\":\"1538767230199287\",\"quality\":\"hd720\",\"qualityLabel\":\"720p\",\"projectionType\":\"RECTANGULAR\",\"audioQuality\":\"AUDIO_QUALITY_MEDIUM\",\"approxDurationMs\":\"719609\",\"audioSampleRate\":\"44100\",\"audioChannels\":2},{\"itag\":43,\"url\":\"https:\/\/r2---sn-gx1v2vax-atne.googlevideo.com\/videoplayback?expire=1578927694\\u0026ei=7jEcXorPKOrmhAeJ7JqAAw\\u0026ip=195.220.58.236\\u0026id=o-ADOIwZ-1ObAvtZbQ2Ls8KsqDqYT_bn40b5G4UPe1Tfbt\\u0026itag=43\\u0026source=youtube\\u0026requiressl=yes\\u0026mm=31%2C29\\u0026mn=sn-gx1v2vax-atne%2Csn-hgn7rn7k\\u0026ms=au%2Crdu\\u0026mv=m\\u0026mvi=1\\u0026pl=20\\u0026initcwndbps=1590000\\u0026vprv=1\\u0026mime=video%2Fwebm\\u0026gir=yes\\u0026clen=74119121\\u0026ratebypass=yes ...
# <div class="video-mole mole-collapsed hid" id="watch-queue-mole"><div class="watch-playlist player-height" id="watch-queue"><div class="main-content"><div class="watch-queue-header"><div class="watch-queue-info"><div class="watch-queue-info-icon"><span class="tv-queue-list-icon yt-sprite"></span></div><h3 class="watch-queue-title">Liste de vidÃ©os Ã  visionner</h3><h3 class="tv-queue-title">File d'attente</h3><span class="tv-queue-details"></span></div><div class="watch-queue-control-bar control-bar-button"><div class="watch-queue-mole-info"><div class="watch-queue-control-bar-icon"><span class="watch-queue-icon yt-sprite"></span></div><div class="watch-queue-title-container"><span class="watch-queue-count"></span><span class="watch-queue-title">Liste de vidÃ©os Ã  visionner</span><span class="tv-queue-title">File d'attente</span></div></div> <span class="dark-overflow-action-menu">
# <button aria-expanded="false" aria-haspopup="true" aria-label="Actions pour la file d&amp;#39;attente" class="flip control-bar-button yt-uix-button yt-uix-button-dark-overflow-action-menu yt-uix-button-size-default yt-uix-button-has-icon no-icon-markup yt-uix-button-empty" onclick=";return false;" type="button"><span class="yt-uix-button-arrow yt-sprite"></span><ul aria-haspopup="true" class="watch-queue-menu yt-uix-button-menu yt-uix-button-menu-dark-overflow-action-menu hid" role="menu"><li role="menuitem"><span class="watch-queue-menu-choice overflow-menu-choice yt-uix-button-menu-item" data-action="remove-all" onclick=";return false;">Tout supprimer</span></li><li role="menuitem"><span class="watch-queue-menu-choice overflow-menu-choice yt-uix-button-menu-item" data-action="disconnect" onclick=";return false;">Dissocier</span></li></ul></button>
# </span>
# <div class="watch-queue-controls">
# <button class="yt-uix-button yt-uix-button-size-default yt-uix-button-empty yt-uix-button-has-icon control-bar-button prev-watch-queue-button yt-uix-button-opacity yt-uix-tooltip yt-uix-tooltip" onclick=";return false;" title="VidÃ©o prÃ©cÃ©dente" type="button"><span class="yt-uix-button-icon-wrapper"><span class="yt-uix-button-icon yt-uix-button-icon-watch-queue-prev yt-sprite"></span></span></button>
# <button class="yt-uix-button yt-uix-button-size-default yt-uix-button-empty yt-uix-button-has-icon control-bar-button play-watch-queue-button yt-uix-button-opacity yt-uix-tooltip yt-uix-tooltip" onclick=";return false;" title="Lire" type="button"><span class="yt-uix-button-icon-wrapper"><span class="yt-uix-button-icon yt-uix-button-icon-watch-queue-play yt-sprite"></span></span></button>
# <button class="yt-uix-button yt-uix-button-size-default yt-uix-button-empty yt-uix-button-has-icon control-bar-button pause-watch-queue-button yt-uix-button-opacity yt-uix-tooltip hid yt-uix-tooltip" onclick=";return false;" title="Mettre en pause" type="button"><span class="yt-uix-button-icon-wrapper"><span class="yt-uix-button-icon yt-uix-button-icon-watch-queue-pause yt-sprite"></span></span></button>
# <button class="yt-uix-button yt-uix-button-size-default yt-uix-button-empty yt-uix-button-has-icon control-bar-button next-watch-queue-button yt-uix-button-opacity yt-uix-tooltip yt-uix-tooltip" onclick=";return false;" title="VidÃ©o suivante" type="button"><span class="yt-uix-button-icon-wrapper"><span class="yt-uix-button-icon yt-uix-button-icon-watch-queue-next yt-sprite"></span></span></button>
# </div>
# </div><div class="autoplay-dismiss-bar fade-out"><span class="autoplay-dismiss-title-label">La vidÃ©o suivante va commencer</span><span><button class="yt-uix-button yt-uix-button-size-default autoplay-dismiss-button yt-uix-tooltip" onclick=";return false;" title="arrÃªter" type="button"><span class="yt-uix-button-content">arrÃªter</span></button></span></div></div><div class="watch-queue-items-container yt-scrollbar-dark yt-scrollbar"><div class="yt-uix-scroller playlist-videos-list"><ol class="watch-queue-items-list" data-scroll-action="yt.www.watchqueue.loadThumbnails"> <p class="yt-spinner">
# <span class="yt-spinner-img yt-sprite" title="IcÃ´ne de chargement"></span>
# <span class="yt-spinner-message">
# Chargementâ€¦
#     </span>
# </p>
# </ol><div class="autoplay-control-container yt-uix-scroller-scroll-unit hid"> <div class="autoplay-control-bar">
# <label class="autoplay-label" for="autoplay-toggle-id"></label>
# <label class="yt-uix-form-input-checkbox-container yt-uix-form-input-container yt-uix-form-input-paper-toggle-container"><input class="yt-uix-form-input-checkbox" id="autoplay-toggle-id" type="checkbox"><div class="yt-uix-form-input-paper-toggle-bg yt-uix-form-input-paper-toggle-bar"></div><div class="yt-uix-form-input-paper-toggle-bg yt-uix-form-input-paper-toggle-button"></div></input></label>
# </div>
# </div><div class="up-next-item-container hid"></div></div></div></div> <div class="hid">
# <div id="watch-queue-title-msg">
# Liste de vidÃ©os Ã  visionner
#     </div>
# <div id="tv-queue-title-msg">File d'attente</div>
# <div id="watch-queue-count-msg">
# __count__/__total__
#     </div>
# <div id="watch-queue-loading-template">
# <!--
#           <p class="yt-spinner ">
#         <span class="yt-spinner-img  yt-sprite" title="IcÃ´ne de chargement"></span>
#
#     <span class="yt-spinner-message">
# Chargementâ€¦
#     </span>
#   </p>
#
#       -->
# </div>
# </div>
# </div></div>
# <div class="content-alignment watch-player-playlist" id="player-playlist">
# </div>
# </div>
# <div class="clear"></div>
# </div><div class="content-alignment" id="content" role="main"> <div id="placeholder-player">
# <div class="player-api player-width player-height"></div>
# </div>
# <div class="" id="watch7-container">
# <div id="player-messages">
# </div>
# <div id="watch7-main-container">
# <div class="clearfix" id="watch7-main">
# <div class="player-width player-height hid" id="watch7-preview">
# </div>
# <div class="watch-main-col" id="watch7-content" itemid="" itemscope="" itemtype="http://schema.org/VideoObject">
# <link href="https://www.youtube.com/watch?v=_ejGGpW1YxE" itemprop="url"/>
# <meta content="Mahan Air A340-600 Business Class - What's Iranian Airline Like?" itemprop="name"/>
# <meta content="Follow me on Mahan Air A340-600 from Kuala Lumpur to Tehran Imam Khomeini Int'l Airport. Find out what's the Business Class is like on an Iranian Airline. A ..." itemprop="description"/>
# <meta content="False" itemprop="paid"/>
# <meta content="UCfYCRj25JJQ41JGPqiqXmJw" itemprop="channelId"/>
# <meta content="_ejGGpW1YxE" itemprop="videoId"/>
# <meta content="PT12M0S" itemprop="duration"/>
# <meta content="False" itemprop="unlisted"/>
# <span itemprop="author" itemscope="" itemtype="http://schema.org/Person">
# <link href="http://www.youtube.com/user/N178UA" itemprop="url"/>
# </span>
# <span itemprop="author" itemscope="" itemtype="http://schema.org/Person">
# <link href="https://plus.google.com/107283123319863948985" itemprop="url"/>
# </span>
# <script type="application/ld+json">
#   {
#     "@context": "http://schema.org",
#     "@type": "BreadcrumbList",
#     "itemListElement": [
#       {
#         "@type": "ListItem",
#         "position": 1,
#         "item": {
#           "@id": "http:\/\/www.youtube.com\/user\/N178UA",
#           "name": "Sam Chui"
#         }
#       }
#     ]
#   }
#   </script>
# <link href="https://i.ytimg.com/vi/_ejGGpW1YxE/maxresdefault.jpg" itemprop="thumbnailUrl"/>
# <span itemprop="thumbnail" itemscope="" itemtype="http://schema.org/ImageObject">
# <link href="https://i.ytimg.com/vi/_ejGGpW1YxE/maxresdefault.jpg" itemprop="url"/>
# <meta content="1280" itemprop="width"/>
# <meta content="720" itemprop="height"/>
# </span>
# <link href="https://www.youtube.com/embed/_ejGGpW1YxE" itemprop="embedUrl"/>
# <meta content="HTML5 Flash" itemprop="playerType"/>
# <meta content="1280" itemprop="width"/>
# <meta content="720" itemprop="height"/>
# <meta content="True" itemprop="isFamilyFriendly"/>
# <meta content="AD,AE,AF,AG,AI,AL,AM,AO,AQ,AR,AS,AT,AU,AW,AX,AZ,BA,BB,BD,BE,BF,BG,BH,BI,BJ,BL,BM,BN,BO,BQ,BR,BS,BT,BV,BW,BY,BZ,CA,CC,CD,CF,CG,CH,CI,CK,CL,CM,CN,CO,CR,CU,CV,CW,CX,CY,CZ,DE,DJ,DK,DM,DO,DZ,EC,EE,EG,EH,ER,ES,ET,FI,FJ,FK,FM,FO,FR,GA,GB,GD,GE,GF,GG,GH,GI,GL,GM,GN,GP,GQ,GR,GS,GT,GU,GW,GY,HK,HM,HN,HR,HT,HU,ID,IE,IL,IM,IN,IO,IQ,IR,IS,IT,JE,JM,JO,JP,KE,KG,KH,KI,KM,KN,KP,KR,KW,KY,KZ,LA,LB,LC,LI,LK,LR,LS,LT,LU,LV,LY,MA,MC,MD,ME,MF,MG,MH,MK,ML,MM,MN,MO,MP,MQ,MR,MS,MT,MU,MV,MW,MX,MY,MZ,NA,NC,NE,NF,NG,NI,NL,NO,NP,NR,NU,NZ,OM,PA,PE,PF,PG,PH,PK,PL,PM,PN,PR,PS,PT,PW,PY,QA,RE,RO,RS,RU,RW,SA,SB,SC,SD,SE,SG,SH,SI,SJ,SK,SL,SM,SN,SO,SR,SS,ST,SV,SX,SY,SZ,TC,TD,TF,TG,TH,TJ,TK,TL,TM,TN,TO,TR,TT,TV,TW,TZ,UA,UG,UM,US,UY,UZ,VA,VC,VE,VG,VI,VN,VU,WF,WS,YE,YT,ZA,ZM,ZW" itemprop="regionsAllowed"/>
# <meta content="743915" itemprop="interactionCount"/>
# <meta content="2018-08-24" itemprop="datePublished"/>
# <meta content="2018-08-24" itemprop="uploadDate"/>
# <meta content="Travel &amp; Events" itemprop="genre"/>
# <div class="yt-card yt-card-has-padding" id="watch-header">
# <div class="clearfix" id="watch7-headline">
# <div id="watch-headline-title">
# <h1 class="watch-title-container">
# <span class="watch-title" dir="ltr" id="eow-title" title="Mahan Air A340-600 Business Class - What's Iranian Airline Like?">
#     Mahan Air A340-600 Business Class - What's Iranian Airline Like?
#   </span>
# </h1>
# </div>
# </div>
# <div class="spf-link" id="watch7-user-header"> <a class="yt-user-photo yt-uix-sessionlink spf-link" data-sessionlink="itct=CC4Q4TkiEwj246HHm4DnAhWE_hUKHTz7Deo" href="/user/N178UA">
# <span class="video-thumb yt-thumb yt-thumb-48">
# <span class="yt-thumb-square">
# <span class="yt-thumb-clip">
# <img alt="Sam Chui" data-thumb="https://yt3.ggpht.com/a/AGF-l7-ehx3YHEh99kWsfrJKEPEMSRe-QnJcpZ889g=s48-c-k-c0xffffffff-no-rj-mo" data-ytimg="1" height="48" onload=";window.__ytRIL &amp;&amp; __ytRIL(this)" src="/yts/img/pixel-vfl3z5WfW.gif" width="48"/>
# <span class="vertical-align"></span>
# </span>
# </span>
# </span>
# </a>
# <div class="yt-user-info">
# <a class="yt-uix-sessionlink spf-link" data-sessionlink="itct=CC4Q4TkiEwj246HHm4DnAhWE_hUKHTz7Deo" href="/channel/UCfYCRj25JJQ41JGPqiqXmJw">Sam Chui</a>
# <span aria-label="ValidÃ©" class="yt-channel-title-icon-verified yt-uix-tooltip yt-sprite" data-tooltip-text="ValidÃ©"></span>
# </div>
# <span id="watch7-subscription-container"><span class="yt-uix-button-subscription-container"><span class="unsubscribe-confirmation-overlay-container">
# <div class="yt-uix-overlay" data-overlay-shape="tiny" data-overlay-style="primary">
# <div class="yt-dialog hid">
# <div class="yt-dialog-base">
# <span class="yt-dialog-align"></span>
# <div class="yt-dialog-fg" role="dialog">
# <div class="yt-dialog-fg-content">
# <div class="yt-dialog-loading">
# <div class="yt-dialog-waiting-content">
# <p class="yt-spinner">
# <span class="yt-spinner-img yt-sprite" title="IcÃ´ne de chargement"></span>
# <span class="yt-spinner-message">
# Chargementâ€¦
#     </span>
# </p>
# </div>
# </div>
# <div class="yt-dialog-content">
# <div class="unsubscribe-confirmation-overlay-content-container">
# <div class="unsubscribe-confirmation-overlay-content">
# <div class="unsubscribe-confirmation-message">
#         Se dÃ©sabonner de Sam ChuiÂ ?
#       </div>
# </div>
# <div class="yt-uix-overlay-actions">
# <button class="yt-uix-button yt-uix-button-size-default yt-uix-button-default yt-uix-overlay-close" onclick=";return false;" type="button"><span class="yt-uix-button-content">Annuler</span></button>
# <button class="yt-uix-button yt-uix-button-size-default yt-uix-button-primary overlay-confirmation-unsubscribe-button yt-uix-overlay-close" onclick=";return false;" type="button"><span class="yt-uix-button-content">Se dÃ©sabonner</span></button>
# </div>
# </div>
# </div>
# <div class="yt-dialog-working">
# <div class="yt-dialog-working-overlay"></div>
# <div class="yt-dialog-working-bubble">
# <div class="yt-dialog-waiting-content">
# <p class="yt-spinner">
# <span class="yt-spinner-img yt-sprite" title="IcÃ´ne de chargement"></span>
# <span class="yt-spinner-message">
#         OpÃ©ration en coursâ€¦
#     </span>
# </p>
# </div>
# </div>
# </div>
# </div>
# <div class="yt-dialog-focus-trap" tabindex="0"></div>
# </div>
# </div>
# </div>
# </div>
# </span><button aria-busy="false" aria-live="polite" class="yt-uix-button yt-uix-button-size-default yt-uix-button-subscribe-branded yt-uix-button-has-icon no-icon-markup yt-uix-subscription-button yt-can-buffer yt-uix-servicelink vve-check" data-channel-external-id="UCfYCRj25JJQ41JGPqiqXmJw" data-clicktracking="itct=CC8QmysiEwj246HHm4DnAhWE_hUKHTz7DeoyBXdhdGNo" data-href="https://accounts.google.com/ServiceLogin?continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Fnext%3D%252Fchannel%252FUCfYCRj25JJQ41JGPqiqXmJw%26continue_action%%253D%26hl%3Dfr%26feature%3Dsubscribe%26app%3Ddesktop%26action_handle_signin%3Dtrue&amp;uilel=3&amp;hl=fr&amp;passive=true&amp;service=youtube" data-params="EgIIAxgAIgtfZWpHR3BXMVl4RQ%3D%3D" data-servicelink="CC8QmysiEwj246HHm4DnAhWE_hUKHTz7DeoyBXdhdGNo" data-show-unsub-confirm-dialog="true" data-style-type="branded" data-visibility-tracking="CC8QmysiEwj246HHm4DnAhWE_hUKHTz7DeoyBXdhdGNo" onclick=";return false;" type="button"><span class="yt-uix-button-content"><span aria-label="S'abonner" class="subscribe-label">S'abonner</span><span aria-label="Annuler" class="subscribed-label">AbonnÃ©</span><span aria-label="Annuler" class="unsubscribe-label">Annuler</span></span></button><button aria-busy="false" aria-label="PrÃ©fÃ©rences d&amp;#39;abonnement" aria-live="polite" aria-role="button" class="yt-uix-button yt-uix-button-size-default yt-uix-button-default yt-uix-button-empty yt-uix-button-has-icon yt-uix-subscription-preferences-button" data-channel-external-id="UCfYCRj25JJQ41JGPqiqXmJw" onclick=";return false;" type="button"><span class="yt-uix-button-icon-wrapper"><span class="yt-uix-button-icon yt-uix-button-icon-subscription-preferences yt-sprite"></span></span></button><span aria-label="1,78Â M" class="yt-subscription-button-subscriber-count-branded-horizontal yt-subscriber-count" tabindex="0" title="1,78Â M">1,78Â M</span> <span class="subscription-preferences-overlay-container">
# <div class="yt-uix-overlay" data-overlay-shape="tiny" data-overlay-style="primary">
# <div class="yt-dialog hid">
# <div class="yt-dialog-base">
# <span class="yt-dialog-align"></span>
# <div class="yt-dialog-fg" role="dialog">
# <div class="yt-dialog-fg-content">
# <div class="yt-dialog-loading">
# <div class="yt-dialog-waiting-content">
# <p class="yt-spinner">
# <span class="yt-spinner-img yt-sprite" title="IcÃ´ne de chargement"></span>
# <span class="yt-spinner-message">
# Chargementâ€¦
#     </span>
# </p>
# </div>
# </div>
# <div class="yt-dialog-content">
# <div class="subscription-preferences-overlay-content-container">
# <div class="subscription-preferences-overlay-loading">
# <p class="yt-spinner">
# <span class="yt-spinner-img yt-sprite" title="IcÃ´ne de chargement"></span>
# <span class="yt-spinner-message">
# Chargementâ€¦
#     </span>
# </p>
# </div>
# <div class="subscription-preferences-overlay-content">
# </div>
# </div>
# </div>
# <div class="yt-dialog-working">
# <div class="yt-dialog-working-overlay"></div>
# <div class="yt-dialog-working-bubble">
# <div class="yt-dialog-waiting-content">
# <p class="yt-spinner">
# <span class="yt-spinner-img yt-sprite" title="IcÃ´ne de chargement"></span>
# <span class="yt-spinner-message">
#         OpÃ©ration en coursâ€¦
#     </span>
# </p>
# </div>
# </div>
# </div>
# </div>
# <div class="yt-dialog-focus-trap" tabindex="0"></div>
# </div>
# </div>
# </div>
# </div>
# </span>
# </span></span></div>
# <div class="watch-action-buttons clearfix" id="watch8-action-buttons"><div class="watch-secondary-actions yt-uix-button-group" data-button-toggle-group="optional" id="watch8-secondary-actions"> <span class="yt-uix-clickcard">
# <button class="yt-uix-button yt-uix-button-size-default yt-uix-button-opacity yt-uix-button-has-icon no-icon-markup yt-uix-clickcard-target addto-button pause-resume-autoplay yt-uix-tooltip" data-orientation="vertical" data-position="bottomleft" onclick=";return false;" title="Ajouter Ã " type="button"><span class="yt-uix-button-content">Ajouter Ã </span></button>
# <div class="signin-clickcard yt-uix-clickcard-content">
# <h3 class="signin-clickcard-header">Regarder Ã  nouveau plus tardÂ ?</h3>
# <div class="signin-clickcard-message">
#       Connectez-vous pour ajouter la vidÃ©o Ã  une playlist.
#     </div>
# <a class="yt-uix-button signin-button yt-uix-sessionlink yt-uix-button-primary yt-uix-button-size-default" data-sessionlink="ei=7jEcXorPKOrmhAeJ7JqAAw" href="https://accounts.google.com/ServiceLogin?continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Ffeature%3D__FEATURE__%26next%3D%252Fwatch%253Fv%253D_ejGGpW1YxE%26hl%3Dfr%26action_handle_signin%3Dtrue%26app%3Ddesktop&amp;uilel=3&amp;hl=fr&amp;passive=true&amp;service=youtube"><span class="yt-uix-button-content">Se connecter</span></a>
# </div>
# </span>
# <button class="yt-uix-button yt-uix-button-size-default yt-uix-button-opacity yt-uix-button-has-icon no-icon-markup pause-resume-autoplay action-panel-trigger action-panel-trigger-share yt-uix-tooltip" data-button-toggle="true" data-trigger-for="action-panel-share" onclick=";return false;" title="Partager
# " type="button"><span class="yt-uix-button-content">Partager
# </span></button>
# <div class="yt-uix-menu"> <button aria-haspopup="true" aria-label="Action menu." aria-pressed="false" class="yt-uix-button yt-uix-button-size-default yt-uix-button-opacity yt-uix-button-has-icon no-icon-markup pause-resume-autoplay yt-uix-menu-trigger yt-uix-tooltip" id="action-panel-overflow-button" onclick=";return false;" role="button" title="Autres actions" type="button"><span class="yt-uix-button-content">Plus</span></button>
# <div class="yt-uix-menu-content yt-ui-menu-content yt-uix-menu-content-hidden" role="menu"><ul id="action-panel-overflow-menu"> <li>
# <span class="yt-uix-clickcard" data-card-class="report-card">
# <button class="yt-ui-menu-item has-icon action-panel-trigger action-panel-trigger-report report-button yt-uix-clickcard-target" data-orientation="horizontal" data-position="topright" type="button">
# <span class="yt-ui-menu-item-label">Signaler</span>
# </button>
# <div class="signin-clickcard yt-uix-clickcard-content">
# <h3 class="signin-clickcard-header">Vous souhaitez signaler cette vidÃ©oÂ ?
# </h3>
# <div class="signin-clickcard-message">
# <p>Connectez-vous pour signaler du contenu inappropriÃ©.
# </p>
# </div>
# <a class="yt-uix-button signin-button yt-uix-sessionlink yt-uix-button-primary yt-uix-button-size-default" data-sessionlink="ei=7jEcXorPKOrmhAeJ7JqAAw" href="https://accounts.google.com/ServiceLogin?continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Ffeature%3D__FEATURE__%26next%3D%252Fwatch%253Fv%253D_ejGGpW1YxE%26hl%3Dfr%26action_handle_signin%3Dtrue%26app%3Ddesktop&amp;uilel=3&amp;hl=fr&amp;passive=true&amp;service=youtube"><span class="yt-uix-button-content">Se connecter</span></a>
# </div>
# </span>
# </li>
# <li>
# <button class="yt-ui-menu-item has-icon yt-uix-menu-close-on-select action-panel-trigger action-panel-trigger-transcript" data-trigger-for="action-panel-transcript" type="button">
# <span class="yt-ui-menu-item-label">Transcription</span>
# </button>
# </li>
# <a class="yt-ui-menu-item has-icon action-panel-trigger-translate" href="/timedtext_video?ref=wt&amp;v=_ejGGpW1YxE&amp;auto=yes&amp;bl=watch" rel="nofollow">
# <span class="yt-ui-menu-item-label">Ajouter des traductions</span>
# </a>
# </ul></div></div></div><div id="watch8-sentiment-actions"><div id="watch7-views-info"><div class="watch-view-count">743â€¯973Â vues</div>
# <div class="video-extras-sparkbars">
# <div class="video-extras-sparkbar-likes" style="width: 93.5656836461%"></div>
# <div class="video-extras-sparkbar-dislikes" style="width: 6.43431635389%"></div>
# </div>
# </div>
# <span class="like-button-renderer" data-button-toggle-group="optional">
# <span class="yt-uix-clickcard">
# <button aria-label="Cliquez sur &amp;quot;J'aime&amp;quot; pour cette vidÃ©o comme 7â€¯329Â autres internautes." class="yt-uix-button yt-uix-button-size-default yt-uix-button-opacity yt-uix-button-has-icon no-icon-markup like-button-renderer-like-button like-button-renderer-like-button-unclicked yt-uix-clickcard-target yt-uix-tooltip" data-force-position="true" data-orientation="vertical" data-position="bottomright" onclick=";return false;" title="J'aime ce contenu" type="button"><span class="yt-uix-button-content">7â€¯329</span></button>
# <div class="signin-clickcard yt-uix-clickcard-content">
# <h3 class="signin-clickcard-header">Vous aimez cette vidÃ©oÂ ?</h3>
# <div class="signin-clickcard-message">
#       Connectez-vous pour donner votre avis.
#     </div>
# <a class="yt-uix-button signin-button yt-uix-sessionlink yt-uix-button-primary yt-uix-button-size-default" data-sessionlink="ei=7jEcXorPKOrmhAeJ7JqAAw" href="https://accounts.google.com/ServiceLogin?continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Ffeature%3D__FEATURE__%26next%3D%252Fwatch%253Fv%253D_ejGGpW1YxE%26hl%3Dfr%26action_handle_signin%3Dtrue%26app%3Ddesktop&amp;uilel=3&amp;hl=fr&amp;passive=true&amp;service=youtube"><span class="yt-uix-button-content">Se connecter</span></a>
# </div>
# </span>
# <span class="yt-uix-clickcard">
# ...
#           'BG_IU': "\/\/www.google.com\/js\/bg\/_mlCwTaS3ftYlLPjiYBUqmaWUIKOu9m_2E9Wu7234aE.js",
#
#
#
#         'COMMENTS_TOKEN': "EkQSC19lakdHcFcxWXhFwAEAyAEA4AEBogINKP___________wFAAMICGxoXaHR0cHM6Ly93d3cueW91dHViZS5jb20iABgG",
#
#       'GET_PLAYER_EVENT_ID': "",
#       'HL_LOCALE': "fr_FR",
#       'TTS_URL': "https:\/\/www.youtube.com\/api\/timedtext?v=_ejGGpW1YxE\u0026asr_langs=de,en,es,fr,it,ja,ko,nl,pt,ru\u0026caps=asr\u0026xorp=true\u0026hl=fr\u0026ip=0.0.0.0\u0026ipbits=0\u0026expire=1578931294\u0026sparams=ip,ipbits,expire,v,asr_langs,caps,xorp\u0026signature=64C10A6D56817984C8BC120B6508223876682ADD.B8F21BBC43A73B89F646278288995D890CB7B3CD\u0026key=yt8",
#       'JS_DELAY_LOAD': 0,
#       'LIST_AUTO_PLAY_VALUE': 1,
#       'SHUFFLE_VALUE': 0,
#       'SKIP_RELATED_ADS': false,
#       'SKIP_TO_NEXT_VIDEO': false,
#       'CONVERSION_CONFIG_DICT': {},
#       'RESOLUTION_TRACKING_ENABLED': false,
#       'WATCH_LEGAL_TEXT_ENABLE_AUTOSCROLL': false,
#       'ADS_DATA': {"gut_vars":{"tag":"\\4061\\ytpwmpu"},"use_gut":true,"afv_vars":{"google_ad_client":"ca-pub-6219811747049371","google_ad_host":"ca-yt-host-pub-4923373081287946","google_scs":"","google_tag_for_child_directed_treatment":"","google_cust_gender":"","google_cust_age":"","google_core_dbp":"ChZ3eU1VY3A4MFRQU2xZcnZqRlAwd3NBEAEgASgAOAI","google_loeid":"23794463,23795268,23835026,23839597,23841119,23847204,23848795,23861742,23865511,23866339,23866478,23867845,23868644,23869499,23869622,23870094,16021042,16021084,9477942","google_ad_block":"2","google_language":"fr","google_ad_format":"300x250_as","google_lact":"-1","google_ad_channel":"0854550288+Vertical_12+Vertical_203+Vertical_50+Vertical_662+Vertical_67+afv_user_id_fYCRj25JJQ41JGPqiqXmJw+afv_user_n178ua+yt_cid_13910348+yt_mabv+yt_mpvid_nZyqTOqubBk_SKSJ+yt_no_360+yt_no_ap+yt_no_wa+ytdevice_1+ytdevicever_1.20200108.07.03+ytel_detailpage+ytps_default","google_page_url":"http:\/\/www.youtube.com\/video\/_ejGGpW1YxE","google_alternate_ad_url":"https:\/\/www.youtube.com\/ad_frame?id=watch-channel-brand-div","google_yt_pt":"APb3F288q-qybOYXAHL_V7mOs5fBuJt1hRbqdgaOwyoMXvxASbSnYlZRBaXXgSMMxEQqUiUVb7FvYME0ha5-PUXs-kkr8fOuDAdCypLYzxGJTuNaDAz32PrarSnjFA0nphDyfkSKW_ZJhe5-frqKDinbWn4wp9Tt1QWKriDAuuYMrdV4R9mi9nN5-bHLjqYCVMmlQiIatxyewv_fKdJf","google_ad_type":"image","google_targeting":"","google_pucrd":"APb3F2-8fP8fguKxYMjvEtZ4WRgCDRh1MbwsDk7huAV_lbBifL4ZjHRAXsHkXWvv08HgaII_vn1qVZr8P2H7","google_video_doc_id":"yt__ejGGpW1YxE","google_ad_host_tier_id":"","google_eids":[],"google_ad_height":"250"},"afc_vars":{"alternate_ad_url":"https:\/\/www.youtube.com\/ad_frame?id=watch-channel-brand-div","ad_host":"ca-yt-host-pub-4923373081287946","loeid":"23794463,23795268,23835026,23839597,23841119,23847204,23848795,23861742,23865511,23866339,23866478,23867845,23868644,23869499,23869622,23870094,16021042,16021084,9477942","ad_channel":"0854550287+Vertical_12+Vertical_203+Vertical_50+Vertical_662+Vertical_67+afc_on_page+afv_user_id_fYCRj25JJQ41JGPqiqXmJw+afv_user_n178ua+yt_cid_13910348+yt_mabv+yt_mpvid_nZyqTOqubBk_SKSJ+yt_no_360+yt_no_ap+yt_no_wa+ytdevice_1+ytdevicever_1.20200108.07.03+ytel_detailpage+ytps_default","ad_host_tier_id":"","lact":"-1","language":"fr","ad_block":"2","pucrd":"APb3F2-8fP8fguKxYMjvEtZ4WRgCDRh1MbwsDk7huAV_lbBifL4ZjHRAXsHkXWvv08HgaII_vn1qVZr8P2H7","core_dbp":"ChZ3eU1VY3A4MFRQU2xZcnZqRlAwd3NBEAEgASgAOAI","ad_type":"image","tag_for_child_directed_treatment":"","video_doc_id":"yt__ejGGpW1YxE","eids":[],"targeting":"","format":"300x250_as","ad_client":"ca-pub-6219811747049371"},"show_afv":true,"show_instream":true,"check_status":false,"show_afc":false,"show_pyv":false},
#       'PLAYBACK_ID': "AAWcAbjopaUtSR3g",
#       'IS_DISTILLER': true,
#       'SHARE_CAPTION': null,
#       'SHARE_REFERER': "",
#       'PLAYLIST_INDEX': null
#     });
#
#
#     yt.setMsg({
#       'EDITOR_AJAX_REQUEST_FAILED': "Une erreur s\u0026#39;est produite lors de l\u0026#39;obtention des donnÃ©es Ã  partir du serveur. Veuillez rÃ©essayer ou actualisez la page.",
#       'EDITOR_AJAX_REQUEST_503': "Cette fonctionnalitÃ© n\u0026#39;est pas disponible pour le moment. Veuillez rÃ©essayer ultÃ©rieurement.",
#         'HTML5_SUBS_ASR': "sous-titres automatiques",
#       'LOADING': "Chargement en coursâ€¦"    });
#
#
#
#
#       yt.setConfig({
#     'GUIDED_HELP_LOCALE': "fr_FR",
#     'GUIDED_HELP_ENVIRONMENT': "prod"
#   });
#
#   </script>
# <script>yt.setConfig({INNERTUBE_API_VERSION: "v1",INNERTUBE_API_KEY: "AIzaSyAO_FJ2SlqU8Q4STEHLGCilw_Y9_11qcW8",INNERTUBE_CONTEXT_CLIENT_VERSION: "1.20200108.07.03",GAPI_HINT_PARAMS: "m;\/_\/scs\/abc-static\/_\/js\/k=gapi.gapi.en.MEVzAPCznC8.O\/d=1\/ct=zgms\/rs=AHpOoo_iL6i3Fuh5d3bLKRBazYvzpKjkxg\/m=__features__",INNERTUBE_CONTEXT_CLIENT_NAME: 1,'VISITOR_DATA': "CgtmcmNaSDV6bEduNCju4_DwBQ%3D%3D",'DELEGATED_SESSION_ID': null,'GAPI_HOST': "https:\/\/apis.google.com",'GAPI_LOCALE': "fr_FR",'INNERTUBE_CONTEXT_HL': "fr",'INNERTUBE_CONTEXT_GL': "FR",'XHR_APIARY_HOST': "youtubei.youtube.com"});yt.setConfig({'PAGE_NAME': "watch",'LOGGED_IN': false,'SESSION_INDEX': null,'VALID_SESSION_TEMPDATA_DOMAINS': ["www.youtube.com","gaming.youtube.com"],'PARENT_TRACKING_PARAMS': "",'FORMATS_FILE_SIZE_JS': ["%sÂ octets","%sÂ Ko","%sÂ Mo","%sÂ Go","%sÂ To"],'ONE_PICK_URL': "",'GOOGLEPLUS_HOST': "https:\/\/plus.google.com",'PAGEFRAME_JS': "\/yts\/jsbin\/www-pageframe-vflPMvchQ\/www-pageframe.js",'GAPI_LOADER_URL': "\/yts\/jsbin\/www-gapi-loader-vflX6I5Bf\/www-gapi-loader.js",'JS_COMMON_MODULE': "\/yts\/jsbin\/www-en_US-vflf34fHi\/common.js",'PAGE_FRAME_DELAYLOADED_CSS': "\/yts\/cssbin\/www-pageframedelayloaded-vflZQkKIB.css",'EXPERIMENT_FLAGS': {"enable_docked_chat_messages":true,"service_worker_scope":"\/","web_logging_max_batch":100,"autoplay_pause_by_lact_sec":0,"mdx_enable_privacy_disclosure_ui":true,"disable_legacy_desktop_remote_queue":true,"kevlar_guide_refresh":true,"desktop_shopping_companion_wta_support":true,"ignore_empty_xhr":true,"enable_ypc_spinners":true,"autoescape_tempdata_url":true,"web_gel_timeout_cap":true,"service_worker_enabled":true,"service_worker_push_prompt_delay_microseconds":3888000000000,"gfeedback_for_signed_out_users_enabled":true,"enable_premium_voluntary_pause":true,"live_chat_increased_min_height":true,"desktop_pyv_on_watch_missing_params":true,"no_sub_count_on_sub_button":true,"service_worker_push_logged_out_prompt_watches":-1,"botguard_periodic_refresh":true,"consent_url_override":"","app_settings_snapshot_min_time_between_snapshots_hours":24,"log_window_onerror_fraction":0.1,"desktop_image_companion_wta_support":true,"log_vis_on_tab_change":true,"desktop_polymer_video_masthead_always_use_responsive_iframe":true,"web_post_search":true,"update_super_chat_moderation":true,"desktop_notification_high_priority_ignore_push":true,"warm_load_nav_start_web":true,"service_worker_push_watch_page_prompt":true,"pass_biscotti_id_in_header_ajax":true,"live_chat_unicode_emoji_json_url":"https:\/\/www.gstatic.com\/youtube\/img\/emojis\/emojis-svg-1.json","enable_watch_next_pause_autoplay_lact":true,"desktop_action_companion_wta_support":true,"should_clear_video_data_on_player_cued_unstarted":true,"cancel_pending_navs":true,"enable_ve_tracker_key":true,"web_system_health_fraction":0.01,"live_chat_client_url":true,"retry_web_logging_batches":true,"disable_legacy_desktop_remote_queue_watch":true,"custom_csi_timeline_use_gel":true,"web_use_beacon_api_for_ad_click_server_pings":true,"desktop_notification_set_title_bar":true,"web_gel_debounce_ms":10000,"service_worker_push_enabled":true,"use_watch_fragments2":true,"web_always_load_chat_support":true,"autoplay_pause_by_lact_sampling_fraction":0.0,"log_web_meta_interval_ms":0,"watch_next_pause_autoplay_lact_sec":4500,"service_worker_push_force_notification_prompt_tag":"1","enable_read_more_format_decoration":true,"service_worker_push_home_page_prompt":true,"desktop_polymer_video_masthead_session_tempdata_ttl":30,"desktop_videowall_companion_wta_support":true,"prefetch_comments_ms_after_video":0,"service_worker_push_prompt_cap":-1,"desktop_pyv_on_watch_override_lact":true},'GUIDE_DELAY_LOAD': true,'GUIDE_DELAYLOADED_CSS': "\/yts\/cssbin\/www-guide-vflybhooe.css",'GUIDED_HELP_PARAMS': {"logged_in":"0"},'HIGH_CONTRAST_MODE_CSS': "\/yts\/cssbin\/www-highcontrastmode-vfl2pKdoC.css",'PREFETCH_LINKS': false,'PREFETCH_LINKS_MAX': 1,'PREFETCH_AUTOPLAY': false,'PREFETCH_AUTOPLAY_TIME': 0,'PREFETCH_A ...
#     'GUIDED_HELP_LOCALE': "fr_FR",
#     'GUIDED_HELP_ENVIRONMENT': "prod"
#   });
# yt.setConfig('SPF_SEARCH_BOX', true);yt.setMsg({'ADDTO_CREATE_NEW_PLAYLIST': "CrÃ©er une playlist\n",'ADDTO_CREATE_PLAYLIST_DYNAMIC_TITLE': "  $dynamic_title_placeholder (crÃ©er)\n",'ADDTO_WATCH_LATER': "Watch later",'ADDTO_WATCH_LATER_ADDED': "AjoutÃ©e",'ADDTO_WATCH_LATER_ERROR': "Erreur",'ADDTO_WATCH_QUEUE': "Watch Queue",'ADDTO_WATCH_QUEUE_ADDED': "AjoutÃ©e",'ADDTO_WATCH_QUEUE_ERROR': "Erreur",'ADDTO_TV_QUEUE': "Queue",'MASTHEAD_NOTIFICATIONS_LABEL': {"one": "#\u00a0notification non lue.", "case0": "Aucune notification non lue.", "case1": "1\u00a0notification non lue.", "other": "#\u00a0notifications non lues."},'MASTHEAD_NOTIFICATIONS_COUNT_99PLUS': "\u0026gt; 99",'MDX_AUTOPLAY_OFF': 'Lecture automatique dÃ©sactivÃ©e','MDX_AUTOPLAY_ON': 'Lecture automatique activÃ©e'});  yt.setConfig('FEED_PRIVACY_CSS_URL', "\/yts\/cssbin\/www-feedprivacydialog-vfltb5-JE.css");
#   yt.setConfig('FEED_PRIVACY_LIGHTBOX_ENABLED', true);
# yt.setConfig({'SBOX_JS_URL': "\/yts\/jsbin\/www-searchbox-vflyG4gaq\/www-searchbox.js",'SBOX_SETTINGS': {"SESSION_INDEX":null,"HAS_ON_SCREEN_KEYBOARD":false,"IS_FUSION":false,"PSUGGEST_TOKEN":null,"SUGG_EXP_ID":"","REQUEST_LANGUAGE":"fr","REQUEST_DOMAIN":"fr","PQ":""},'SBOX_LABELS': {"SUGGESTION_DISMISSED_LABEL":"Suggestion supprimÃ©e","SUGGESTION_DISMISS_LABEL":"Supprimer"}});  yt.setConfig({
#     'YPC_LOADER_JS': "\/yts\/jsbin\/www-ypc-vflYFn1AH\/www-ypc.js",
#     'YPC_LOADER_CSS': "\/yts\/cssbin\/www-ypc-vflx_KJhA.css",
#     'YPC_SIGNIN_URL': "https:\/\/accounts.google.com\/ServiceLogin?continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Fnext%3D%252F%26hl%3Dfr%26action_handle_signin%3Dtrue%26app%3Ddesktop\u0026uilel=3\u0026hl=fr\u0026passive=true\u0026service=youtube",
#     'DBLCLK_ADVERTISER_ID': "2542116",
#     'DBLCLK_YPC_ACTIVITY_GROUP': "youtu444",
#     'SUBSCRIPTION_URL': "\/subscription_ajax",
#     'YPC_SWITCH_URL': "\/signin?feature=purchases\u0026next=%2F\u0026action_handle_signin=true\u0026skip_identity_prompt=True",
#     'YPC_GB_LANGUAGE': "fr_FR",
#     'YPC_MB_URL': "https:\/\/payments.youtube.com\/payments\/v4\/js\/integrator.js?ss=md",
#     'YPC_TRANSACTION_URL': "\/transaction_handler",
#     'YPC_SUBSCRIPTION_URL': "\/ypc_subscription_ajax",
#     'YPC_POST_PURCHASE_URL': "\/ypc_post_purchase_ajax",
#     'YTR_FAMILY_CREATION_URL': "https:\/\/families.google.com\/webcreation?usegapi=1",
#     'YTO_GTM_DATA': {'event': 'purchased', 'purchaseStatus': 'success'},
#     'YTO_GTM_1_BUTTON_CLICK_DATA': {'event': 'landingButtonClick', 'buttonPosition': '1'},
#     'YTO_GTM_2_BUTTON_CLICK_DATA': {'event': 'landingButtonClick', 'buttonPosition': '2'}
#   });
#   yt.setMsg({
#     'YPC_OFFER_OVERLAY': "  \n",
#     'YPC_UNSUBSCRIBE_OVERLAY': "  \n"
#   });
#   yt.setConfig('GOOGLE_HELP_CONTEXT', "watch");
# ytcsi.info('st', 321);ytcfg.set({"CSI_SERVICE_NAME":"youtube","TIMING_INFO":{"yt_lt":"cold","yt_pl":0,"GetPlayer_rid":"0x173198860c4c71cc","GetWatchNext_rid":"0x173198860c4c71cc","c":"WEB","cver":"1.20200108.07.03","yt_ad":"1","yt_li":"0"}});;ytcfg.set({"CSI_VIEWPORT":true,"TIMING_ACTION":"watch"});;  yt.setConfig({
#       'XSRF_TOKEN': "",
#       'XSRF_FIELD_NAME': "session_token",
#
#       'XSRF_REDIRECT_TOKEN': "hC1pXQUZQH-Px7XFEjhy42_DNO98MTU3ODk5MjQ5NUAxNTc4OTA2MDk1"  });
# yt.setConfig('ID_TOKEN', null);window.ytcfg.set('SERVICE_WORKER_KILLSWITCH', false);  yt.setConfig('THUMB_DELAY_LOAD_BUFFER', 0);
# if (window.ytcsi) {window.ytcsi.tick("jl", null, '');}</script>
# </body></html>

# %%
dic = {'.':'','avr':'apr','janv':'jan','mars':'mar','mai':'may','juin':'jun','févr':'feb','juil':'jul','déc':'dec','août':'aug','sept':'sep','aoÃ»t':'aug'}
var_date_of_public = SoupCréeJS.find('strong',attrs={'class': "watch-time-text"}).text.strip().replace('.','')
var_date_of_public = replace_all(var_date_of_public,dic)
str(datetime.strptime(re.search("[0-9][0-9]* [a-zA-Z]* [0-9]*", var_date_of_public).group(0), '%d %b %Y')). replace('00:00:00', '')
# Out:
# '2018-08-24 '

# %%
var_date_of_public
# Out:
# 'AjoutÃ©e le 24 aoÃ»t 2018'

# %% [markdown]
# # global implementation

# %%
# %%time
# Create a new json

with open('data.json', 'w', encoding='utf8') as outfile:
    json

for Equation in equations[16:20]:
    list_Videos = URLlist(Equation,None)
    # len(list_Videos)
    if len(list_Videos) > 1 :
        for URL_unique in range(min(len(list_Videos),7)):
            soup1 = scroll(list_Videos[URL_unique], 4)
            SoupCréeJS = GetCodeHTML(list_Videos, URL_unique)
        # date comment
            date1 = []
            for span1 in soup1.findAll('span', attrs={'class': "comment-renderer-time"}):
                a = (span1.find('a', attrs={'class': "yt-uix-sessionlink spf-link"}).text.strip())
                date1.append(a)
            date_Track = 0
            for span in soup1.findAll('div', attrs={'class': 'comment-renderer-text-content'}):
                if span.text.strip() != '':
                    comment = span.text.strip()
                    nb_com = re.search("[0-9][0-9]*", (soup.find('h2', 
                                                                 attrs={'class': 'comment-section-header-renderer'}).text.strip()).replace('\xa0',' ').replace('\u202f','')).group(0)
                    CreateJs(comment, nb_com, SoupCréeJS, date1[date_Track])
                    date_Track += 1
            print('vidéo numéro : ', URL_unique, ' fini')
        print('équation finie :', Equation)
print('extraction complete')
# Out:
# vidéo numéro :  0  fini
# vidéo numéro :  1  fini
# vidéo numéro :  2  fini
# vidéo numéro :  3  fini
# vidéo numéro :  4  fini
# vidéo numéro :  5  fini
# vidéo numéro :  6  fini
# équation finie : American+Airlines+A340-600
# vidéo numéro :  0  fini
# vidéo numéro :  1  fini
# vidéo numéro :  2  fini
# vidéo numéro :  3  fini
# vidéo numéro :  4  fini
# vidéo numéro :  5  fini
# vidéo numéro :  6  fini
# équation finie : American+Airlines+A350-900

# %%
var_date_of_public = SoupCréeJS.find('strong',attrs={'class': "watch-time-text"}).text.strip().replace('.','').replace('sept','sep')
str(datetime.strptime(re.search("[0-9][0-9]* [a-zA-Z]* [0-9]*", var_date_of_public).group(0), '%d %b %Y')). replace('00:00:00', '')
# Out:
# '2016-09-25 '

# %%
print(var_date_of_public)
# Out:
# Ajoutée le 25 sept 2016

# %%
re.search("[0-9][0-9]* [a-zA-Z]* [0-9]*", var_date_of_public)
# Out:
# <re.Match object; span=(11, 23), match='25 sept 2016'>
