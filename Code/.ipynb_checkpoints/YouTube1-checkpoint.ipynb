# %%
import urllib.request
import urllib.parse
import urllib.error
from bs4 import BeautifulSoup
import ssl
import json
import ast
import json
import os
from urllib.request import Request, urlopen

# %%
from bs4 import BeautifulSoup as bs
import requests

# %%
racineURL = "https://www.youtube.com/results?search_query="
EquationRecherche = "airbus+A380"

r = requests.get(racineURL + EquationRecherche)
page = r.text
soup = bs(page,'html.parser')

videos = soup.findAll('a',attrs={'class':'yt-uix-tile-link'})

# %%
listVideos=[]
for v in videos:
    URL = 'https://www.youtube.com' + v['href']
    listVideos.append(URL)

# %%
listVideos[0]
# Out:
# 'https://www.youtube.com/watch?v=N8mTPYiCO-8'

# %%
def CréeJs(listeURL,chiffre) :     
    url = listeURL[chiffre]
    req = Request(url, headers={'User-Agent': 'Mozilla/5.0'})
    webpage = urlopen(req).read()


    soup = BeautifulSoup(webpage, 'html.parser')
    html = soup.prettify('utf-8')
    video_details = {}

#sortir le titre de la vidéo 

    for span in soup.findAll('span',attrs={'class': 'watch-title'}):
        video_details['Titre'] = span.text.strip()

#sortir le nom de la chaine
    for script in soup.findAll('script',attrs={'type': 'application/ld+json'}):
            channelDesctiption = json.loads(script.text.strip())
            video_details['Nom chaine'] = channelDesctiption['itemListElement'][0]['item']['name']

#sortir le nombre de vue
    for div in soup.findAll('div',attrs={'class': 'watch-view-count'}):
        video_details['Nombre de vues'] = div.text.strip()

#sortir un bouton likes
    for span in soup.findAll('',attrs={'class':"yt-uix-button yt-uix-button-size-default yt-uix-button-opacity yt-uix-button-has-icon no-icon-markup like-button-renderer-like-button like-button-renderer-like-button-unclicked yt-uix-clickcard-target yt-uix-tooltip"}):
        for span1 in span.findAll('span',attrs={'class': 'yt-uix-button-content'}):
            video_details['LIKES'] =span1.text.strip()

#sortir un bouton de dislikes 
    for button in soup.findAll('button',attrs={'class':"yt-uix-button yt-uix-button-size-default yt-uix-button-opacity yt-uix-button-has-icon no-icon-markup like-button-renderer-dislike-button like-button-renderer-dislike-button-unclicked yt-uix-clickcard-target yt-uix-tooltip"}):
        for span in button.findAll('span',attrs={'class': 'yt-uix-button-content'}):
            video_details['DISLIKES'] =span.text.strip()

#sortir le nombre d'abonné
    for span in soup.findAll('span',attrs={'class': 'yt-subscription-button-subscriber-count-branded-horizontal yt-subscriber-count'}):
        video_details['Nombre abonné'] = span.text.strip()

#sortir hashtags
    hashtags = []

    for span in soup.findAll('span',attrs={'class': 'standalone-collection-badge-renderer-text'}):
        for a in span.findAll('a',attrs={'class': 'yt-uix-sessionlink'}):
            hashtags.append(a.text.strip())
    video_details['Référence'] = hashtags


#    with open('data1.json', 'w', encoding='utf8') as outfile:
#        json.dump(video_details, outfile, ensure_ascii=False,indent=4)
    print(video_details)
    print ('Extraction finie')

# %%
CréeJs(listVideos,0)
# Out:
# {'Titre': 'A380 - Le Géant des Airs - Documentaire', 'Nom chaine': '- French Air Force & Co -', 'Nombre de vues': '100\u202f368\xa0vues', 'LIKES': '703', 'DISLIKES': '30', 'Nombre abonné': '7,85\xa0k', 'Référence': []}
# Extraction finie

# %%
url = listVideos[0]
req = Request(url, headers={'User-Agent': 'Mozilla/5.0'})
webpage = urlopen(req).read()
soup = BeautifulSoup(webpage, 'html.parser') 

for span1 in span.findAll('span',attrs={'class': 'yt-uix-button-content'}):
    print(span1.text.strip())
# Out:
# 30

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

#url = input('Enter Youtube Video Url- ')
url = listVideos[0]
req = Request(url, headers={'User-Agent': 'Mozilla/5.0'})
webpage = urlopen(req).read()


soup = BeautifulSoup(webpage, 'html.parser')
html = soup.prettify('utf-8')
video_details = {}

for span in soup.findAll('span',attrs={'class': 'watch-title'}):
    video_details['Titre'] = span.text.strip()

for script in soup.findAll('script',attrs={'type': 'application/ld+json'}):
        channelDesctiption = json.loads(script.text.strip())
        video_details['Nom chaine'] = channelDesctiption['itemListElement'][0]['item']['name']

for div in soup.findAll('div',attrs={'class': 'watch-view-count'}):
    video_details['Nombre de vues'] = div.text.strip()
'''
for button in soup.findAll('button',attrs={'title': 'I like this'}):
    video_details['LIKES'] = button.text.strip()

for button in soup.findAll('button',attrs={'title': 'I dislike this'}):
    video_details['DISLIKES'] = button.text.strip()
'''
for span in soup.findAll('span',attrs={'class': 'yt-subscription-button-subscriber-count-branded-horizontal yt-subscriber-count'}):
    video_details['Nombre abonné'] = span.text.strip()

hashtags = []
for span in soup.findAll('span',attrs={'class': 'standalone-collection-badge-renderer-text'}):
    for a in span.findAll('a',attrs={'class': 'yt-uix-sessionlink'}):
        hashtags.append(a.text.strip())
video_details['Référence'] = hashtags


# A corriger

'''
for script in soup.findAll('script'):
        test = json.loads(script.text.strip())
# FAUX        
com = []
for span in soup.findAll('a',attrs={'class': 'yt-formatted-string'}):
    print(span)
    for a in span.findAll('span',attrs={'class': 'style-scope ytd-comment-renderer'}):
        print('ok')
        com.append(a.text.strip())
video_details['Commentaires'] = com
for link in soup.findAll(id="content-text"):
    print(link.get_text())

###########    
'''
    
with open('output_file.html', 'wb') as file:
    file.write(html)


with open('data1.json', 'w', encoding='utf8') as outfile:
    json.dump(video_details, outfile, ensure_ascii=False,indent=4)
print(video_details)
print ('Extraction finie')
# Out:
# {'Titre': 'A380 - Le Géant des Airs - Documentaire', 'Nom chaine': '- French Air Force & Co -', 'Nombre de vues': '100\u202f349\xa0vues', 'Nombre abonné': '7,85\xa0k', 'Référence': []}
# Extraction finie

# %%
r = requests.get("https://www.youtube.com/watch?v=2RDCppcfveg")
page = r.text

# %%
# Out:
# <!DOCTYPE html>
# ...
