# %%
import urllib.request
import urllib.parse
import urllib.error
from bs4 import BeautifulSoup
import ssl
import json
import ast
import json
import os
from urllib.request import Request, urlopen
from bs4 import BeautifulSoup as bs
import requests

# %%
racineURL = "https://s.weibo.com/weibo/"
EquationRecherche = "Airbus%2520A350"

r = requests.get(racineURL + EquationRecherche)
page = r.text
soup = bs(page,'html.parser')

# videos = soup.findAll('a',attrs={'class':'yt-uix-tile-link'})

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible">
# <meta content="webkit" name="renderer"/>
# <meta content="initial-scale=1,minimum-scale=1" name="viewport"/>
# <title>微博搜索</title>
# <link href="//img.t.sinajs.cn/t4/appstyle/searchpc/css/pc/css/video.css?version=20200102104577" rel="stylesheet"/>
# <link href="//img.t.sinajs.cn/t4/appstyle/searchpc/css/pc/css/global.css?version=20200102104577" rel="stylesheet"/>
# <link href="//img.t.sinajs.cn/t4/appstyle/searchpc/css/pc/css/module.css?version=20200102104577" rel="stylesheet"/>
# <link href="//img.t.sinajs.cn/t4/appstyle/searchpc/css/pc/css/page.css?version=20200102104577" rel="stylesheet"/>
# <link href="//img.t.sinajs.cn/t4/appstyle/searchpc/css/pc/css/card.css?version=20200102104577" rel="stylesheet"/>
# <link href="//img.t.sinajs.cn/t4/appstyle/searchpc/css/pc/css/css_v6/layer/layer_show_pic.css?version=20200102104577" rel="stylesheet"/>
# ...

# %%
texte = soup.findAll('p',attrs={'class':'txt'})

# %%
texte
# Out:
# [<p class="txt" nick-name="北京麦子2010" node-type="feed_list_content">
#                      空客 <em class="s-color-red">A</em><em class="s-color-red">350</em>(<em class="s-color-red">Airbus</em> <em class="s-color-red">A</em><em class="s-color-red">350</em>),地点:法兰克福降落后… ​                </p>,
#  <p class="txt" nick-name="基爷不是基" node-type="feed_list_content">
#                      四川航空 熊猫彩绘<br/><em class="s-color-red">Airbus</em> <em class="s-color-red">A</em><em class="s-color-red">350</em>-941 B-306N<br/><a href="//weibo.com/n/%E7%A9%BA%E4%B8%AD%E5%AE%A2%E8%BD%A6" target="_blank">@空中客车</a> <a href="//weibo.com/n/%E5%9B%9B%E5%B7%9D%E8%88%AA%E7%A9%BA" target="_blank">@四川航空</a> ​                </p>,
#  <p class="txt" nick-name="仔糕随行笔记" node-type="feed_list_content">
# ...
